# %% [markdown]
# # Detecting Human Activities Through Smartphone Sensor - Training

# %% [markdown]
# ## Imports

# %%
# TF related imports
import tensorflow as tf
from tensorflow.keras.models import Model
import tensorflow.keras.layers as layer
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

#scikit related imports
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# other generic imports
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from mlxtend import plotting
from tqdm import tqdm
from datetime import timedelta
import time
# Out:
# 2024-11-20 11:14:08.554240: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-20 11:14:08.568832: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-20 11:14:08.573431: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-20 11:14:08.584769: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-20 11:14:09.400113: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Global Variables

# %%
# global variables
PBAR_FORMAT='{desc:12} {percentage:3.0f}%|{bar:27}| [ {n:4d}/{total:4d}, {elapsed}<{remaining}{postfix} ]'

ACTIVITY_CODES_MAPPING = {'A': 'walking',
                          'B': 'jogging',
                          'C': 'stairs',
                          'D': 'sitting',
                          'E': 'standing',
                          'F': 'typing',
                          'G': 'brushing teeth',
                          'H': 'eating soup',
                          'I': 'eating chips',
                          'J': 'eating pasta',
                          'K': 'drinking from cup',
                          'L': 'eating sandwich',
                          'M': 'kicking soccer ball',
                          'O': 'playing catch tennis ball',
                          'P': 'dribbling basket ball',
                          'Q': 'writing',
                          'R': 'clapping',
                          'S': 'folding clothes'}
# csv file column names
COL_NAMES =  ['id' , 'activity_code' , 'timestamp', 'x', 'y', 'z']
# training verbose
VERBOSE = 1
# rnadom state for split
RANDOM_STATE=12345

# %% [markdown]
# ## Dataset, Model and Trainer

# %% [markdown]
# ### Helper functions

# %%
def get_activity_code(activity_names):
    cat_len=len(activity_names)
    activity_code={}
    for idx, an in enumerate(activity_names):
        for k in ACTIVITY_CODES_MAPPING.keys() :
            if ACTIVITY_CODES_MAPPING[k]==an:
                key = k
        activity_code[key]=idx
    
    assert(len(activity_code.keys())== cat_len)
    
    print(f"{activity_code}")
    print(f"Number of Categories {cat_len}")
    return activity_code, cat_len

def sliding_window(dataset, window_size, step_size):  
    x_list, y_list, z_list = [], [], []
    targets_list = []
    for i in range(0, dataset.shape[0] - window_size, step_size):
        x_list.append(dataset["x"].values[i: i + window_size])
        y_list.append(dataset["y"].values[i: i + window_size])
        z_list.append(dataset["z"].values[i: i + window_size])
        targets_list.append(stats.mode(dataset["activity_code"][i: i + window_size])[0])

    feature_list = [x_list, y_list, z_list]

    feature_list = [np.array(data_list) for data_list in feature_list]
    dataset = np.stack(feature_list, axis = 2)

    return dataset, targets_list

# %% [markdown]
# ### Dataset

# %%
def WISDM_Dataset(dir, window_size, step_size, activity_code):
    window_size = window_size
    step_size = step_size
    path = dir
    column_names = COL_NAMES
    activity_dic = activity_code
    filelist_train = sorted([txt for txt in os.listdir(path + "/") if txt[-4:] == ".txt"])
    columns = ["x", "y", "z"]
        
    # Training data
    dataset_train = pd.DataFrame()

    for txt in tqdm(filelist_train, desc="loading data", bar_format=PBAR_FORMAT):
        dataset_tmp = pd.read_csv(path + '/' + txt, header = None, names = column_names, comment = ";")
        for k in activity_dic.keys():
            df_tmp = dataset_tmp[dataset_tmp['activity_code']==k][0:2400]
            dataset_train = pd.concat([dataset_train, df_tmp])
    print(dataset_train)

    # normalize the data
    dataset_train["activity_code"] = dataset_train["activity_code"].map(activity_dic)
    labels = dataset_train["activity_code"].to_numpy()

    scaler = RobustScaler()
    dataset_train = scaler.fit_transform(dataset_train[["x", "y", "z"]])
    dataset_train = pd.DataFrame(data = dataset_train, columns = ["x", "y", "z"])
    dataset_train["activity_code"] = labels
    
    # feature engineering
    dataset_train, targets_list = sliding_window(dataset_train, window_size, step_size)
    targets = np.array(targets_list)
    return dataset_train, targets

# %% [markdown]
# ### Model

# %%
def lstm_net(data, num_classes):
    x_input = layer.Input(shape = (data.shape[-2:]))

    x = layer.Bidirectional(layer.LSTM(256, return_sequences = True))(x_input)
    x = layer.BatchNormalization()(x)
    x = layer.Bidirectional(layer.LSTM(128, return_sequences = True))(x)
    x = layer.BatchNormalization()(x)

    x = layer.Flatten()(x)

    x = layer.Dense(128, activation = "relu")(x)
    x = layer.BatchNormalization()(x)
    x = layer.Dropout(0.5)(x)
    x_output = layer.Dense(num_classes, activation = "softmax")(x)

    model = Model(inputs = x_input, outputs = x_output, name = "LSTM_NET")

    return model

# %% [markdown]
# ### Plotting function

# %%
def plot_loss_acc(epochs, train_losses, train_acc, test_losses, test_acc, fold):
    fig, ax1 = plt.subplots()
    xaxis = list(range(1, epochs + 1))
    plt_train_loss = ax1.plot(xaxis, train_losses, label = "Training Loss", color="red")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2 = ax1.twinx()
    plt_train_acc = ax2.plot(xaxis, train_acc, label = "Training Accuracy", color="green")
    ax2.set_ylabel("Accuracy in %")
    ax2.set_ylim(0.0, 100.0)

    plt_val_loss = ax1.plot(xaxis, test_losses, label = "Validation Loss", color="firebrick")
    plt_val_acc = ax2.plot(xaxis, test_acc, label = "Validation Accuracy", color="limegreen")

    lines = plt_train_loss + plt_train_acc + plt_val_loss + plt_val_acc
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels)
    fold = " Fold " + str(fold) 
    plt.title("Loss and Accuracy" + fold)
    plt.show()

def plot_confusion_matrix(y_pred, y_valid, fold):
    conf_matrix = confusion_matrix(y_valid, y_pred)
    plotting.plot_confusion_matrix(conf_mat = conf_matrix,
                                   class_names = ACTIVITY_NAMES,
                                   show_normed = True,
                                   figsize = (10, 7),
                                   colorbar = True)
    plt.title("Confusion matrix Fold " + str(fold))
    plt.show()

# %% [markdown]
# ### Trainer function

# %%
def train(nn_net, cat_len, batch_size, num_epochs, k_fold, train_ds, target_ds):
    val_acc_last = []
    
    training_data={}
    start_time = time.time()
    for fold, (train_index, test_index) in enumerate(k_fold.split(train_ds, target_ds)):
        print(f"Running fold: {fold}")
        x_train, x_valid = train_ds[train_index], train_ds[test_index]
        y_train, y_valid = target_ds[train_index], target_ds[test_index]
        
        # convert to tf dataset
        train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size).with_options(options)
        valid_data = tf.data.Dataset.from_tensor_slices((x_valid, y_valid)).batch(batch_size).with_options(options)
        
        model = nn_net(train_ds, cat_len)
        
        model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
        
        learning_rate = ReduceLROnPlateau(monitor = "val_loss", factor = 0.5, patience = 5, verbose = VERBOSE)
        early_stopping = EarlyStopping(monitor = "val_loss", patience = 10, verbose = VERBOSE, mode = "min", 
                                       restore_best_weights = True)
        
        # model training
        model_data = model.fit(train_data, 
                                validation_data = valid_data, 
                                epochs = num_epochs,
                                verbose = VERBOSE,
                                batch_size = BATCH_SIZE, 
                                callbacks = [learning_rate, early_stopping])        
        val_acc_last.append(np.around(100.0 * model_data.history["val_accuracy"][-1], 2))

        y_pred = np.argmax(model.predict(valid_data, batch_size = BATCH_SIZE), axis = 1)
        print("\n")

        training_data[fold] = {'model_data':model_data,
                               'y_pred': y_pred, 
                               'y_valid':y_valid}
        print(f'Time elapsed: {timedelta(microseconds=int((time.time()-start_time)*1000000))}')
    
    print(f'Total Training Time: {timedelta(seconds=int(time.time()-start_time))}')
    print("Val Acc per fold:", val_acc_last)
    return training_data

# %% [markdown]
# ## Training on watch accelerometer

# %% [markdown]
# ### Hyper parameters

# %%
#ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "kicking soccer ball"]
ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "typing", "brushing teeth",
                  "eating soup", "drinking from cup", 
                  "kicking soccer ball", "playing catch tennis ball", "dribbling basket ball", 
                  "writing", "clapping", "folding clothes"]
NUM_EPOCHS = 90
BATCH_SIZE = 256
WINDOW_SIZE=200
STEP_SIZE=100
NUM_SPLITS=5
NN_NET = lstm_net
DATA_DIR="../dataset/raw/watch/accel"

# %% [markdown]
# ### Initialize Dataset

# %%
options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.OFF
activity_code, cat_len = get_activity_code(ACTIVITY_NAMES)
# Dataset
train_ds, target_ds = WISDM_Dataset(dir = DATA_DIR,
                              window_size = WINDOW_SIZE,
                              step_size = STEP_SIZE,
                              activity_code = activity_code)
k_fold = KFold(n_splits = NUM_SPLITS,
           shuffle = True,
           random_state = RANDOM_STATE)
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'K': 8, 'M': 9, 'O': 10, 'P': 11, 'Q': 12, 'R': 13, 'S': 14}
# Number of Categories 15
# loading data 100%|███████████████████████████| [   51/  51, 00:14<00:00 ]
#          id activity_code         timestamp         x         y         z
# 0      1600             A    90426708196641  7.091625 -0.591667  8.195502
# 1      1600             A    90426757696641  4.972757 -0.158317  6.696732
# 2      1600             A    90426807196641  3.253720 -0.191835  6.107758
# 3      1600             A    90426856696641  2.801216 -0.155922  5.997625
# 4      1600             A    90426906196641  3.770868 -1.051354  7.731027
# ...     ...           ...               ...       ...       ...       ...
# 65386  1650             S  2426124382870752  6.425738 -6.462100  1.874061
# 65387  1650             S  2426124432864802  6.267721 -6.217891  1.682525
# 65388  1650             S  2426124482858852  5.822399 -6.553080  1.079186
# 65389  1650             S  2426124532852902  5.590162 -7.029526  0.504578
# 65390  1650             S  2426124582846952  5.702689 -7.668778  0.317830
#
# [1826400 rows x 6 columns]

# %% [markdown]
# ### Model Summary

# %%
model = NN_NET(train_ds, cat_len)
print(model.summary())
# Out:
# 2024-11-20 11:14:33.581057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6634 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:65:00.0, compute capability: 7.5
# Model: "LSTM_NET"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 200, 512)       │       532,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 200, 256)       │       656,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 200, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     6,553,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │         1,935 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,748,111 (29.56 MB)
#  Trainable params: 7,746,319 (29.55 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# None

# %% [markdown]
# ### Training

# %%
training_data = train(nn_net=NN_NET,
                      cat_len=cat_len,
                      batch_size=BATCH_SIZE,
                      num_epochs=NUM_EPOCHS,
                      k_fold=k_fold,
                      train_ds=train_ds,
                      target_ds=target_ds)
# Out:
# Running fold: 0
# Epoch 1/90
# 2024-11-20 11:14:38.106122: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.2272 - loss: 3.0227 - val_accuracy: 0.1968 - val_loss: 2.4019 - learning_rate: 0.0010
# Epoch 2/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.3476 - loss: 2.1174 - val_accuracy: 0.1637 - val_loss: 2.4186 - learning_rate: 0.0010
# Epoch 3/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.4390 - loss: 1.7876 - val_accuracy: 0.3222 - val_loss: 2.1477 - learning_rate: 0.0010
# Epoch 4/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.5177 - loss: 1.5113 - val_accuracy: 0.3822 - val_loss: 1.9624 - learning_rate: 0.0010
# Epoch 5/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.5764 - loss: 1.2956 - val_accuracy: 0.4347 - val_loss: 1.7335 - learning_rate: 0.0010
# Epoch 6/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.6241 - loss: 1.1451 - val_accuracy: 0.5042 - val_loss: 1.5901 - learning_rate: 0.0010
# Epoch 7/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.6653 - loss: 1.0132 - val_accuracy: 0.5527 - val_loss: 1.4389 - learning_rate: 0.0010
# Epoch 8/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.7083 - loss: 0.8980 - val_accuracy: 0.5987 - val_loss: 1.3197 - learning_rate: 0.0010
# Epoch 9/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.7506 - loss: 0.7962 - val_accuracy: 0.6228 - val_loss: 1.1848 - learning_rate: 0.0010
# Epoch 10/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.7688 - loss: 0.7268 - val_accuracy: 0.6734 - val_loss: 1.0582 - learning_rate: 0.0010
# Epoch 11/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.7898 - loss: 0.6506 - val_accuracy: 0.7063 - val_loss: 0.9364 - learning_rate: 0.0010
# Epoch 12/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.8136 - loss: 0.5673 - val_accuracy: 0.7002 - val_loss: 0.9847 - learning_rate: 0.0010
# Epoch 13/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.8294 - loss: 0.5326 - val_accuracy: 0.7150 - val_loss: 0.9453 - learning_rate: 0.0010
# Epoch 14/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8389 - loss: 0.4928 - val_accuracy: 0.7194 - val_loss: 0.9331 - learning_rate: 0.0010
# Epoch 15/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.8337 - loss: 0.5103 - val_accuracy: 0.7227 - val_loss: 0.9448 - learning_rate: 0.0010
# Epoch 16/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8450 - loss: 0.4599 - val_accuracy: 0.7273 - val_loss: 0.8898 - learning_rate: 0.0010
# Epoch 17/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8751 - loss: 0.3949 - val_accuracy: 0.7350 - val_loss: 0.8342 - learning_rate: 0.0010
# Epoch 18/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8895 - loss: 0.3402 - val_accuracy: 0.7643 - val_loss: 0.7911 - learning_rate: 0.0010
# Epoch 19/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9107 - loss: 0.2878 - val_accuracy: 0.7681 - val_loss: 0.7735 - learning_rate: 0.0010
# Epoch 20/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9144 - loss: 0.2709 - val_accuracy: 0.7635 - val_loss: 0.8039 - learning_rate: 0.0010
# Epoch 21/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9247 - loss: 0.2435 - val_accuracy: 0.7709 - val_loss: 0.8161 - learning_rate: 0.0010
# Epoch 22/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9256 - loss: 0.2300 - val_accuracy: 0.7268 - val_loss: 0.9454 - learning_rate: 0.0010
# Epoch 23/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9304 - loss: 0.2186 - val_accuracy: 0.7698 - val_loss: 0.8024 - learning_rate: 0.0010
# Epoch 24/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9386 - loss: 0.2052
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9383 - loss: 0.2059 - val_accuracy: 0.7791 - val_loss: 0.8079 - learning_rate: 0.0010
# Epoch 25/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9497 - loss: 0.1686 - val_accuracy: 0.7895 - val_loss: 0.7807 - learning_rate: 5.0000e-04
# Epoch 26/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9582 - loss: 0.1328 - val_accuracy: 0.7914 - val_loss: 0.8055 - learning_rate: 5.0000e-04
# Epoch 27/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9605 - loss: 0.1277 - val_accuracy: 0.7813 - val_loss: 0.8383 - learning_rate: 5.0000e-04
# Epoch 28/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9712 - loss: 0.1018 - val_accuracy: 0.8029 - val_loss: 0.7551 - learning_rate: 5.0000e-04
# Epoch 29/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9664 - loss: 0.1078 - val_accuracy: 0.7917 - val_loss: 0.8089 - learning_rate: 5.0000e-04
# Epoch 30/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9798 - loss: 0.0776 - val_accuracy: 0.7961 - val_loss: 0.7784 - learning_rate: 5.0000e-04
# Epoch 31/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9805 - loss: 0.0697 - val_accuracy: 0.7952 - val_loss: 0.8275 - learning_rate: 5.0000e-04
# Epoch 32/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9860 - loss: 0.0620 - val_accuracy: 0.7961 - val_loss: 0.8282 - learning_rate: 5.0000e-04
# Epoch 33/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9874 - loss: 0.0552
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9872 - loss: 0.0558 - val_accuracy: 0.7955 - val_loss: 0.8321 - learning_rate: 5.0000e-04
# Epoch 34/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9881 - loss: 0.0536 - val_accuracy: 0.8043 - val_loss: 0.8154 - learning_rate: 2.5000e-04
# Epoch 35/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9908 - loss: 0.0438 - val_accuracy: 0.8059 - val_loss: 0.7858 - learning_rate: 2.5000e-04
# Epoch 36/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9934 - loss: 0.0373 - val_accuracy: 0.8051 - val_loss: 0.8210 - learning_rate: 2.5000e-04
# Epoch 37/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9940 - loss: 0.0329 - val_accuracy: 0.8062 - val_loss: 0.8017 - learning_rate: 2.5000e-04
# Epoch 38/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9944 - loss: 0.0311
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9942 - loss: 0.0315 - val_accuracy: 0.8045 - val_loss: 0.8242 - learning_rate: 2.5000e-04
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 28.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
#
#
# Time elapsed: 0:04:54.405257
# Running fold: 1
# Epoch 1/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 137ms/step - accuracy: 0.2342 - loss: 3.1422 - val_accuracy: 0.1829 - val_loss: 2.3083 - learning_rate: 0.0010
# Epoch 2/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.3582 - loss: 2.1417 - val_accuracy: 0.1684 - val_loss: 2.4301 - learning_rate: 0.0010
# Epoch 3/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4274 - loss: 1.8042 - val_accuracy: 0.1927 - val_loss: 2.3413 - learning_rate: 0.0010
# Epoch 4/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5051 - loss: 1.5543 - val_accuracy: 0.3203 - val_loss: 2.1569 - learning_rate: 0.0010
# Epoch 5/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5736 - loss: 1.3192 - val_accuracy: 0.4013 - val_loss: 1.9557 - learning_rate: 0.0010
# Epoch 6/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.6196 - loss: 1.1530 - val_accuracy: 0.4544 - val_loss: 1.7412 - learning_rate: 0.0010
# Epoch 7/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6588 - loss: 1.0148 - val_accuracy: 0.5177 - val_loss: 1.4765 - learning_rate: 0.0010
# Epoch 8/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.6890 - loss: 0.9067 - val_accuracy: 0.5713 - val_loss: 1.2819 - learning_rate: 0.0010
# Epoch 9/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7402 - loss: 0.7662 - val_accuracy: 0.6370 - val_loss: 1.1223 - learning_rate: 0.0010
# Epoch 10/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7582 - loss: 0.7155 - val_accuracy: 0.6616 - val_loss: 1.0732 - learning_rate: 0.0010
# Epoch 11/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7956 - loss: 0.6235 - val_accuracy: 0.6819 - val_loss: 1.0687 - learning_rate: 0.0010
# Epoch 12/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.7934 - loss: 0.6309 - val_accuracy: 0.7013 - val_loss: 0.9829 - learning_rate: 0.0010
# Epoch 13/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8042 - loss: 0.5755 - val_accuracy: 0.6800 - val_loss: 1.0225 - learning_rate: 0.0010
# Epoch 14/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8257 - loss: 0.5240 - val_accuracy: 0.6912 - val_loss: 1.0193 - learning_rate: 0.0010
# Epoch 15/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8415 - loss: 0.4817 - val_accuracy: 0.7178 - val_loss: 0.9521 - learning_rate: 0.0010
# Epoch 16/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8575 - loss: 0.4214 - val_accuracy: 0.7358 - val_loss: 0.8682 - learning_rate: 0.0010
# Epoch 17/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8723 - loss: 0.3928 - val_accuracy: 0.7336 - val_loss: 0.9839 - learning_rate: 0.0010
# Epoch 18/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8760 - loss: 0.3824 - val_accuracy: 0.7399 - val_loss: 0.9883 - learning_rate: 0.0010
# Epoch 19/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8772 - loss: 0.3729 - val_accuracy: 0.7495 - val_loss: 0.9045 - learning_rate: 0.0010
# Epoch 20/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8934 - loss: 0.3265 - val_accuracy: 0.7564 - val_loss: 0.9254 - learning_rate: 0.0010
# Epoch 21/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9105 - loss: 0.2799
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9103 - loss: 0.2805 - val_accuracy: 0.7555 - val_loss: 0.8991 - learning_rate: 0.0010
# Epoch 22/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9287 - loss: 0.2341 - val_accuracy: 0.7763 - val_loss: 0.8405 - learning_rate: 5.0000e-04
# Epoch 23/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9404 - loss: 0.1927 - val_accuracy: 0.7917 - val_loss: 0.8104 - learning_rate: 5.0000e-04
# Epoch 24/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9474 - loss: 0.1663 - val_accuracy: 0.7900 - val_loss: 0.8134 - learning_rate: 5.0000e-04
# Epoch 25/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9539 - loss: 0.1489 - val_accuracy: 0.7966 - val_loss: 0.8055 - learning_rate: 5.0000e-04
# Epoch 26/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9645 - loss: 0.1214 - val_accuracy: 0.7958 - val_loss: 0.7908 - learning_rate: 5.0000e-04
# Epoch 27/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9693 - loss: 0.1084 - val_accuracy: 0.7988 - val_loss: 0.8409 - learning_rate: 5.0000e-04
# Epoch 28/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9747 - loss: 0.0936 - val_accuracy: 0.7950 - val_loss: 0.8284 - learning_rate: 5.0000e-04
# Epoch 29/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9774 - loss: 0.0900 - val_accuracy: 0.7982 - val_loss: 0.8485 - learning_rate: 5.0000e-04
# Epoch 30/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9767 - loss: 0.0895 - val_accuracy: 0.7972 - val_loss: 0.8396 - learning_rate: 5.0000e-04
# Epoch 31/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9707 - loss: 0.1007
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9705 - loss: 0.1014 - val_accuracy: 0.7884 - val_loss: 0.8993 - learning_rate: 5.0000e-04
# Epoch 32/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9694 - loss: 0.1001 - val_accuracy: 0.7944 - val_loss: 0.8528 - learning_rate: 2.5000e-04
# Epoch 33/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9848 - loss: 0.0629 - val_accuracy: 0.8002 - val_loss: 0.8376 - learning_rate: 2.5000e-04
# Epoch 34/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9889 - loss: 0.0546 - val_accuracy: 0.7991 - val_loss: 0.8489 - learning_rate: 2.5000e-04
# Epoch 35/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9921 - loss: 0.0465 - val_accuracy: 0.8059 - val_loss: 0.8481 - learning_rate: 2.5000e-04
# Epoch 36/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9920 - loss: 0.0429
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9919 - loss: 0.0433 - val_accuracy: 0.8013 - val_loss: 0.8474 - learning_rate: 2.5000e-04
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
#
#
# Time elapsed: 0:09:33.651161
# Running fold: 2
# Epoch 1/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - accuracy: 0.2358 - loss: 3.0860 - val_accuracy: 0.2607 - val_loss: 2.2950 - learning_rate: 0.0010
# Epoch 2/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.3620 - loss: 2.1467 - val_accuracy: 0.2204 - val_loss: 2.3325 - learning_rate: 0.0010
# Epoch 3/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.4259 - loss: 1.8085 - val_accuracy: 0.2401 - val_loss: 2.3467 - learning_rate: 0.0010
# Epoch 4/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.5009 - loss: 1.5634 - val_accuracy: 0.3242 - val_loss: 2.0871 - learning_rate: 0.0010
# Epoch 5/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.5514 - loss: 1.3716 - val_accuracy: 0.4313 - val_loss: 1.8362 - learning_rate: 0.0010
# Epoch 6/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.6090 - loss: 1.1606 - val_accuracy: 0.4836 - val_loss: 1.5802 - learning_rate: 0.0010
# Epoch 7/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.6531 - loss: 1.0409 - val_accuracy: 0.5668 - val_loss: 1.3664 - learning_rate: 0.0010
# Epoch 8/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.6870 - loss: 0.9287 - val_accuracy: 0.5953 - val_loss: 1.3330 - learning_rate: 0.0010
# Epoch 9/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7157 - loss: 0.8251 - val_accuracy: 0.6470 - val_loss: 1.1452 - learning_rate: 0.0010
# Epoch 10/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.7570 - loss: 0.7180 - val_accuracy: 0.6490 - val_loss: 1.1497 - learning_rate: 0.0010
# Epoch 11/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7694 - loss: 0.6736 - val_accuracy: 0.6577 - val_loss: 1.1225 - learning_rate: 0.0010
# Epoch 12/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7967 - loss: 0.6134 - val_accuracy: 0.7007 - val_loss: 1.0017 - learning_rate: 0.0010
# Epoch 13/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8194 - loss: 0.5510 - val_accuracy: 0.7010 - val_loss: 0.9898 - learning_rate: 0.0010
# Epoch 14/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8413 - loss: 0.4920 - val_accuracy: 0.7237 - val_loss: 0.9449 - learning_rate: 0.0010
# Epoch 15/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8434 - loss: 0.4632 - val_accuracy: 0.7210 - val_loss: 0.9932 - learning_rate: 0.0010
# Epoch 16/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8392 - loss: 0.4793 - val_accuracy: 0.7336 - val_loss: 0.9325 - learning_rate: 0.0010
# Epoch 17/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8680 - loss: 0.3952 - val_accuracy: 0.7396 - val_loss: 0.9301 - learning_rate: 0.0010
# Epoch 18/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8773 - loss: 0.3619 - val_accuracy: 0.7432 - val_loss: 0.9421 - learning_rate: 0.0010
# Epoch 19/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8963 - loss: 0.3237 - val_accuracy: 0.7429 - val_loss: 0.9303 - learning_rate: 0.0010
# Epoch 20/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8934 - loss: 0.3208 - val_accuracy: 0.7484 - val_loss: 0.8684 - learning_rate: 0.0010
# Epoch 21/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9035 - loss: 0.2927 - val_accuracy: 0.7207 - val_loss: 0.9626 - learning_rate: 0.0010
# Epoch 22/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9095 - loss: 0.2760 - val_accuracy: 0.7393 - val_loss: 0.8974 - learning_rate: 0.0010
# Epoch 23/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9255 - loss: 0.2323 - val_accuracy: 0.7530 - val_loss: 0.8639 - learning_rate: 0.0010
# Epoch 24/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9343 - loss: 0.2058 - val_accuracy: 0.7410 - val_loss: 0.9259 - learning_rate: 0.0010
# Epoch 25/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9363 - loss: 0.1965 - val_accuracy: 0.7604 - val_loss: 0.8490 - learning_rate: 0.0010
# Epoch 26/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9326 - loss: 0.2055 - val_accuracy: 0.7571 - val_loss: 0.9114 - learning_rate: 0.0010
# Epoch 27/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9341 - loss: 0.2025 - val_accuracy: 0.7541 - val_loss: 0.9481 - learning_rate: 0.0010
# Epoch 28/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9443 - loss: 0.1770 - val_accuracy: 0.7475 - val_loss: 0.9767 - learning_rate: 0.0010
# Epoch 29/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9418 - loss: 0.1746 - val_accuracy: 0.7664 - val_loss: 0.9044 - learning_rate: 0.0010
# Epoch 30/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9530 - loss: 0.1582
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9529 - loss: 0.1585 - val_accuracy: 0.7659 - val_loss: 0.9277 - learning_rate: 0.0010
# Epoch 31/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9642 - loss: 0.1194 - val_accuracy: 0.7872 - val_loss: 0.8354 - learning_rate: 5.0000e-04
# Epoch 32/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9709 - loss: 0.0959 - val_accuracy: 0.7823 - val_loss: 0.8492 - learning_rate: 5.0000e-04
# Epoch 33/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9768 - loss: 0.0786 - val_accuracy: 0.7922 - val_loss: 0.8232 - learning_rate: 5.0000e-04
# Epoch 34/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9848 - loss: 0.0608 - val_accuracy: 0.7897 - val_loss: 0.8347 - learning_rate: 5.0000e-04
# Epoch 35/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9875 - loss: 0.0528 - val_accuracy: 0.7930 - val_loss: 0.8227 - learning_rate: 5.0000e-04
# Epoch 36/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9898 - loss: 0.0490 - val_accuracy: 0.7903 - val_loss: 0.8476 - learning_rate: 5.0000e-04
# Epoch 37/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9880 - loss: 0.0501 - val_accuracy: 0.7856 - val_loss: 0.8791 - learning_rate: 5.0000e-04
# Epoch 38/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9885 - loss: 0.0492 - val_accuracy: 0.7924 - val_loss: 0.8576 - learning_rate: 5.0000e-04
# Epoch 39/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9912 - loss: 0.0402 - val_accuracy: 0.7900 - val_loss: 0.8686 - learning_rate: 5.0000e-04
# Epoch 40/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9930 - loss: 0.0366
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9927 - loss: 0.0371 - val_accuracy: 0.7968 - val_loss: 0.8534 - learning_rate: 5.0000e-04
# Epoch 41/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9933 - loss: 0.0335 - val_accuracy: 0.7985 - val_loss: 0.8818 - learning_rate: 2.5000e-04
# Epoch 42/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9935 - loss: 0.0288 - val_accuracy: 0.8007 - val_loss: 0.8643 - learning_rate: 2.5000e-04
# Epoch 43/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9956 - loss: 0.0261 - val_accuracy: 0.8004 - val_loss: 0.8872 - learning_rate: 2.5000e-04
# Epoch 44/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9960 - loss: 0.0238 - val_accuracy: 0.7976 - val_loss: 0.8836 - learning_rate: 2.5000e-04
# Epoch 45/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9962 - loss: 0.0218
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9960 - loss: 0.0221 - val_accuracy: 0.7968 - val_loss: 0.8972 - learning_rate: 2.5000e-04
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 35.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
#
#
# Time elapsed: 0:15:21.001963
# Running fold: 3
# Epoch 1/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.2220 - loss: 3.0267 - val_accuracy: 0.1703 - val_loss: 2.4468 - learning_rate: 0.0010
# Epoch 2/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.3449 - loss: 2.1456 - val_accuracy: 0.1848 - val_loss: 2.4705 - learning_rate: 0.0010
# Epoch 3/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.4049 - loss: 1.8477 - val_accuracy: 0.2051 - val_loss: 2.2425 - learning_rate: 0.0010
# Epoch 4/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.4845 - loss: 1.5823 - val_accuracy: 0.3168 - val_loss: 2.0097 - learning_rate: 0.0010
# Epoch 5/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.5587 - loss: 1.3425 - val_accuracy: 0.4318 - val_loss: 1.8322 - learning_rate: 0.0010
# Epoch 6/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.6174 - loss: 1.1388 - val_accuracy: 0.5271 - val_loss: 1.5280 - learning_rate: 0.0010
# Epoch 7/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.6485 - loss: 1.0373 - val_accuracy: 0.5769 - val_loss: 1.4383 - learning_rate: 0.0010
# Epoch 8/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.6853 - loss: 0.9200 - val_accuracy: 0.6194 - val_loss: 1.2694 - learning_rate: 0.0010
# Epoch 9/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.7295 - loss: 0.7983 - val_accuracy: 0.6276 - val_loss: 1.2265 - learning_rate: 0.0010
# Epoch 10/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7467 - loss: 0.7488 - val_accuracy: 0.6553 - val_loss: 1.1234 - learning_rate: 0.0010
# Epoch 11/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.7816 - loss: 0.6536 - val_accuracy: 0.6857 - val_loss: 1.0279 - learning_rate: 0.0010
# Epoch 12/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7943 - loss: 0.6107 - val_accuracy: 0.7048 - val_loss: 0.9540 - learning_rate: 0.0010
# Epoch 13/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8219 - loss: 0.5326 - val_accuracy: 0.6870 - val_loss: 1.0464 - learning_rate: 0.0010
# Epoch 14/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8393 - loss: 0.4872 - val_accuracy: 0.6996 - val_loss: 0.9632 - learning_rate: 0.0010
# Epoch 15/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8612 - loss: 0.4206 - val_accuracy: 0.7352 - val_loss: 0.8844 - learning_rate: 0.0010
# Epoch 16/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8749 - loss: 0.3788 - val_accuracy: 0.7503 - val_loss: 0.8931 - learning_rate: 0.0010
# Epoch 17/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8841 - loss: 0.3515 - val_accuracy: 0.7308 - val_loss: 0.9353 - learning_rate: 0.0010
# Epoch 18/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8897 - loss: 0.3340 - val_accuracy: 0.7322 - val_loss: 0.9198 - learning_rate: 0.0010
# Epoch 19/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8871 - loss: 0.3380 - val_accuracy: 0.7352 - val_loss: 0.9716 - learning_rate: 0.0010
# Epoch 20/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8844 - loss: 0.3440
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8842 - loss: 0.3450 - val_accuracy: 0.7325 - val_loss: 0.9525 - learning_rate: 0.0010
# Epoch 21/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9061 - loss: 0.2730 - val_accuracy: 0.7749 - val_loss: 0.7935 - learning_rate: 5.0000e-04
# Epoch 22/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9296 - loss: 0.2268 - val_accuracy: 0.7872 - val_loss: 0.7391 - learning_rate: 5.0000e-04
# Epoch 23/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9497 - loss: 0.1699 - val_accuracy: 0.7881 - val_loss: 0.7322 - learning_rate: 5.0000e-04
# Epoch 24/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9560 - loss: 0.1457 - val_accuracy: 0.7924 - val_loss: 0.7214 - learning_rate: 5.0000e-04
# Epoch 25/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9665 - loss: 0.1284 - val_accuracy: 0.7793 - val_loss: 0.7961 - learning_rate: 5.0000e-04
# Epoch 26/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9598 - loss: 0.1332 - val_accuracy: 0.7971 - val_loss: 0.7428 - learning_rate: 5.0000e-04
# Epoch 27/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9688 - loss: 0.1131 - val_accuracy: 0.7848 - val_loss: 0.8186 - learning_rate: 5.0000e-04
# Epoch 28/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9702 - loss: 0.1071 - val_accuracy: 0.7771 - val_loss: 0.8148 - learning_rate: 5.0000e-04
# Epoch 29/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9730 - loss: 0.1044
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9726 - loss: 0.1053 - val_accuracy: 0.7793 - val_loss: 0.8253 - learning_rate: 5.0000e-04
# Epoch 30/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9715 - loss: 0.1016 - val_accuracy: 0.7960 - val_loss: 0.7652 - learning_rate: 2.5000e-04
# Epoch 31/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9789 - loss: 0.0760 - val_accuracy: 0.8015 - val_loss: 0.7772 - learning_rate: 2.5000e-04
# Epoch 32/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9850 - loss: 0.0677 - val_accuracy: 0.7963 - val_loss: 0.7813 - learning_rate: 2.5000e-04
# Epoch 33/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9875 - loss: 0.0587 - val_accuracy: 0.7976 - val_loss: 0.7873 - learning_rate: 2.5000e-04
# Epoch 34/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9893 - loss: 0.0550
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9890 - loss: 0.0556 - val_accuracy: 0.7922 - val_loss: 0.8097 - learning_rate: 2.5000e-04
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
#
#
# Time elapsed: 0:19:44.284853
# Running fold: 4
# Epoch 1/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - accuracy: 0.2119 - loss: 3.0953 - val_accuracy: 0.1950 - val_loss: 2.3866 - learning_rate: 0.0010
# Epoch 2/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.3346 - loss: 2.2054 - val_accuracy: 0.1700 - val_loss: 2.3783 - learning_rate: 0.0010
# Epoch 3/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.4114 - loss: 1.8397 - val_accuracy: 0.2456 - val_loss: 2.2601 - learning_rate: 0.0010
# Epoch 4/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.5035 - loss: 1.5498 - val_accuracy: 0.3628 - val_loss: 1.9794 - learning_rate: 0.0010
# Epoch 5/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.5767 - loss: 1.2855 - val_accuracy: 0.4551 - val_loss: 1.6996 - learning_rate: 0.0010
# Epoch 6/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.6304 - loss: 1.1318 - val_accuracy: 0.4578 - val_loss: 1.6127 - learning_rate: 0.0010
# Epoch 7/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6728 - loss: 0.9950 - val_accuracy: 0.5331 - val_loss: 1.4468 - learning_rate: 0.0010
# Epoch 8/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.7078 - loss: 0.8746 - val_accuracy: 0.5942 - val_loss: 1.2713 - learning_rate: 0.0010
# Epoch 9/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.7392 - loss: 0.7893 - val_accuracy: 0.6377 - val_loss: 1.1326 - learning_rate: 0.0010
# Epoch 10/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7651 - loss: 0.7087 - val_accuracy: 0.6429 - val_loss: 1.1132 - learning_rate: 0.0010
# Epoch 11/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7811 - loss: 0.6398 - val_accuracy: 0.6717 - val_loss: 1.0510 - learning_rate: 0.0010
# Epoch 12/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8043 - loss: 0.5868 - val_accuracy: 0.7237 - val_loss: 0.9597 - learning_rate: 0.0010
# Epoch 13/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8446 - loss: 0.4834 - val_accuracy: 0.7010 - val_loss: 0.9947 - learning_rate: 0.0010
# Epoch 14/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8422 - loss: 0.4641 - val_accuracy: 0.7122 - val_loss: 0.9253 - learning_rate: 0.0010
# Epoch 15/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8727 - loss: 0.3947 - val_accuracy: 0.7026 - val_loss: 1.0121 - learning_rate: 0.0010
# Epoch 16/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8704 - loss: 0.3940 - val_accuracy: 0.7385 - val_loss: 0.9073 - learning_rate: 0.0010
# Epoch 17/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8921 - loss: 0.3292 - val_accuracy: 0.7325 - val_loss: 0.9163 - learning_rate: 0.0010
# Epoch 18/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8916 - loss: 0.3267 - val_accuracy: 0.7240 - val_loss: 0.9954 - learning_rate: 0.0010
# Epoch 19/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.8931 - loss: 0.3182 - val_accuracy: 0.7530 - val_loss: 0.8699 - learning_rate: 0.0010
# Epoch 20/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9038 - loss: 0.2799 - val_accuracy: 0.7410 - val_loss: 0.9088 - learning_rate: 0.0010
# Epoch 21/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9187 - loss: 0.2441 - val_accuracy: 0.7484 - val_loss: 0.9383 - learning_rate: 0.0010
# Epoch 22/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9192 - loss: 0.2499 - val_accuracy: 0.7459 - val_loss: 0.9005 - learning_rate: 0.0010
# Epoch 23/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9241 - loss: 0.2339 - val_accuracy: 0.7111 - val_loss: 1.0671 - learning_rate: 0.0010
# Epoch 24/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9115 - loss: 0.2679
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9115 - loss: 0.2680 - val_accuracy: 0.7519 - val_loss: 0.9803 - learning_rate: 0.0010
# Epoch 25/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9381 - loss: 0.1909 - val_accuracy: 0.7848 - val_loss: 0.8137 - learning_rate: 5.0000e-04
# Epoch 26/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9559 - loss: 0.1448 - val_accuracy: 0.7933 - val_loss: 0.7965 - learning_rate: 5.0000e-04
# Epoch 27/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9634 - loss: 0.1219 - val_accuracy: 0.7949 - val_loss: 0.8058 - learning_rate: 5.0000e-04
# Epoch 28/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9695 - loss: 0.1063 - val_accuracy: 0.7949 - val_loss: 0.7944 - learning_rate: 5.0000e-04
# Epoch 29/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9770 - loss: 0.0873 - val_accuracy: 0.8042 - val_loss: 0.7834 - learning_rate: 5.0000e-04
# Epoch 30/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9815 - loss: 0.0761 - val_accuracy: 0.7897 - val_loss: 0.8201 - learning_rate: 5.0000e-04
# Epoch 31/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9828 - loss: 0.0707 - val_accuracy: 0.7998 - val_loss: 0.8085 - learning_rate: 5.0000e-04
# Epoch 32/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9868 - loss: 0.0615 - val_accuracy: 0.7933 - val_loss: 0.8179 - learning_rate: 5.0000e-04
# Epoch 33/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9883 - loss: 0.0542 - val_accuracy: 0.8039 - val_loss: 0.7903 - learning_rate: 5.0000e-04
# Epoch 34/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9880 - loss: 0.0524
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9878 - loss: 0.0531 - val_accuracy: 0.7968 - val_loss: 0.8531 - learning_rate: 5.0000e-04
# Epoch 35/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9880 - loss: 0.0536 - val_accuracy: 0.8026 - val_loss: 0.8129 - learning_rate: 2.5000e-04
# Epoch 36/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9931 - loss: 0.0399 - val_accuracy: 0.7996 - val_loss: 0.8264 - learning_rate: 2.5000e-04
# Epoch 37/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9944 - loss: 0.0338 - val_accuracy: 0.8001 - val_loss: 0.8245 - learning_rate: 2.5000e-04
# Epoch 38/90
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9953 - loss: 0.0307 - val_accuracy: 0.7938 - val_loss: 0.8677 - learning_rate: 2.5000e-04
# Epoch 39/90
# 57/58 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9955 - loss: 0.0296
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9953 - loss: 0.0301 - val_accuracy: 0.7916 - val_loss: 0.8818 - learning_rate: 2.5000e-04
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
#
#
# Time elapsed: 0:24:45.683682
# Total Training Time: 0:24:45
# Val Acc per fold: [80.45, 80.13, 79.68, 79.22, 79.16]

# %% [markdown]
# ### Plot loss and accuracy

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    plot_loss_acc(len(model_data.history["loss"]), model_data.history["loss"], 
                              [acc * 100.0 for acc in model_data.history["accuracy"]], 
                              model_data.history["val_loss"], 
                              [acc * 100.0 for acc in model_data.history["val_accuracy"]], str(k))

# %% [markdown]
# ### Plot Confusion matrix

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    plot_confusion_matrix(y_pred, y_valid, k)

# %% [markdown]
# ### Accuracy Per Fold

# %%
print("Validation Accuracy fold wise")
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    val_acc = np.around(100.0 * model_data.history["val_accuracy"][-1], 2)
    print(f"fold {k}: {val_acc}")
# Out:
# Validation Accuracy fold wise
# fold 0: 80.45
# fold 1: 80.13
# fold 2: 79.68
# fold 3: 79.22
# fold 4: 79.16

# %% [markdown]
# ### Classification metric

# %%
for k in training_data.keys():
    # F1 score
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    print(f"Classification report for fold {k}")
    print(classification_report(y_true=y_valid,
                                y_pred=y_pred))
# Out:
# Classification report for fold 0
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91       237
#            1       0.97      0.97      0.97       249
#            2       0.92      0.84      0.88       244
#            3       0.61      0.59      0.60       237
#            4       0.63      0.78      0.70       233
#            5       0.68      0.57      0.62       235
#            6       0.83      0.78      0.80       250
#            7       0.77      0.80      0.79       263
#            8       0.72      0.75      0.73       269
#            9       0.86      0.82      0.84       233
#           10       0.95      0.86      0.90       256
#           11       0.97      0.86      0.91       241
#           12       0.66      0.76      0.71       244
#           13       0.91      0.84      0.87       244
#           14       0.73      0.91      0.81       218
#
#     accuracy                           0.80      3653
#    macro avg       0.81      0.80      0.80      3653
# weighted avg       0.81      0.80      0.80      3653
#
# Classification report for fold 1
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87       262
#            1       0.98      0.98      0.98       213
#            2       0.87      0.79      0.83       260
#            3       0.50      0.61      0.55       241
#            4       0.75      0.77      0.76       243
#            5       0.75      0.60      0.66       242
#            6       0.88      0.77      0.82       258
#            7       0.67      0.80      0.73       228
#            8       0.76      0.76      0.76       229
#            9       0.85      0.86      0.85       238
#           10       0.97      0.87      0.92       239
#           11       0.96      0.83      0.89       257
#           12       0.63      0.80      0.71       246
#           13       0.87      0.88      0.87       238
#           14       0.77      0.82      0.79       259
#
#     accuracy                           0.80      3653
#    macro avg       0.81      0.80      0.80      3653
# weighted avg       0.81      0.80      0.80      3653
#
# Classification report for fold 2
#               precision    recall  f1-score   support
#
#            0       0.94      0.85      0.89       266
#            1       1.00      0.97      0.98       224
#            2       0.89      0.84      0.86       240
#            3       0.48      0.66      0.56       265
#            4       0.73      0.73      0.73       257
#            5       0.75      0.52      0.61       227
#            6       0.84      0.85      0.85       233
#            7       0.69      0.83      0.75       232
#            8       0.65      0.72      0.68       253
#            9       0.90      0.81      0.85       245
#           10       0.97      0.87      0.92       236
#           11       0.99      0.83      0.91       223
#           12       0.73      0.75      0.74       250
#           13       0.91      0.85      0.88       254
#           14       0.73      0.84      0.78       247
#
#     accuracy                           0.79      3652
#    macro avg       0.81      0.79      0.80      3652
# weighted avg       0.81      0.79      0.80      3652
#
# Classification report for fold 3
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.92       257
#            1       0.99      0.99      0.99       271
#            2       0.88      0.81      0.84       201
#            3       0.49      0.71      0.58       255
#            4       0.66      0.70      0.68       243
#            5       0.83      0.35      0.49       243
#            6       0.76      0.77      0.77       226
#            7       0.72      0.76      0.74       233
#            8       0.71      0.78      0.74       253
#            9       0.91      0.79      0.85       254
#           10       0.98      0.90      0.94       242
#           11       0.98      0.87      0.93       247
#           12       0.65      0.80      0.72       254
#           13       0.92      0.87      0.90       257
#           14       0.74      0.88      0.80       216
#
#     accuracy                           0.79      3652
#    macro avg       0.81      0.79      0.79      3652
# weighted avg       0.81      0.79      0.79      3652
#
# Classification report for fold 4
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89       252
#            1       0.99      0.99      0.99       243
#            2       0.88      0.84      0.86       255
#            3       0.52      0.69      0.59       226
#            4       0.69      0.79      0.74       248
#            5       0.77      0.73      0.75       253
#            6       0.81      0.75      0.78       257
#            7       0.76      0.73      0.74       268
#            8       0.75      0.72      0.73       220
#            9       0.89      0.80      0.84       254
#           10       0.97      0.89      0.93       227
#           11       0.97      0.86      0.92       256
#           12       0.68      0.74      0.71       230
#           13       0.85      0.80      0.82       231
#           14       0.75      0.86      0.80       232
#
#     accuracy                           0.80      3652
#    macro avg       0.81      0.80      0.81      3652
# weighted avg       0.82      0.80      0.81      3652

# %% [markdown]
# ## Training on watch gyroscope sensor

# %% [markdown]
# ### Hyper parameters

# %%
#ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "kicking soccer ball"]
ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "typing", "brushing teeth",
                  "eating soup", "drinking from cup", 
                  "kicking soccer ball", "playing catch tennis ball", "dribbling basket ball", 
                  "writing", "clapping", "folding clothes"]
NUM_EPOCHS = 90
BATCH_SIZE = 256
WINDOW_SIZE=200
STEP_SIZE=100
NUM_SPLITS=5
NN_NET = lstm_net
DATA_DIR="../dataset/raw/watch/gyro"

# %% [markdown]
# ### Initialize Dataset

# %%
options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.OFF
activity_code, cat_len = get_activity_code(ACTIVITY_NAMES)
# Dataset
train_ds, target_ds = WISDM_Dataset(dir = DATA_DIR,
                              window_size = WINDOW_SIZE,
                              step_size = STEP_SIZE,
                              activity_code = activity_code)
k_fold = KFold(n_splits = NUM_SPLITS,
           shuffle = True,
           random_state = RANDOM_STATE)
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'K': 8, 'M': 9, 'O': 10, 'P': 11, 'Q': 12, 'R': 13, 'S': 14}
# Number of Categories 15
# loading data 100%|███████████████████████████| [   51/  51, 00:12<00:00 ]
#          id activity_code         timestamp         x         y         z
# 0      1600             A    90426757696641  0.314944 -1.022277 -0.309962
# 1      1600             A    90426807196641  0.387382 -0.618541 -0.048972
# 2      1600             A    90426856696641  0.070999 -0.209480 -0.195978
# 3      1600             A    90426906196641  0.037975  0.254976 -0.156563
# 4      1600             A    90426955696641  0.073129  0.719431 -0.001035
# ...     ...           ...               ...       ...       ...       ...
# 65352  1650             S  2426124432864802 -0.761755  1.007815 -0.567129
# 65353  1650             S  2426124482858852 -1.278409  1.254957 -0.672590
# 65354  1650             S  2426124532852902 -1.342324  1.273066 -0.770594
# 65355  1650             S  2426124582846952 -1.215558  1.024859 -0.732245
# 65356  1650             S  2426124632841002 -0.984396  0.541229 -0.325314
#
# [1814400 rows x 6 columns]

# %% [markdown]
# ### Model Summary

# %%
model = NN_NET(train_ds, cat_len)
print(model.summary())
# Out:
# Model: "LSTM_NET"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_12                │ (None, 200, 512)       │       532,480 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 200, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_13                │ (None, 200, 256)       │       656,384 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 200, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │     6,553,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 15)             │         1,935 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,748,111 (29.56 MB)
#  Trainable params: 7,746,319 (29.55 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# None

# %% [markdown]
# ### Training

# %%
training_data = train(nn_net=NN_NET,
                      cat_len=cat_len,
                      batch_size=BATCH_SIZE,
                      num_epochs=NUM_EPOCHS,
                      k_fold=k_fold,
                      train_ds=train_ds,
                      target_ds=target_ds)
# Out:
# Running fold: 0
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.3304 - loss: 2.3839 - val_accuracy: 0.3759 - val_loss: 2.0043 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.5377 - loss: 1.3340 - val_accuracy: 0.4015 - val_loss: 1.8075 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6133 - loss: 1.0628 - val_accuracy: 0.5068 - val_loss: 1.5173 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6818 - loss: 0.8784 - val_accuracy: 0.5597 - val_loss: 1.3322 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7338 - loss: 0.7417 - val_accuracy: 0.6572 - val_loss: 1.0918 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7757 - loss: 0.6361 - val_accuracy: 0.6644 - val_loss: 1.0059 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8014 - loss: 0.5615 - val_accuracy: 0.7305 - val_loss: 0.8369 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8327 - loss: 0.4760 - val_accuracy: 0.7393 - val_loss: 0.7698 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8400 - loss: 0.4460 - val_accuracy: 0.7418 - val_loss: 0.7633 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8748 - loss: 0.3587 - val_accuracy: 0.7721 - val_loss: 0.7110 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8911 - loss: 0.3123 - val_accuracy: 0.7716 - val_loss: 0.7210 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9082 - loss: 0.2645 - val_accuracy: 0.7702 - val_loss: 0.7155 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9152 - loss: 0.2533 - val_accuracy: 0.7909 - val_loss: 0.6963 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9592 - loss: 0.1220 - val_accuracy: 0.7847 - val_loss: 0.7668 - learning_rate: 0.0010
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9569 - loss: 0.1285 - val_accuracy: 0.7985 - val_loss: 0.6822 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9562 - loss: 0.1213 - val_accuracy: 0.8153 - val_loss: 0.7211 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9716 - loss: 0.0823 - val_accuracy: 0.8208 - val_loss: 0.6556 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9784 - loss: 0.0714 - val_accuracy: 0.8142 - val_loss: 0.7332 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9731 - loss: 0.0776
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9730 - loss: 0.0779 - val_accuracy: 0.8164 - val_loss: 0.6554 - learning_rate: 5.0000e-04
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
#
#
# Time elapsed: 0:14:54.144020
# Running fold: 4
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.3342 - loss: 2.3588 - val_accuracy: 0.3793 - val_loss: 1.9439 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5632 - loss: 1.2752 - val_accuracy: 0.4487 - val_loss: 1.6738 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6486 - loss: 1.0119 - val_accuracy: 0.5061 - val_loss: 1.4890 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7028 - loss: 0.8423 - val_accuracy: 0.6009 - val_loss: 1.2259 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7458 - loss: 0.7158 - val_accuracy: 0.6224 - val_loss: 1.0884 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7993 - loss: 0.5783 - val_accuracy: 0.6808 - val_loss: 0.9335 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8353 - loss: 0.4695 - val_accuracy: 0.7120 - val_loss: 0.8424 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8477 - loss: 0.4312 - val_accuracy: 0.7260 - val_loss: 0.8259 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8786 - loss: 0.3608 - val_accuracy: 0.7514 - val_loss: 0.7443 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8921 - loss: 0.3230 - val_accuracy: 0.7585 - val_loss: 0.7501 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9032 - loss: 0.2775 - val_accuracy: 0.7759 - val_loss: 0.7041 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9223 - loss: 0.2383 - val_accuracy: 0.7668 - val_loss: 0.7391 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9321 - loss: 0.1998 - val_accuracy: 0.7732 - val_loss: 0.7887 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9292 - loss: 0.2046 - val_accuracy: 0.7690 - val_loss: 0.7849 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9352 - loss: 0.1865 - val_accuracy: 0.7798 - val_loss: 0.7245 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9484 - loss: 0.1532
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9483 - loss: 0.1537 - val_accuracy: 0.7825 - val_loss: 0.7590 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9511 - loss: 0.1437 - val_accuracy: 0.7941 - val_loss: 0.6985 - learning_rate: 5.0000e-04
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9531 - loss: 0.1297 - val_accuracy: 0.8032 - val_loss: 0.7097 - learning_rate: 5.0000e-04
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9661 - loss: 0.1072 - val_accuracy: 0.7996 - val_loss: 0.6887 - learning_rate: 5.0000e-04
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9700 - loss: 0.0895 - val_accuracy: 0.8090 - val_loss: 0.6984 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9734 - loss: 0.0827 - val_accuracy: 0.8095 - val_loss: 0.7029 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9717 - loss: 0.0896 - val_accuracy: 0.8082 - val_loss: 0.7168 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9738 - loss: 0.0769 - val_accuracy: 0.8115 - val_loss: 0.7124 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9761 - loss: 0.0736
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9759 - loss: 0.0740 - val_accuracy: 0.8065 - val_loss: 0.7640 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9774 - loss: 0.0693 - val_accuracy: 0.8104 - val_loss: 0.7736 - learning_rate: 2.5000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9803 - loss: 0.0596 - val_accuracy: 0.8139 - val_loss: 0.7321 - learning_rate: 2.5000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9838 - loss: 0.0510 - val_accuracy: 0.8109 - val_loss: 0.7567 - learning_rate: 2.5000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9851 - loss: 0.0496 - val_accuracy: 0.8084 - val_loss: 0.7399 - learning_rate: 2.5000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9842 - loss: 0.0494
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9841 - loss: 0.0497 - val_accuracy: 0.8148 - val_loss: 0.7463 - learning_rate: 2.5000e-04
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
#
#
# Time elapsed: 0:18:37.623019
# Total Training Time: 0:18:37
# Val Acc per fold: [82.78, 80.66, 80.95, 81.64, 81.48]

# %% [markdown]
# ### Plot loss and accuracy

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    plot_loss_acc(len(model_data.history["loss"]), model_data.history["loss"], 
                              [acc * 100.0 for acc in model_data.history["accuracy"]], 
                              model_data.history["val_loss"], 
                              [acc * 100.0 for acc in model_data.history["val_accuracy"]], str(k))

# %% [markdown]
# ### Plot Confusion matrix

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    plot_confusion_matrix(y_pred, y_valid, k)

# %% [markdown]
# ### Accuracy Per Fold

# %%
print("Validation Accuracy fold wise")
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    val_acc = np.around(100.0 * model_data.history["val_accuracy"][-1], 2)
    print(f"fold {k}: {val_acc}")
# Out:
# Validation Accuracy fold wise
# fold 0: 82.78
# fold 1: 80.66
# fold 2: 80.95
# fold 3: 81.64
# fold 4: 81.48

# %% [markdown]
# ### Classification metric

# %%
for k in training_data.keys():
    # F1 score
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    print(f"Classification report for fold {k}")
    print(classification_report(y_true=y_valid,
                                y_pred=y_pred))
# Out:
# Classification report for fold 0
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.