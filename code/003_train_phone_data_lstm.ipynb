# %% [markdown]
# # Detecting Human Activities Through Smartphone Sensor - Training

# %% [markdown]
# ## Imports

# %%
# TF related imports
import tensorflow as tf
from tensorflow.keras.models import Model
import tensorflow.keras.layers as layer
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

#scikit related imports
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import confusion_matrix

# other generic imports
import numpy as np
import os
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from scipy import stats
from mlxtend import plotting
from tqdm import tqdm
# Out:
# 2024-11-20 05:34:15.990540: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-20 05:34:16.004984: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-20 05:34:16.009291: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-20 05:34:16.020500: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-20 05:34:16.819231: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Global Variables

# %%
# global variables
PBAR_FORMAT='{desc:12} {percentage:3.0f}%|{bar:27}| [ {n:4d}/{total:4d}, {elapsed}<{remaining}{postfix} ]'

ACTIVITY_CODES_MAPPING = {'A': 'walking',
                          'B': 'jogging',
                          'C': 'stairs',
                          'D': 'sitting',
                          'E': 'standing',
                          'F': 'typing',
                          'G': 'brushing teeth',
                          'H': 'eating soup',
                          'I': 'eating chips',
                          'J': 'eating pasta',
                          'K': 'drinking from cup',
                          'L': 'eating sandwich',
                          'M': 'kicking soccer ball',
                          'O': 'playing catch tennis ball',
                          'P': 'dribbling basket ball',
                          'Q': 'writing',
                          'R': 'clapping',
                          'S': 'folding clothes'}
# csv file column names
COL_NAMES =  ['id' , 'activity_code' , 'timestamp', 'x', 'y', 'z']
# training verbose
VERBOSE = 1
# rnadom state for split
RANDOM_STATE=12345

# %% [markdown]
# ## Dataset, Model and Trainer

# %% [markdown]
# ### Helper functions

# %%
def get_activity_code(activity_names):
    cat_len=len(activity_names)
    activity_code={}
    for idx, an in enumerate(activity_names):
        for k in ACTIVITY_CODES_MAPPING.keys() :
            if ACTIVITY_CODES_MAPPING[k]==an:
                key = k
        activity_code[key]=idx
    
    assert(len(activity_code.keys())== cat_len)
    
    print(f"{activity_code}")
    print(f"Number of Categories {cat_len}")
    return activity_code, cat_len

def sliding_window(dataset, window_size, step_size):  
    x_list, y_list, z_list = [], [], []
    targets_list = []
    for i in range(0, dataset.shape[0] - window_size, step_size):
        x_list.append(dataset["x"].values[i: i + window_size])
        y_list.append(dataset["y"].values[i: i + window_size])
        z_list.append(dataset["z"].values[i: i + window_size])
        targets_list.append(stats.mode(dataset["activity_code"][i: i + window_size])[0])

    feature_list = [x_list, y_list, z_list]

    feature_list = [np.array(data_list) for data_list in feature_list]
    dataset = np.stack(feature_list, axis = 2)

    return dataset, targets_list

# %% [markdown]
# ### Dataset

# %%
def WISDM_Dataset(dir, window_size, step_size, activity_code):
    window_size = window_size
    step_size = step_size
    path = dir
    column_names = COL_NAMES
    activity_dic = activity_code
    filelist_train = sorted([txt for txt in os.listdir(path + "/") if txt[-4:] == ".txt"])
    columns = ["x", "y", "z"]
        
    # Training data
    dataset_train = pd.DataFrame()

    for txt in tqdm(filelist_train, desc="loading data", bar_format=PBAR_FORMAT):
        dataset_tmp = pd.read_csv(path + '/' + txt, header = None, names = column_names, comment = ";")
        for k in activity_dic.keys():
            df_tmp = dataset_tmp[dataset_tmp['activity_code']==k][0:2400]
            dataset_train = pd.concat([dataset_train, df_tmp])
    print(dataset_train)

    # normalize the data
    dataset_train["activity_code"] = dataset_train["activity_code"].map(activity_dic)
    labels = dataset_train["activity_code"].to_numpy()

    scaler = RobustScaler()
    dataset_train = scaler.fit_transform(dataset_train[["x", "y", "z"]])
    dataset_train = pd.DataFrame(data = dataset_train, columns = ["x", "y", "z"])
    dataset_train["activity_code"] = labels
    
    # feature engineering
    dataset_train, targets_list = sliding_window(dataset_train, window_size, step_size)
    targets = np.array(targets_list)
    return dataset_train, targets

# %% [markdown]
# ### Model

# %%
def lstm_net(data, num_classes):
    x_input = layer.Input(shape = (data.shape[-2:]))

    x = layer.Bidirectional(layer.LSTM(256, return_sequences = True))(x_input)
    x = layer.BatchNormalization()(x)
    x = layer.Bidirectional(layer.LSTM(128, return_sequences = True))(x)
    x = layer.BatchNormalization()(x)

    x = layer.Flatten()(x)

    x = layer.Dense(128, activation = "relu")(x)
    x = layer.BatchNormalization()(x)
    x = layer.Dropout(0.5)(x)
    x_output = layer.Dense(num_classes, activation = "softmax")(x)

    model = Model(inputs = x_input, outputs = x_output, name = "LSTM_NET")

    return model

# %% [markdown]
# ### Plotting function

# %%
def plot_loss_acc(epochs, train_losses, train_acc, test_losses, test_acc, fold):
    fig, ax1 = plt.subplots()
    xaxis = list(range(1, epochs + 1))
    plt_train_loss = ax1.plot(xaxis, train_losses, label = "Training Loss", color="red")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2 = ax1.twinx()
    plt_train_acc = ax2.plot(xaxis, train_acc, label = "Training Accuracy", color="green")
    ax2.set_ylabel("Accuracy in %")
    ax2.set_ylim(0.0, 100.0)

    plt_val_loss = ax1.plot(xaxis, test_losses, label = "Validation Loss", color="firebrick")
    plt_val_acc = ax2.plot(xaxis, test_acc, label = "Validation Accuracy", color="limegreen")

    lines = plt_train_loss + plt_train_acc + plt_val_loss + plt_val_acc
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels)
    fold = " Fold " + str(fold) 
    plt.title("Loss and Accuracy" + fold)
    plt.show()

def plot_confusion_matrix(y_pred, y_valid, fold):
    conf_matrix = confusion_matrix(y_valid, y_pred)
    plotting.plot_confusion_matrix(conf_mat = conf_matrix,
                                   class_names = ACTIVITY_NAMES,
                                   show_normed = True,
                                   figsize = (10, 7),
                                   colorbar = True)
    plt.title("Confusion matrix Fold " + str(fold))
    plt.show()

# %% [markdown]
# ### Trainer function

# %%
def train(data_dir, num_splits, window_size, step_size, activity_names, batch_size, num_epochs):
    options = tf.data.Options()
    options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.OFF
    activity_code, cat_len = get_activity_code(activity_names)
    # Dataset
    train, targets = WISDM_Dataset(dir = data_dir,
                                  window_size = window_size,
                                  step_size = step_size,
                                  activity_code = activity_code)
      
    k_fold = KFold(n_splits = num_splits,
                   shuffle = True,
                   random_state = RANDOM_STATE)
    val_acc_last = []
    
    model = lstm_net(train, cat_len)
    print(model.summary())
    
    for fold, (train_index, test_index) in enumerate(k_fold.split(train, targets)):
        print(f"Running fold: {fold}")
        x_train, x_valid = train[train_index], train[test_index]
        y_train, y_valid = targets[train_index], targets[test_index]
        
        # convert to tf dataset
        train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size).with_options(options)
        valid_data = tf.data.Dataset.from_tensor_slices((x_valid, y_valid)).batch(batch_size).with_options(options)
        
        model = lstm_net(train, cat_len)
        
        model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
        
        learning_rate = ReduceLROnPlateau(monitor = "val_loss", factor = 0.5, patience = 5, verbose = VERBOSE)
        early_stopping = EarlyStopping(monitor = "val_loss", patience = 10, verbose = VERBOSE, mode = "min", 
                                       restore_best_weights = True)
        
        # model training
        history = model.fit(train_data, 
                            validation_data = valid_data, 
                            epochs = num_epochs,
                            verbose = VERBOSE,    # for debugging VERBOSE
                            batch_size = BATCH_SIZE, 
                            callbacks = [learning_rate, early_stopping])
        
        # Plot loss and accuracy curves
        plot_loss_acc(len(history.history["loss"]), history.history["loss"], 
                                  [acc * 100.0 for acc in history.history["accuracy"]], 
                                  history.history["val_loss"], 
                                  [acc * 100.0 for acc in history.history["val_accuracy"]], str(fold))
        
        val_acc_last.append(np.around(100.0 * history.history["val_accuracy"][-1], 2))    # safe last validation accuracy
        
        # Plot confusion matrix
        y_pred = np.argmax(model.predict(valid_data, batch_size = BATCH_SIZE), axis = 1)
        plot_confusion_matrix(y_pred, y_valid, fold)                                          
    
    print("Val Acc per fold:", val_acc_last)

# %% [markdown]
# ## Training on phone accelerometer

# %%
##################################################################
#Hyperparameter
##################################################################
#ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "kicking soccer ball"]
ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "typing", "brushing teeth",
                  "eating soup", "drinking from cup", 
                  "kicking soccer ball", "playing catch tennis ball", "dribbling basket ball", 
                  "writing", "clapping", "folding clothes"]
NUM_EPOCHS  = 90
BATCH_SIZE = 256
WINDOW_SIZE=200
STEP_SIZE=100
NUM_SPLITS=5
DATA_DIR="../dataset/raw/phone/accel"

train(data_dir=DATA_DIR,
      num_splits=NUM_SPLITS,
      window_size=WINDOW_SIZE,
      step_size=STEP_SIZE,
      activity_names=ACTIVITY_NAMES,
      batch_size=BATCH_SIZE,
      num_epochs=NUM_EPOCHS)
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'K': 8, 'M': 9, 'O': 10, 'P': 11, 'Q': 12, 'R': 13, 'S': 14}
# Number of Categories 15
# loading data 100%|███████████████████████████| [   51/  51, 00:15<00:00 ]
#           id activity_code        timestamp         x          y         z
# 0       1600             A  252207666810782 -0.364761   8.793503  1.055084
# 1       1600             A  252207717164786 -0.879730   9.768784  1.016998
# 2       1600             A  252207767518790  2.001495  11.109070  2.619156
# 3       1600             A  252207817872794  0.450623  12.651642  0.184555
# 4       1600             A  252207868226798 -2.164352  13.928436 -4.422485
# ...      ...           ...              ...       ...        ...       ...
# 154242  1650             S  357602446012000 -8.763377  -3.745811 -2.277664
# 154243  1650             S  357602466108000 -8.895103  -3.717071 -2.919529
# 154244  1650             S  357602486288000 -8.631651  -3.836822 -3.475173
# 154245  1650             S  357602506384000 -8.270002  -4.102669 -2.859653
# 154246  1650             S  357602526598000 -8.183782  -4.315825 -1.733994
#
# [1821600 rows x 6 columns]
# 2024-11-20 05:34:42.072506: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6634 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:65:00.0, compute capability: 7.5
# Model: "LSTM_NET"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 200, 512)       │       532,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 200, 256)       │       656,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 200, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     6,553,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │         1,935 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,748,111 (29.56 MB)
#  Trainable params: 7,746,319 (29.55 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# None
# Running fold: 0
# Epoch 1/90
# 2024-11-20 05:34:46.676601: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 133ms/step - accuracy: 0.1075 - loss: 3.7630 - val_accuracy: 0.1032 - val_loss: 2.6864 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.1028 - loss: 3.2016 - val_accuracy: 0.1186 - val_loss: 2.5990 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.1183 - loss: 3.0194 - val_accuracy: 0.0958 - val_loss: 2.6618 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.1396 - loss: 2.8947 - val_accuracy: 0.1235 - val_loss: 2.5347 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.1747 - loss: 2.5842 - val_accuracy: 0.1021 - val_loss: 2.6392 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.1914 - loss: 2.4723 - val_accuracy: 0.1320 - val_loss: 2.5110 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.2219 - loss: 2.3348 - val_accuracy: 0.1628 - val_loss: 2.3632 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.2292 - loss: 2.2314 - val_accuracy: 0.1902 - val_loss: 2.3226 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.2538 - loss: 2.0938 - val_accuracy: 0.2092 - val_loss: 2.1035 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.3003 - loss: 1.9373 - val_accuracy: 0.2440 - val_loss: 2.1132 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.3069 - loss: 1.9313 - val_accuracy: 0.2709 - val_loss: 1.9848 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.3376 - loss: 1.8256 - val_accuracy: 0.2786 - val_loss: 2.0249 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.3713 - loss: 1.7247 - val_accuracy: 0.2976 - val_loss: 1.9407 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.4002 - loss: 1.6328 - val_accuracy: 0.3162 - val_loss: 1.9111 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.4391 - loss: 1.5430 - val_accuracy: 0.3077 - val_loss: 1.9596 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.4559 - loss: 1.5108 - val_accuracy: 0.3105 - val_loss: 1.9817 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.4588 - loss: 1.4773 - val_accuracy: 0.2778 - val_loss: 2.0529 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.4847 - loss: 1.4163 - val_accuracy: 0.3138 - val_loss: 1.9359 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.5231 - loss: 1.3126
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.5229 - loss: 1.3132 - val_accuracy: 0.3088 - val_loss: 2.1033 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.5630 - loss: 1.2219 - val_accuracy: 0.3094 - val_loss: 2.0404 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.6038 - loss: 1.1229 - val_accuracy: 0.2998 - val_loss: 2.0895 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.6521 - loss: 1.0197 - val_accuracy: 0.2992 - val_loss: 2.2074 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.6586 - loss: 0.9916 - val_accuracy: 0.2932 - val_loss: 2.2337 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6872 - loss: 0.9146
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.6869 - loss: 0.9154 - val_accuracy: 0.3052 - val_loss: 2.1947 - learning_rate: 5.0000e-04
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# Running fold: 1
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.1044 - loss: 3.8253 - val_accuracy: 0.0969 - val_loss: 2.6261 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.0973 - loss: 3.2010 - val_accuracy: 0.1038 - val_loss: 2.6920 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.0979 - loss: 3.1476 - val_accuracy: 0.1191 - val_loss: 2.5919 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.1111 - loss: 2.9527 - val_accuracy: 0.0911 - val_loss: 2.7154 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.1274 - loss: 2.8605 - val_accuracy: 0.1060 - val_loss: 2.6391 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.1654 - loss: 2.6702 - val_accuracy: 0.1383 - val_loss: 2.5011 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1715 - loss: 2.4952 - val_accuracy: 0.1718 - val_loss: 2.3534 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.2032 - loss: 2.3063 - val_accuracy: 0.1886 - val_loss: 2.2357 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.2236 - loss: 2.1748 - val_accuracy: 0.1976 - val_loss: 2.1941 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.2494 - loss: 2.0888 - val_accuracy: 0.2369 - val_loss: 2.1201 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2723 - loss: 2.0122 - val_accuracy: 0.2492 - val_loss: 2.0423 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.2784 - loss: 1.9676 - val_accuracy: 0.2578 - val_loss: 2.0763 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.3113 - loss: 1.8620 - val_accuracy: 0.2750 - val_loss: 2.0789 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.3446 - loss: 1.7754 - val_accuracy: 0.2836 - val_loss: 2.0491 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.3815 - loss: 1.6754 - val_accuracy: 0.2761 - val_loss: 2.2011 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.3599 - loss: 1.7253
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.3599 - loss: 1.7255 - val_accuracy: 0.2605 - val_loss: 2.1203 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4192 - loss: 1.5978 - val_accuracy: 0.2987 - val_loss: 1.9769 - learning_rate: 5.0000e-04
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4568 - loss: 1.4696 - val_accuracy: 0.2819 - val_loss: 2.1092 - learning_rate: 5.0000e-04
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5030 - loss: 1.3727 - val_accuracy: 0.2923 - val_loss: 2.0936 - learning_rate: 5.0000e-04
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5371 - loss: 1.2806 - val_accuracy: 0.3096 - val_loss: 2.1020 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5707 - loss: 1.2139 - val_accuracy: 0.3143 - val_loss: 2.1223 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6006 - loss: 1.1504
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6003 - loss: 1.1513 - val_accuracy: 0.2992 - val_loss: 2.1659 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6121 - loss: 1.1097 - val_accuracy: 0.2945 - val_loss: 2.0901 - learning_rate: 2.5000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6585 - loss: 1.0182 - val_accuracy: 0.3063 - val_loss: 2.1271 - learning_rate: 2.5000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6801 - loss: 0.9577 - val_accuracy: 0.3058 - val_loss: 2.1637 - learning_rate: 2.5000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7074 - loss: 0.9011 - val_accuracy: 0.3212 - val_loss: 2.1760 - learning_rate: 2.5000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7214 - loss: 0.8459
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7212 - loss: 0.8466 - val_accuracy: 0.3176 - val_loss: 2.2152 - learning_rate: 2.5000e-04
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Running fold: 2
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.0824 - loss: 3.8951 - val_accuracy: 0.0873 - val_loss: 2.7831 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.0739 - loss: 3.3692 - val_accuracy: 0.0928 - val_loss: 2.7646 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.0646 - loss: 3.4043 - val_accuracy: 0.0818 - val_loss: 2.7698 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.1028 - loss: 3.0573 - val_accuracy: 0.0947 - val_loss: 2.7262 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1552 - loss: 2.7024 - val_accuracy: 0.1353 - val_loss: 2.4954 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.1803 - loss: 2.5644 - val_accuracy: 0.1351 - val_loss: 2.5320 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2094 - loss: 2.3740 - val_accuracy: 0.1389 - val_loss: 2.4472 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2370 - loss: 2.2155 - val_accuracy: 0.1762 - val_loss: 2.3029 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.2707 - loss: 2.0652 - val_accuracy: 0.1688 - val_loss: 2.3708 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2647 - loss: 2.0863 - val_accuracy: 0.1908 - val_loss: 2.2385 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3193 - loss: 1.8781 - val_accuracy: 0.2481 - val_loss: 2.1244 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3457 - loss: 1.7885 - val_accuracy: 0.2712 - val_loss: 2.0339 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.3786 - loss: 1.6915 - val_accuracy: 0.2882 - val_loss: 2.0421 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4034 - loss: 1.6345 - val_accuracy: 0.2970 - val_loss: 2.0638 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4200 - loss: 1.5798 - val_accuracy: 0.2923 - val_loss: 2.0382 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4463 - loss: 1.5048 - val_accuracy: 0.3132 - val_loss: 2.0089 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4641 - loss: 1.4756 - val_accuracy: 0.2959 - val_loss: 2.0216 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4731 - loss: 1.4353 - val_accuracy: 0.2918 - val_loss: 2.1787 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4701 - loss: 1.4328 - val_accuracy: 0.3000 - val_loss: 2.1912 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5191 - loss: 1.3326 - val_accuracy: 0.3000 - val_loss: 2.1358 - learning_rate: 0.0010
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5606 - loss: 1.2397
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5605 - loss: 1.2402 - val_accuracy: 0.3151 - val_loss: 2.3393 - learning_rate: 0.0010
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5958 - loss: 1.1614 - val_accuracy: 0.3138 - val_loss: 2.2413 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6288 - loss: 1.0779 - val_accuracy: 0.3231 - val_loss: 2.2066 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6771 - loss: 0.9758 - val_accuracy: 0.3179 - val_loss: 2.3898 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6819 - loss: 0.9416 - val_accuracy: 0.3107 - val_loss: 2.4144 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7089 - loss: 0.8682
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7089 - loss: 0.8684 - val_accuracy: 0.2885 - val_loss: 2.5319 - learning_rate: 5.0000e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Running fold: 3
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.0963 - loss: 3.8697 - val_accuracy: 0.0758 - val_loss: 2.7208 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.0895 - loss: 3.3450 - val_accuracy: 0.0922 - val_loss: 2.7910 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.0882 - loss: 3.2592 - val_accuracy: 0.0955 - val_loss: 2.7829 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.0978 - loss: 3.0587 - val_accuracy: 0.0755 - val_loss: 2.7806 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.0969 - loss: 2.9966 - val_accuracy: 0.0936 - val_loss: 2.6499 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1032 - loss: 2.8895 - val_accuracy: 0.0983 - val_loss: 2.5888 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1076 - loss: 2.8150 - val_accuracy: 0.1054 - val_loss: 2.5970 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1015 - loss: 2.8429 - val_accuracy: 0.0961 - val_loss: 2.6070 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1086 - loss: 2.7473 - val_accuracy: 0.1049 - val_loss: 2.5853 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.1066 - loss: 2.7013 - val_accuracy: 0.0703 - val_loss: 2.9075 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.1221 - loss: 2.6624 - val_accuracy: 0.0966 - val_loss: 2.7864 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1199 - loss: 2.6110 - val_accuracy: 0.1013 - val_loss: 2.6484 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1232 - loss: 2.5807 - val_accuracy: 0.0972 - val_loss: 2.7883 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.1204 - loss: 2.5933
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1203 - loss: 2.5939 - val_accuracy: 0.1189 - val_loss: 2.5932 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1258 - loss: 2.5278 - val_accuracy: 0.0999 - val_loss: 2.6174 - learning_rate: 5.0000e-04
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1461 - loss: 2.4317 - val_accuracy: 0.1035 - val_loss: 2.6140 - learning_rate: 5.0000e-04
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.1647 - loss: 2.3950 - val_accuracy: 0.1147 - val_loss: 2.5881 - learning_rate: 5.0000e-04
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1753 - loss: 2.3589 - val_accuracy: 0.0958 - val_loss: 2.6588 - learning_rate: 5.0000e-04
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.1809 - loss: 2.3300
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1806 - loss: 2.3311 - val_accuracy: 0.1216 - val_loss: 2.6185 - learning_rate: 5.0000e-04
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Running fold: 4
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 11s 136ms/step - accuracy: 0.0913 - loss: 4.1140 - val_accuracy: 0.0947 - val_loss: 2.7192 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.0941 - loss: 3.2661 - val_accuracy: 0.0612 - val_loss: 2.9126 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.0763 - loss: 3.3799 - val_accuracy: 0.0862 - val_loss: 2.8433 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1196 - loss: 2.9721 - val_accuracy: 0.0920 - val_loss: 2.7407 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.1692 - loss: 2.6656 - val_accuracy: 0.0975 - val_loss: 2.7490 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.2186 - loss: 2.3591 - val_accuracy: 0.1296 - val_loss: 2.7181 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2447 - loss: 2.2378 - val_accuracy: 0.1274 - val_loss: 2.5177 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2598 - loss: 2.1404 - val_accuracy: 0.1406 - val_loss: 2.7242 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2750 - loss: 2.0943 - val_accuracy: 0.1840 - val_loss: 2.2458 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.3113 - loss: 1.9322 - val_accuracy: 0.2164 - val_loss: 2.1578 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3215 - loss: 1.8507 - val_accuracy: 0.2367 - val_loss: 2.0869 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3544 - loss: 1.7482 - val_accuracy: 0.2713 - val_loss: 1.9875 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3763 - loss: 1.6913 - val_accuracy: 0.2586 - val_loss: 2.0787 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3930 - loss: 1.6579 - val_accuracy: 0.2320 - val_loss: 2.2830 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4223 - loss: 1.5909 - val_accuracy: 0.2584 - val_loss: 2.1839 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4215 - loss: 1.5643 - val_accuracy: 0.2545 - val_loss: 2.1402 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4611 - loss: 1.4840
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4607 - loss: 1.4849 - val_accuracy: 0.2754 - val_loss: 2.1088 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4891 - loss: 1.4359 - val_accuracy: 0.2685 - val_loss: 2.2000 - learning_rate: 5.0000e-04
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5234 - loss: 1.3285 - val_accuracy: 0.2691 - val_loss: 2.2389 - learning_rate: 5.0000e-04
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5777 - loss: 1.2175 - val_accuracy: 0.2765 - val_loss: 2.1499 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5845 - loss: 1.1788 - val_accuracy: 0.2617 - val_loss: 2.2894 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6177 - loss: 1.1157
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6175 - loss: 1.1163 - val_accuracy: 0.2696 - val_loss: 2.3000 - learning_rate: 5.0000e-04
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Val Acc per fold: [30.52, 31.76, 28.85, 12.16, 26.96]

# %% [markdown]
# ## Training on phone gyroscope sensor

# %%
##################################################################
#Hyperparameter
##################################################################
#ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "kicking soccer ball"]
ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "typing", "brushing teeth",
                  "eating soup", "drinking from cup", 
                  "kicking soccer ball", "playing catch tennis ball", "dribbling basket ball", 
                  "writing", "clapping", "folding clothes"]
NUM_EPOCHS = 90
BATCH_SIZE = 256
WINDOW_SIZE=200
STEP_SIZE=100
NUM_SPLITS=5
DATA_DIR="../dataset/raw/phone/gyro"

##################################################################
#Training
##################################################################
train(data_dir=DATA_DIR,
      num_splits=NUM_SPLITS,
      window_size=WINDOW_SIZE,
      step_size=STEP_SIZE,
      activity_names=ACTIVITY_NAMES,
      batch_size=BATCH_SIZE,
      num_epochs=NUM_EPOCHS)
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'K': 8, 'M': 9, 'O': 10, 'P': 11, 'Q': 12, 'R': 13, 'S': 14}
# Number of Categories 15
# loading data 100%|███████████████████████████| [   51/  51, 00:12<00:00 ]
#          id activity_code        timestamp         x         y         z
# 0      1600             A  252207918580802 -0.853210  0.297226  0.890182
# 1      1600             A  252207968934806 -0.875137  0.015472  0.162231
# 2      1600             A  252208019288809 -0.720169  0.388489 -0.284012
# 3      1600             A  252208069642813 -0.571640  1.227402 -0.241669
# 4      1600             A  252208119996817 -0.380493  1.202835 -0.213135
# ...     ...           ...              ...       ...       ...       ...
# 78280  1650             S  357650830694000  0.687096  0.087352  0.167247
# 78281  1650             S  357650870975000  0.417584 -0.095874  0.056459
# 78282  1650             S  357650911282000  0.096939 -0.083091 -0.028762
# 78283  1650             S  357650951562000 -0.242880 -0.164051 -0.102265
# 78284  1650             S  357650992561000 -0.543285 -0.302535 -0.196009
#
# [1819200 rows x 6 columns]
# Model: "LSTM_NET"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_12                │ (None, 200, 512)       │       532,480 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 200, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_13                │ (None, 200, 256)       │       656,384 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 200, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │     6,553,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 15)             │         1,935 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,748,111 (29.56 MB)
#  Trainable params: 7,746,319 (29.55 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# None
# Running fold: 0
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.1980 - loss: 2.8730 - val_accuracy: 0.2658 - val_loss: 2.0679 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.2950 - loss: 2.0652 - val_accuracy: 0.2732 - val_loss: 2.0433 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.3697 - loss: 1.8041 - val_accuracy: 0.3051 - val_loss: 1.8772 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4209 - loss: 1.6284 - val_accuracy: 0.3485 - val_loss: 1.7632 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4633 - loss: 1.5051 - val_accuracy: 0.3881 - val_loss: 1.6704 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5068 - loss: 1.3656 - val_accuracy: 0.4071 - val_loss: 1.6077 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5405 - loss: 1.2747 - val_accuracy: 0.4255 - val_loss: 1.6105 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5643 - loss: 1.2088 - val_accuracy: 0.4483 - val_loss: 1.5724 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5900 - loss: 1.1231 - val_accuracy: 0.4387 - val_loss: 1.6203 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6032 - loss: 1.0918 - val_accuracy: 0.4601 - val_loss: 1.5459 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6313 - loss: 1.0126 - val_accuracy: 0.4706 - val_loss: 1.5841 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6450 - loss: 0.9682 - val_accuracy: 0.4676 - val_loss: 1.6165 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6738 - loss: 0.9036 - val_accuracy: 0.4700 - val_loss: 1.5921 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6967 - loss: 0.8477 - val_accuracy: 0.4901 - val_loss: 1.5128 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7258 - loss: 0.7745 - val_accuracy: 0.4786 - val_loss: 1.5463 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7327 - loss: 0.7598 - val_accuracy: 0.5000 - val_loss: 1.4880 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7649 - loss: 0.6591 - val_accuracy: 0.4959 - val_loss: 1.5427 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7836 - loss: 0.6164 - val_accuracy: 0.4997 - val_loss: 1.4933 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7964 - loss: 0.5864 - val_accuracy: 0.5115 - val_loss: 1.5061 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8087 - loss: 0.5496 - val_accuracy: 0.5135 - val_loss: 1.4889 - learning_rate: 0.0010
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8294 - loss: 0.4919
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8296 - loss: 0.4915 - val_accuracy: 0.5275 - val_loss: 1.4998 - learning_rate: 0.0010
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8428 - loss: 0.4564 - val_accuracy: 0.5371 - val_loss: 1.3981 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8709 - loss: 0.3856 - val_accuracy: 0.5423 - val_loss: 1.4108 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8988 - loss: 0.3074 - val_accuracy: 0.5335 - val_loss: 1.4694 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9136 - loss: 0.2712 - val_accuracy: 0.5426 - val_loss: 1.4512 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9141 - loss: 0.2622 - val_accuracy: 0.5481 - val_loss: 1.4493 - learning_rate: 5.0000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9217 - loss: 0.2431
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9217 - loss: 0.2428 - val_accuracy: 0.5522 - val_loss: 1.4892 - learning_rate: 5.0000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9233 - loss: 0.2323 - val_accuracy: 0.5473 - val_loss: 1.4953 - learning_rate: 2.5000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9410 - loss: 0.1948 - val_accuracy: 0.5465 - val_loss: 1.5097 - learning_rate: 2.5000e-04
# Epoch 30/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9469 - loss: 0.1725 - val_accuracy: 0.5481 - val_loss: 1.5101 - learning_rate: 2.5000e-04
# Epoch 31/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9525 - loss: 0.1565 - val_accuracy: 0.5531 - val_loss: 1.4920 - learning_rate: 2.5000e-04
# Epoch 32/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9566 - loss: 0.1465
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9567 - loss: 0.1462 - val_accuracy: 0.5531 - val_loss: 1.5335 - learning_rate: 2.5000e-04
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# Running fold: 1
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 11s 137ms/step - accuracy: 0.1962 - loss: 2.8796 - val_accuracy: 0.2477 - val_loss: 2.0679 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2932 - loss: 2.0918 - val_accuracy: 0.2823 - val_loss: 2.0185 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.3674 - loss: 1.8259 - val_accuracy: 0.3208 - val_loss: 1.8445 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.4123 - loss: 1.6659 - val_accuracy: 0.3576 - val_loss: 1.7204 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4539 - loss: 1.5263 - val_accuracy: 0.3881 - val_loss: 1.6717 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.4922 - loss: 1.4089 - val_accuracy: 0.4082 - val_loss: 1.6443 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5299 - loss: 1.3164 - val_accuracy: 0.4024 - val_loss: 1.6676 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5644 - loss: 1.2113 - val_accuracy: 0.4313 - val_loss: 1.5934 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5948 - loss: 1.1333 - val_accuracy: 0.4398 - val_loss: 1.5704 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6229 - loss: 1.0732 - val_accuracy: 0.4516 - val_loss: 1.5799 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6443 - loss: 0.9958 - val_accuracy: 0.4755 - val_loss: 1.5040 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6664 - loss: 0.9229 - val_accuracy: 0.4816 - val_loss: 1.5003 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6789 - loss: 0.8839 - val_accuracy: 0.4830 - val_loss: 1.5168 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7079 - loss: 0.8224 - val_accuracy: 0.5019 - val_loss: 1.4699 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7291 - loss: 0.7711 - val_accuracy: 0.5041 - val_loss: 1.4871 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7449 - loss: 0.7325 - val_accuracy: 0.5115 - val_loss: 1.4568 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7561 - loss: 0.6975 - val_accuracy: 0.4975 - val_loss: 1.5962 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7579 - loss: 0.6860 - val_accuracy: 0.5168 - val_loss: 1.4635 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7732 - loss: 0.6426 - val_accuracy: 0.5300 - val_loss: 1.4268 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7970 - loss: 0.5795 - val_accuracy: 0.5030 - val_loss: 1.5453 - learning_rate: 0.0010
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8245 - loss: 0.5177 - val_accuracy: 0.5209 - val_loss: 1.5149 - learning_rate: 0.0010
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8346 - loss: 0.4842 - val_accuracy: 0.5181 - val_loss: 1.4918 - learning_rate: 0.0010
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8430 - loss: 0.4584 - val_accuracy: 0.5206 - val_loss: 1.5979 - learning_rate: 0.0010
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8627 - loss: 0.4004
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8629 - loss: 0.3998 - val_accuracy: 0.5311 - val_loss: 1.5941 - learning_rate: 0.0010
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8837 - loss: 0.3388 - val_accuracy: 0.5404 - val_loss: 1.5554 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9072 - loss: 0.2859 - val_accuracy: 0.5473 - val_loss: 1.5090 - learning_rate: 5.0000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9270 - loss: 0.2297 - val_accuracy: 0.5467 - val_loss: 1.5159 - learning_rate: 5.0000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9281 - loss: 0.2194 - val_accuracy: 0.5495 - val_loss: 1.5369 - learning_rate: 5.0000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9296 - loss: 0.2090
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9297 - loss: 0.2086 - val_accuracy: 0.5462 - val_loss: 1.6128 - learning_rate: 5.0000e-04
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# Running fold: 2
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.2053 - loss: 2.7122 - val_accuracy: 0.2298 - val_loss: 2.1805 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3175 - loss: 1.9888 - val_accuracy: 0.2675 - val_loss: 1.9737 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3741 - loss: 1.7817 - val_accuracy: 0.3200 - val_loss: 1.8281 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.4352 - loss: 1.5844 - val_accuracy: 0.3804 - val_loss: 1.6972 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4712 - loss: 1.4575 - val_accuracy: 0.4137 - val_loss: 1.6320 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5159 - loss: 1.3307 - val_accuracy: 0.4151 - val_loss: 1.6342 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5527 - loss: 1.2422 - val_accuracy: 0.4401 - val_loss: 1.5277 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.5879 - loss: 1.1214 - val_accuracy: 0.4662 - val_loss: 1.4937 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6088 - loss: 1.0731 - val_accuracy: 0.4428 - val_loss: 1.5469 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6264 - loss: 1.0328 - val_accuracy: 0.4709 - val_loss: 1.5596 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.6529 - loss: 0.9620 - val_accuracy: 0.4846 - val_loss: 1.4804 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.6691 - loss: 0.9215 - val_accuracy: 0.4920 - val_loss: 1.5399 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6870 - loss: 0.8501 - val_accuracy: 0.5049 - val_loss: 1.4882 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7266 - loss: 0.7742 - val_accuracy: 0.5143 - val_loss: 1.4624 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7310 - loss: 0.7539 - val_accuracy: 0.5272 - val_loss: 1.4306 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7487 - loss: 0.7085 - val_accuracy: 0.5267 - val_loss: 1.4080 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7664 - loss: 0.6531 - val_accuracy: 0.5148 - val_loss: 1.5139 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7850 - loss: 0.6181 - val_accuracy: 0.5341 - val_loss: 1.4042 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8048 - loss: 0.5689 - val_accuracy: 0.5327 - val_loss: 1.4372 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7966 - loss: 0.5846 - val_accuracy: 0.5407 - val_loss: 1.4394 - learning_rate: 0.0010
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8177 - loss: 0.5355 - val_accuracy: 0.5349 - val_loss: 1.4358 - learning_rate: 0.0010
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8431 - loss: 0.4575 - val_accuracy: 0.5407 - val_loss: 1.4604 - learning_rate: 0.0010
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8500 - loss: 0.4401
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8504 - loss: 0.4391 - val_accuracy: 0.5459 - val_loss: 1.4354 - learning_rate: 0.0010
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.8691 - loss: 0.3757 - val_accuracy: 0.5533 - val_loss: 1.4006 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.9048 - loss: 0.2849 - val_accuracy: 0.5594 - val_loss: 1.3958 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9204 - loss: 0.2507 - val_accuracy: 0.5742 - val_loss: 1.3743 - learning_rate: 5.0000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9316 - loss: 0.2136 - val_accuracy: 0.5682 - val_loss: 1.4064 - learning_rate: 5.0000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9376 - loss: 0.1907 - val_accuracy: 0.5731 - val_loss: 1.3921 - learning_rate: 5.0000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9373 - loss: 0.1884 - val_accuracy: 0.5682 - val_loss: 1.4290 - learning_rate: 5.0000e-04
# Epoch 30/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9422 - loss: 0.1764 - val_accuracy: 0.5775 - val_loss: 1.4471 - learning_rate: 5.0000e-04
# Epoch 31/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9473 - loss: 0.1661
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9474 - loss: 0.1657 - val_accuracy: 0.5745 - val_loss: 1.4386 - learning_rate: 5.0000e-04
# Epoch 32/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9558 - loss: 0.1422 - val_accuracy: 0.5756 - val_loss: 1.4803 - learning_rate: 2.5000e-04
# Epoch 33/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9690 - loss: 0.1151 - val_accuracy: 0.5728 - val_loss: 1.4605 - learning_rate: 2.5000e-04
# Epoch 34/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9724 - loss: 0.0993 - val_accuracy: 0.5833 - val_loss: 1.4777 - learning_rate: 2.5000e-04
# Epoch 35/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9761 - loss: 0.0879 - val_accuracy: 0.5797 - val_loss: 1.4775 - learning_rate: 2.5000e-04
# Epoch 36/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9764 - loss: 0.0854
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9764 - loss: 0.0852 - val_accuracy: 0.5775 - val_loss: 1.5104 - learning_rate: 2.5000e-04
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# Running fold: 3
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 11s 136ms/step - accuracy: 0.1995 - loss: 2.8741 - val_accuracy: 0.2592 - val_loss: 2.0955 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2955 - loss: 2.0916 - val_accuracy: 0.3054 - val_loss: 1.9954 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.3559 - loss: 1.8448 - val_accuracy: 0.3299 - val_loss: 1.8171 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4244 - loss: 1.6451 - val_accuracy: 0.3433 - val_loss: 1.7487 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.4700 - loss: 1.4792 - val_accuracy: 0.3911 - val_loss: 1.6454 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5076 - loss: 1.3601 - val_accuracy: 0.4016 - val_loss: 1.6060 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5392 - loss: 1.2688 - val_accuracy: 0.4335 - val_loss: 1.5215 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5673 - loss: 1.1968 - val_accuracy: 0.4489 - val_loss: 1.5291 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.5968 - loss: 1.1153 - val_accuracy: 0.4599 - val_loss: 1.5145 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6160 - loss: 1.0584 - val_accuracy: 0.4640 - val_loss: 1.5406 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6292 - loss: 1.0086 - val_accuracy: 0.4750 - val_loss: 1.4736 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.6639 - loss: 0.9451 - val_accuracy: 0.4775 - val_loss: 1.5106 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.6888 - loss: 0.8791 - val_accuracy: 0.5027 - val_loss: 1.4334 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7121 - loss: 0.8286 - val_accuracy: 0.5008 - val_loss: 1.4307 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7427 - loss: 0.7364 - val_accuracy: 0.5236 - val_loss: 1.4020 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7441 - loss: 0.7146 - val_accuracy: 0.5206 - val_loss: 1.4525 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7693 - loss: 0.6478 - val_accuracy: 0.5181 - val_loss: 1.4527 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7943 - loss: 0.5869 - val_accuracy: 0.5269 - val_loss: 1.4957 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8076 - loss: 0.5637 - val_accuracy: 0.5214 - val_loss: 1.5584 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8288 - loss: 0.4992
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.8291 - loss: 0.4986 - val_accuracy: 0.5225 - val_loss: 1.5654 - learning_rate: 0.0010
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8494 - loss: 0.4421 - val_accuracy: 0.5445 - val_loss: 1.4227 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8568 - loss: 0.4107 - val_accuracy: 0.5489 - val_loss: 1.3968 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.8818 - loss: 0.3422 - val_accuracy: 0.5547 - val_loss: 1.3852 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9002 - loss: 0.2959 - val_accuracy: 0.5605 - val_loss: 1.4226 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9137 - loss: 0.2658 - val_accuracy: 0.5547 - val_loss: 1.4531 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9198 - loss: 0.2529 - val_accuracy: 0.5574 - val_loss: 1.4312 - learning_rate: 5.0000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9266 - loss: 0.2292 - val_accuracy: 0.5613 - val_loss: 1.4754 - learning_rate: 5.0000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9263 - loss: 0.2208
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9265 - loss: 0.2203 - val_accuracy: 0.5533 - val_loss: 1.4893 - learning_rate: 5.0000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9310 - loss: 0.1984 - val_accuracy: 0.5577 - val_loss: 1.5072 - learning_rate: 2.5000e-04
# Epoch 30/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9445 - loss: 0.1676 - val_accuracy: 0.5574 - val_loss: 1.5679 - learning_rate: 2.5000e-04
# Epoch 31/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9568 - loss: 0.1442 - val_accuracy: 0.5533 - val_loss: 1.6108 - learning_rate: 2.5000e-04
# Epoch 32/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9638 - loss: 0.1236 - val_accuracy: 0.5511 - val_loss: 1.6168 - learning_rate: 2.5000e-04
# Epoch 33/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9644 - loss: 0.1164
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9646 - loss: 0.1161 - val_accuracy: 0.5547 - val_loss: 1.6403 - learning_rate: 2.5000e-04
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# Running fold: 4
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.2009 - loss: 2.7955 - val_accuracy: 0.2639 - val_loss: 2.1155 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.3011 - loss: 2.0416 - val_accuracy: 0.3059 - val_loss: 2.0245 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.3711 - loss: 1.7850 - val_accuracy: 0.3617 - val_loss: 1.7713 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.4284 - loss: 1.6047 - val_accuracy: 0.3546 - val_loss: 1.7528 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.4715 - loss: 1.4851 - val_accuracy: 0.3892 - val_loss: 1.6655 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.5053 - loss: 1.3818 - val_accuracy: 0.3928 - val_loss: 1.6682 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.5341 - loss: 1.2891 - val_accuracy: 0.4313 - val_loss: 1.5601 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.5721 - loss: 1.1817 - val_accuracy: 0.4491 - val_loss: 1.5209 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6074 - loss: 1.0943 - val_accuracy: 0.4582 - val_loss: 1.5581 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6381 - loss: 1.0204 - val_accuracy: 0.4769 - val_loss: 1.5229 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6487 - loss: 0.9892 - val_accuracy: 0.4772 - val_loss: 1.4957 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.6795 - loss: 0.9103 - val_accuracy: 0.4857 - val_loss: 1.5452 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.6942 - loss: 0.8615 - val_accuracy: 0.4920 - val_loss: 1.4611 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7248 - loss: 0.7859 - val_accuracy: 0.4871 - val_loss: 1.4859 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7484 - loss: 0.7285 - val_accuracy: 0.5047 - val_loss: 1.4753 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - accuracy: 0.7706 - loss: 0.6652 - val_accuracy: 0.5157 - val_loss: 1.3828 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7861 - loss: 0.6047 - val_accuracy: 0.5052 - val_loss: 1.5796 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8033 - loss: 0.5678 - val_accuracy: 0.5225 - val_loss: 1.4571 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.8112 - loss: 0.5457 - val_accuracy: 0.5113 - val_loss: 1.5503 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8300 - loss: 0.4996 - val_accuracy: 0.5181 - val_loss: 1.4995 - learning_rate: 0.0010
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8321 - loss: 0.4833
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.8324 - loss: 0.4826 - val_accuracy: 0.5187 - val_loss: 1.5627 - learning_rate: 0.0010
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.8535 - loss: 0.4407 - val_accuracy: 0.5470 - val_loss: 1.3998 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8889 - loss: 0.3360 - val_accuracy: 0.5473 - val_loss: 1.3926 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9129 - loss: 0.2726 - val_accuracy: 0.5467 - val_loss: 1.4285 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9236 - loss: 0.2393 - val_accuracy: 0.5451 - val_loss: 1.4555 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9348 - loss: 0.2084
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9349 - loss: 0.2082 - val_accuracy: 0.5520 - val_loss: 1.4730 - learning_rate: 5.0000e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Val Acc per fold: [55.31, 54.62, 57.75, 55.47, 55.2]
