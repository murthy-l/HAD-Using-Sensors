# %% [markdown]
# # Detecting Human Activities Through Smartphone Sensor - Training

# %% [markdown]
# ## Imports

# %%
# TF related imports
import tensorflow as tf
from tensorflow.keras.models import Model
import tensorflow.keras.layers as layer
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

#scikit related imports
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import confusion_matrix

# other generic imports
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from mlxtend import plotting
from tqdm import tqdm
from datetime import timedelta
import time
# Out:
# 2024-11-19 17:41:06.506290: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-19 17:41:06.520930: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-19 17:41:06.525402: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-19 17:41:06.536527: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-19 17:41:07.300757: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Global Variables

# %%
# global variables
PBAR_FORMAT='{desc:12} {percentage:3.0f}%|{bar:27}| [ {n:4d}/{total:4d}, {elapsed}<{remaining}{postfix} ]'

ACTIVITY_CODES_MAPPING = {'A': 'walking',
                          'B': 'jogging',
                          'C': 'stairs',
                          'D': 'sitting',
                          'E': 'standing',
                          'F': 'typing',
                          'G': 'brushing teeth',
                          'H': 'eating soup',
                          'I': 'eating chips',
                          'J': 'eating pasta',
                          'K': 'drinking from cup',
                          'L': 'eating sandwich',
                          'M': 'kicking soccer ball',
                          'O': 'playing catch tennis ball',
                          'P': 'dribbling basket ball',
                          'Q': 'writing',
                          'R': 'clapping',
                          'S': 'folding clothes'}
# csv file column names
COL_NAMES =  ['id' , 'activity_code' , 'timestamp', 'x', 'y', 'z']
# training verbose
VERBOSE = 1
# rnadom state for split
RANDOM_STATE=12345

# %% [markdown]
# ## Dataset, Model and Trainer

# %% [markdown]
# ### Helper functions

# %%
def get_activity_code(activity_names):
    cat_len=len(activity_names)
    activity_code={}
    for idx, an in enumerate(activity_names):
        for k in ACTIVITY_CODES_MAPPING.keys() :
            if ACTIVITY_CODES_MAPPING[k]==an:
                key = k
        activity_code[key]=idx
    
    assert(len(activity_code.keys())== cat_len)
    
    print(f"{activity_code}")
    print(f"Number of Categories {cat_len}")
    return activity_code, cat_len

def sliding_window(dataset, window_size, step_size):  
    x_list, y_list, z_list = [], [], []
    targets_list = []
    for i in range(0, dataset.shape[0] - window_size, step_size):
        x_list.append(dataset["x"].values[i: i + window_size])
        y_list.append(dataset["y"].values[i: i + window_size])
        z_list.append(dataset["z"].values[i: i + window_size])
        targets_list.append(stats.mode(dataset["activity_code"][i: i + window_size])[0])

    feature_list = [x_list, y_list, z_list]

    feature_list = [np.array(data_list) for data_list in feature_list]
    dataset = np.stack(feature_list, axis = 2)

    return dataset, targets_list

# %% [markdown]
# ### Dataset

# %%
def WISDM_Dataset(dir, window_size, step_size, activity_code):
    window_size = window_size
    step_size = step_size
    path = dir
    column_names = COL_NAMES
    activity_dic = activity_code
    filelist_train = sorted([txt for txt in os.listdir(path + "/") if txt[-4:] == ".txt"])
    columns = ["x", "y", "z"]
        
    # Training data
    dataset_train = pd.DataFrame()

    for txt in tqdm(filelist_train, desc="loading data", bar_format=PBAR_FORMAT):
        dataset_tmp = pd.read_csv(path + '/' + txt, header = None, names = column_names, comment = ";")
        for k in activity_dic.keys():
            df_tmp = dataset_tmp[dataset_tmp['activity_code']==k][0:2400]
            dataset_train = pd.concat([dataset_train, df_tmp])
    print(dataset_train)

    # normalize the data
    dataset_train["activity_code"] = dataset_train["activity_code"].map(activity_dic)
    labels = dataset_train["activity_code"].to_numpy()

    scaler = RobustScaler()
    dataset_train = scaler.fit_transform(dataset_train[["x", "y", "z"]])
    dataset_train = pd.DataFrame(data = dataset_train, columns = ["x", "y", "z"])
    dataset_train["activity_code"] = labels
    
    # feature engineering
    dataset_train, targets_list = sliding_window(dataset_train, window_size, step_size)
    targets = np.array(targets_list)
    return dataset_train, targets

# %% [markdown]
# ### Model

# %%
def gru_net(data, num_classes):
    x_input = layer.Input(shape = (data.shape[-2:]))
    x = layer.Bidirectional(layer.GRU(512, return_sequences = True))(x_input)
    x = layer.BatchNormalization()(x)
    x = layer.Bidirectional(layer.GRU(256, return_sequences = True))(x)
    x = layer.BatchNormalization()(x)
    x = layer.Bidirectional(layer.GRU(128, return_sequences = True))(x)
    x = layer.BatchNormalization()(x)

    x = layer.Flatten()(x)

    x = layer.Dense(128, activation = "relu")(x)
    x = layer.BatchNormalization()(x)
    x = layer.Dropout(0.5)(x)
    x_output = layer.Dense(num_classes, activation = "softmax")(x)

    model = Model(inputs = x_input, outputs = x_output, name = "GRU_NET")

    return model

# %% [markdown]
# ### Plotting function

# %%
def plot_loss_acc(epochs, train_losses, train_acc, test_losses, test_acc, fold):
    fig, ax1 = plt.subplots()
    xaxis = list(range(1, epochs + 1))
    plt_train_loss = ax1.plot(xaxis, train_losses, label = "Training Loss", color="red")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2 = ax1.twinx()
    plt_train_acc = ax2.plot(xaxis, train_acc, label = "Training Accuracy", color="green")
    ax2.set_ylabel("Accuracy in %")
    ax2.set_ylim(0.0, 100.0)

    plt_val_loss = ax1.plot(xaxis, test_losses, label = "Validation Loss", color="firebrick")
    plt_val_acc = ax2.plot(xaxis, test_acc, label = "Validation Accuracy", color="limegreen")

    lines = plt_train_loss + plt_train_acc + plt_val_loss + plt_val_acc
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels)
    fold = " Fold " + str(fold) 
    plt.title("Loss and Accuracy" + fold)
    plt.show()

def plot_confusion_matrix(y_pred, y_valid, fold):
    conf_matrix = confusion_matrix(y_valid, y_pred)
    plotting.plot_confusion_matrix(conf_mat = conf_matrix,
                                   class_names = ACTIVITY_NAMES,
                                   show_normed = True,
                                   figsize = (10, 7),
                                   colorbar = True)
    plt.title("Confusion matrix Fold " + str(fold))
    plt.show()

# %% [markdown]
# ### Trainer function

# %%
def train(data_dir, num_splits, window_size, step_size, activity_names, batch_size, num_epochs):
    options = tf.data.Options()
    options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.OFF
    activity_code, cat_len = get_activity_code(activity_names)
    # Dataset
    train, targets = WISDM_Dataset(dir = data_dir,
                                  window_size = window_size,
                                  step_size = step_size,
                                  activity_code = activity_code)
      
    k_fold = KFold(n_splits = num_splits,
                   shuffle = True,
                   random_state = RANDOM_STATE)
    val_acc_last = []
    
    model = gru_net(train, cat_len)
    print(model.summary())
    start_time = time.time()
    for fold, (train_index, test_index) in enumerate(k_fold.split(train, targets)):
        print(f"Running fold: {fold}")
        x_train, x_valid = train[train_index], train[test_index]
        y_train, y_valid = targets[train_index], targets[test_index]
        
        # convert to tf dataset
        train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size).with_options(options)
        valid_data = tf.data.Dataset.from_tensor_slices((x_valid, y_valid)).batch(batch_size).with_options(options)
        
        model = gru_net(train, cat_len)
        
        model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
        
        learning_rate = ReduceLROnPlateau(monitor = "val_loss", factor = 0.5, patience = 5, verbose = VERBOSE)
        early_stopping = EarlyStopping(monitor = "val_loss", patience = 10, verbose = VERBOSE, mode = "min", 
                                       restore_best_weights = True)
        
        # model training
        history = model.fit(train_data, 
                            validation_data = valid_data, 
                            epochs = num_epochs,
                            verbose = VERBOSE,    # for debugging VERBOSE
                            batch_size = BATCH_SIZE, 
                            callbacks = [learning_rate, early_stopping])
        
        # Plot loss and accuracy curves
        plot_loss_acc(len(history.history["loss"]), history.history["loss"], 
                                  [acc * 100.0 for acc in history.history["accuracy"]], 
                                  history.history["val_loss"], 
                                  [acc * 100.0 for acc in history.history["val_accuracy"]], str(fold))
        
        val_acc_last.append(np.around(100.0 * history.history["val_accuracy"][-1], 2))    # safe last validation accuracy
        
        # Plot confusion matrix
        y_pred = np.argmax(model.predict(valid_data, batch_size = BATCH_SIZE), axis = 1)
        print("\n")
        plot_confusion_matrix(y_pred, y_valid, fold) 
        print(f'Time elapsed: {timedelta(microseconds=int((time.time()-start_time)*1000000))}')

    print(f'Total Training Time: {timedelta(seconds=int(time.time()-start_time))}')
    print("Val Acc per fold:", val_acc_last)

# %% [markdown]
# ## Training on phone accelerometer

# %%
##################################################################
#Hyperparameter
##################################################################
#ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "kicking soccer ball"]
ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "typing", "brushing teeth",
                  "eating soup", "drinking from cup", 
                  "kicking soccer ball", "playing catch tennis ball", "dribbling basket ball", 
                  "writing", "clapping", "folding clothes"]
NUM_EPOCHS  = 90
BATCH_SIZE = 256
WINDOW_SIZE=200
STEP_SIZE=100
NUM_SPLITS=5
DATA_DIR="../dataset/raw/phone/accel"

##################################################################
#Training
##################################################################
train(data_dir=DATA_DIR,
      num_splits=NUM_SPLITS,
      window_size=WINDOW_SIZE,
      step_size=STEP_SIZE,
      activity_names=ACTIVITY_NAMES,
      batch_size=BATCH_SIZE,
      num_epochs=NUM_EPOCHS)
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'K': 8, 'M': 9, 'O': 10, 'P': 11, 'Q': 12, 'R': 13, 'S': 14}
# Number of Categories 15
# loading data 100%|███████████████████████████| [   51/  51, 00:15<00:00 ]
#           id activity_code        timestamp         x          y         z
# 0       1600             A  252207666810782 -0.364761   8.793503  1.055084
# 1       1600             A  252207717164786 -0.879730   9.768784  1.016998
# 2       1600             A  252207767518790  2.001495  11.109070  2.619156
# 3       1600             A  252207817872794  0.450623  12.651642  0.184555
# 4       1600             A  252207868226798 -2.164352  13.928436 -4.422485
# ...      ...           ...              ...       ...        ...       ...
# 154242  1650             S  357602446012000 -8.763377  -3.745811 -2.277664
# 154243  1650             S  357602466108000 -8.895103  -3.717071 -2.919529
# 154244  1650             S  357602486288000 -8.631651  -3.836822 -3.475173
# 154245  1650             S  357602506384000 -8.270002  -4.102669 -2.859653
# 154246  1650             S  357602526598000 -8.183782  -4.315825 -1.733994
#
# [1821600 rows x 6 columns]
# 2024-11-19 17:41:33.577698: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6634 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:65:00.0, compute capability: 7.5
# Model: "GRU_NET"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 200, 1024)      │     1,588,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200, 1024)      │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 200, 512)       │     1,969,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 200, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 200, 256)       │       493,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 200, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     6,553,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │         1,935 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,613,775 (40.49 MB)
#  Trainable params: 10,609,935 (40.47 MB)
#  Non-trainable params: 3,840 (15.00 KB)
# None
# Running fold: 0
# Epoch 1/90
# 2024-11-19 17:41:39.487588: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 26s 354ms/step - accuracy: 0.0899 - loss: 3.9945 - val_accuracy: 0.0749 - val_loss: 3.0284 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 354ms/step - accuracy: 0.1225 - loss: 3.1371 - val_accuracy: 0.0686 - val_loss: 3.1146 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 355ms/step - accuracy: 0.1708 - loss: 2.6650 - val_accuracy: 0.0653 - val_loss: 4.0264 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 357ms/step - accuracy: 0.1988 - loss: 2.5162 - val_accuracy: 0.0684 - val_loss: 3.5039 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 357ms/step - accuracy: 0.2375 - loss: 2.2612 - val_accuracy: 0.1010 - val_loss: 3.0406 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.2559 - loss: 2.1233 - val_accuracy: 0.1458 - val_loss: 2.4885 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.2851 - loss: 2.0014 - val_accuracy: 0.1507 - val_loss: 2.3570 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 358ms/step - accuracy: 0.3000 - loss: 1.9147 - val_accuracy: 0.1537 - val_loss: 2.5195 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 358ms/step - accuracy: 0.2691 - loss: 2.0216 - val_accuracy: 0.1691 - val_loss: 2.4729 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.2842 - loss: 1.9690 - val_accuracy: 0.2064 - val_loss: 2.4177 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.2716 - loss: 2.0488 - val_accuracy: 0.2116 - val_loss: 2.1423 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.3149 - loss: 1.8520 - val_accuracy: 0.2904 - val_loss: 2.0935 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.3468 - loss: 1.7560 - val_accuracy: 0.2740 - val_loss: 2.0395 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 360ms/step - accuracy: 0.3900 - loss: 1.6535 - val_accuracy: 0.2989 - val_loss: 1.9453 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.4100 - loss: 1.6083 - val_accuracy: 0.2808 - val_loss: 2.1400 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.4227 - loss: 1.5605 - val_accuracy: 0.2844 - val_loss: 2.1906 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.4462 - loss: 1.5139 - val_accuracy: 0.3033 - val_loss: 2.1219 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.4776 - loss: 1.4336 - val_accuracy: 0.3225 - val_loss: 2.0161 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5113 - loss: 1.3535
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 360ms/step - accuracy: 0.5110 - loss: 1.3542 - val_accuracy: 0.3382 - val_loss: 2.0954 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.5558 - loss: 1.2445 - val_accuracy: 0.3179 - val_loss: 2.0779 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 360ms/step - accuracy: 0.5976 - loss: 1.1371 - val_accuracy: 0.3231 - val_loss: 2.0690 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 360ms/step - accuracy: 0.6527 - loss: 1.0229 - val_accuracy: 0.3324 - val_loss: 2.0578 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.6835 - loss: 0.9160 - val_accuracy: 0.3214 - val_loss: 2.1071 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7166 - loss: 0.8491
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.7161 - loss: 0.8502 - val_accuracy: 0.3275 - val_loss: 2.1593 - learning_rate: 5.0000e-04
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step
# Time elapsed: 0:08:19.351561
# Running fold: 1
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 24s 363ms/step - accuracy: 0.0952 - loss: 4.0413 - val_accuracy: 0.0796 - val_loss: 3.1823 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.1298 - loss: 3.0546 - val_accuracy: 0.0917 - val_loss: 2.9473 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.1716 - loss: 2.7103 - val_accuracy: 0.1123 - val_loss: 2.9570 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.2039 - loss: 2.4807 - val_accuracy: 0.1131 - val_loss: 2.9092 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.2223 - loss: 2.3849 - val_accuracy: 0.1222 - val_loss: 2.8770 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.2345 - loss: 2.2643 - val_accuracy: 0.1408 - val_loss: 2.7553 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.2567 - loss: 2.1600 - val_accuracy: 0.1578 - val_loss: 2.4896 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.3050 - loss: 1.9628 - val_accuracy: 0.2163 - val_loss: 2.1843 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.3237 - loss: 1.8824 - val_accuracy: 0.2281 - val_loss: 2.1251 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.3532 - loss: 1.8199 - val_accuracy: 0.2416 - val_loss: 2.0509 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.3550 - loss: 1.8095 - val_accuracy: 0.2267 - val_loss: 2.1852 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.3434 - loss: 1.8244 - val_accuracy: 0.2558 - val_loss: 2.0887 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.3758 - loss: 1.7070 - val_accuracy: 0.2385 - val_loss: 2.1825 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.3993 - loss: 1.6547 - val_accuracy: 0.2663 - val_loss: 2.0232 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.4381 - loss: 1.5293 - val_accuracy: 0.2866 - val_loss: 2.0291 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.4866 - loss: 1.4231 - val_accuracy: 0.2610 - val_loss: 2.1299 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.4943 - loss: 1.3780 - val_accuracy: 0.2320 - val_loss: 2.4940 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.4780 - loss: 1.4388 - val_accuracy: 0.2531 - val_loss: 2.2407 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.4860 - loss: 1.4077
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.4859 - loss: 1.4080 - val_accuracy: 0.2921 - val_loss: 2.2114 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 364ms/step - accuracy: 0.5470 - loss: 1.2700 - val_accuracy: 0.2978 - val_loss: 2.0147 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6252 - loss: 1.0664 - val_accuracy: 0.3253 - val_loss: 1.9891 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.6741 - loss: 0.9542 - val_accuracy: 0.3179 - val_loss: 2.0973 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7139 - loss: 0.8576 - val_accuracy: 0.3231 - val_loss: 2.2027 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7407 - loss: 0.7776 - val_accuracy: 0.3231 - val_loss: 2.1994 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7748 - loss: 0.6969 - val_accuracy: 0.3006 - val_loss: 2.3115 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7668 - loss: 0.6952
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 360ms/step - accuracy: 0.7668 - loss: 0.6953 - val_accuracy: 0.3239 - val_loss: 2.3094 - learning_rate: 5.0000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.8078 - loss: 0.6003 - val_accuracy: 0.3022 - val_loss: 2.4240 - learning_rate: 2.5000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.8405 - loss: 0.5208 - val_accuracy: 0.3179 - val_loss: 2.4326 - learning_rate: 2.5000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.8790 - loss: 0.4254 - val_accuracy: 0.3212 - val_loss: 2.4031 - learning_rate: 2.5000e-04
# Epoch 30/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9014 - loss: 0.3626 - val_accuracy: 0.3132 - val_loss: 2.4599 - learning_rate: 2.5000e-04
# Epoch 31/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9065 - loss: 0.3368
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9063 - loss: 0.3372 - val_accuracy: 0.3256 - val_loss: 2.5271 - learning_rate: 2.5000e-04
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step
# Time elapsed: 0:19:05.016941
# Running fold: 2
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 24s 364ms/step - accuracy: 0.1103 - loss: 3.9021 - val_accuracy: 0.0769 - val_loss: 3.0214 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.1189 - loss: 3.1094 - val_accuracy: 0.0845 - val_loss: 2.8786 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.1569 - loss: 2.8004 - val_accuracy: 0.0659 - val_loss: 2.9684 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.1847 - loss: 2.6255 - val_accuracy: 0.1123 - val_loss: 3.0676 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.2135 - loss: 2.4336 - val_accuracy: 0.1340 - val_loss: 2.9398 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.2372 - loss: 2.2702 - val_accuracy: 0.1504 - val_loss: 2.7319 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.2774 - loss: 2.0854 - val_accuracy: 0.1718 - val_loss: 2.5270 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.3023 - loss: 1.9768 - val_accuracy: 0.1908 - val_loss: 2.2962 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.3261 - loss: 1.8739 - val_accuracy: 0.2191 - val_loss: 2.2905 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.3277 - loss: 1.8536 - val_accuracy: 0.2512 - val_loss: 2.0970 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.3613 - loss: 1.7752 - val_accuracy: 0.2589 - val_loss: 2.1227 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.3854 - loss: 1.6770 - val_accuracy: 0.2973 - val_loss: 2.0066 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.4182 - loss: 1.5864 - val_accuracy: 0.2948 - val_loss: 2.0145 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.4290 - loss: 1.5561 - val_accuracy: 0.2910 - val_loss: 2.0674 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.4475 - loss: 1.5299 - val_accuracy: 0.2811 - val_loss: 2.1148 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.4584 - loss: 1.4809 - val_accuracy: 0.2956 - val_loss: 1.9843 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.4831 - loss: 1.4147 - val_accuracy: 0.2833 - val_loss: 2.1107 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.4920 - loss: 1.3615 - val_accuracy: 0.3201 - val_loss: 1.9800 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.5565 - loss: 1.2241 - val_accuracy: 0.3181 - val_loss: 2.0320 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.5747 - loss: 1.1532 - val_accuracy: 0.3151 - val_loss: 2.0494 - learning_rate: 0.0010
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.5878 - loss: 1.1179 - val_accuracy: 0.3058 - val_loss: 2.0942 - learning_rate: 0.0010
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.6147 - loss: 1.0829 - val_accuracy: 0.3028 - val_loss: 2.1775 - learning_rate: 0.0010
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.6423 - loss: 0.9971
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6421 - loss: 0.9977 - val_accuracy: 0.3365 - val_loss: 2.1344 - learning_rate: 0.0010
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.6643 - loss: 0.9366 - val_accuracy: 0.3374 - val_loss: 2.1387 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.7390 - loss: 0.7775 - val_accuracy: 0.3566 - val_loss: 2.0993 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7730 - loss: 0.6724 - val_accuracy: 0.3409 - val_loss: 2.1220 - learning_rate: 5.0000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7978 - loss: 0.6178 - val_accuracy: 0.3555 - val_loss: 2.1640 - learning_rate: 5.0000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8199 - loss: 0.5621
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.8199 - loss: 0.5621 - val_accuracy: 0.3332 - val_loss: 2.2978 - learning_rate: 5.0000e-04
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step
# Time elapsed: 0:28:48.186224
# Running fold: 3
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 24s 363ms/step - accuracy: 0.1046 - loss: 3.8318 - val_accuracy: 0.0925 - val_loss: 2.9253 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.1344 - loss: 3.0835 - val_accuracy: 0.1095 - val_loss: 2.6693 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.1656 - loss: 2.8303 - val_accuracy: 0.1260 - val_loss: 2.5091 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.1611 - loss: 2.7795 - val_accuracy: 0.0843 - val_loss: 3.3225 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.1797 - loss: 2.6517 - val_accuracy: 0.0996 - val_loss: 2.7771 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.1967 - loss: 2.5443 - val_accuracy: 0.1405 - val_loss: 2.7688 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.2163 - loss: 2.4134 - val_accuracy: 0.1828 - val_loss: 2.4446 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.2648 - loss: 2.1451 - val_accuracy: 0.2111 - val_loss: 2.2480 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.2885 - loss: 2.0333 - val_accuracy: 0.2314 - val_loss: 2.1170 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 364ms/step - accuracy: 0.3345 - loss: 1.8797 - val_accuracy: 0.2682 - val_loss: 2.0274 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.3671 - loss: 1.7711 - val_accuracy: 0.3036 - val_loss: 1.9375 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.3855 - loss: 1.7044 - val_accuracy: 0.2987 - val_loss: 1.9102 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.4146 - loss: 1.6474 - val_accuracy: 0.3190 - val_loss: 1.9096 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.4237 - loss: 1.6132 - val_accuracy: 0.3129 - val_loss: 1.9096 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.4460 - loss: 1.5674 - val_accuracy: 0.3228 - val_loss: 1.9265 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.4700 - loss: 1.4530 - val_accuracy: 0.3324 - val_loss: 1.8857 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.4873 - loss: 1.3924 - val_accuracy: 0.3096 - val_loss: 1.9444 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.4972 - loss: 1.3600 - val_accuracy: 0.3409 - val_loss: 1.9158 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.5540 - loss: 1.2437 - val_accuracy: 0.3615 - val_loss: 1.8325 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.5711 - loss: 1.1835 - val_accuracy: 0.3374 - val_loss: 1.9994 - learning_rate: 0.0010
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.6037 - loss: 1.1130 - val_accuracy: 0.3522 - val_loss: 2.0920 - learning_rate: 0.0010
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6169 - loss: 1.0718 - val_accuracy: 0.3478 - val_loss: 1.9680 - learning_rate: 0.0010
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6326 - loss: 1.0199 - val_accuracy: 0.3121 - val_loss: 2.2431 - learning_rate: 0.0010
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.6312 - loss: 1.0363
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.6310 - loss: 1.0369 - val_accuracy: 0.3280 - val_loss: 2.2391 - learning_rate: 0.0010
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6688 - loss: 0.9556 - val_accuracy: 0.3571 - val_loss: 2.0410 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7193 - loss: 0.8080 - val_accuracy: 0.3437 - val_loss: 2.0650 - learning_rate: 5.0000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7566 - loss: 0.7072 - val_accuracy: 0.3310 - val_loss: 2.2387 - learning_rate: 5.0000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7676 - loss: 0.6744 - val_accuracy: 0.3390 - val_loss: 2.2437 - learning_rate: 5.0000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7949 - loss: 0.6056
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7948 - loss: 0.6060 - val_accuracy: 0.3585 - val_loss: 2.2673 - learning_rate: 5.0000e-04
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step
# Time elapsed: 0:38:52.570389
# Running fold: 4
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 24s 364ms/step - accuracy: 0.1110 - loss: 3.7539 - val_accuracy: 0.0994 - val_loss: 3.0359 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.1291 - loss: 3.0694 - val_accuracy: 0.0829 - val_loss: 3.0147 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.1664 - loss: 2.7306 - val_accuracy: 0.1301 - val_loss: 2.8929 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.2083 - loss: 2.4926 - val_accuracy: 0.1013 - val_loss: 3.0885 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.2433 - loss: 2.3054 - val_accuracy: 0.0969 - val_loss: 2.7993 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.2690 - loss: 2.1603 - val_accuracy: 0.1321 - val_loss: 2.7489 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.2812 - loss: 2.1051 - val_accuracy: 0.1521 - val_loss: 2.5360 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.3043 - loss: 1.9756 - val_accuracy: 0.2018 - val_loss: 2.2430 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.3411 - loss: 1.8535 - val_accuracy: 0.2512 - val_loss: 2.0660 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.3864 - loss: 1.7052 - val_accuracy: 0.2677 - val_loss: 2.0270 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.3925 - loss: 1.6738 - val_accuracy: 0.2891 - val_loss: 2.0195 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.4221 - loss: 1.6006 - val_accuracy: 0.2960 - val_loss: 1.9888 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.4259 - loss: 1.5823 - val_accuracy: 0.3026 - val_loss: 1.9705 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.4565 - loss: 1.4978 - val_accuracy: 0.3040 - val_loss: 2.0045 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.4593 - loss: 1.4655 - val_accuracy: 0.3122 - val_loss: 2.0213 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.4928 - loss: 1.3906 - val_accuracy: 0.2968 - val_loss: 2.1739 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.5283 - loss: 1.3175 - val_accuracy: 0.3196 - val_loss: 2.1516 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.5453 - loss: 1.2496
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.5450 - loss: 1.2505 - val_accuracy: 0.3114 - val_loss: 2.2913 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.5613 - loss: 1.1968 - val_accuracy: 0.3523 - val_loss: 2.0896 - learning_rate: 5.0000e-04
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6168 - loss: 1.0823 - val_accuracy: 0.3594 - val_loss: 1.8750 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.6742 - loss: 0.9451 - val_accuracy: 0.3526 - val_loss: 1.9836 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7097 - loss: 0.8677 - val_accuracy: 0.3347 - val_loss: 2.0496 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7347 - loss: 0.7962 - val_accuracy: 0.3490 - val_loss: 2.0603 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7577 - loss: 0.7208 - val_accuracy: 0.3418 - val_loss: 2.1613 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7765 - loss: 0.6820
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7763 - loss: 0.6823 - val_accuracy: 0.3229 - val_loss: 2.3189 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.8012 - loss: 0.6245 - val_accuracy: 0.3347 - val_loss: 2.3044 - learning_rate: 2.5000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.8306 - loss: 0.5437 - val_accuracy: 0.3364 - val_loss: 2.2874 - learning_rate: 2.5000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.8637 - loss: 0.4599 - val_accuracy: 0.3306 - val_loss: 2.2653 - learning_rate: 2.5000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.8939 - loss: 0.3936 - val_accuracy: 0.3295 - val_loss: 2.2498 - learning_rate: 2.5000e-04
# Epoch 30/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9119 - loss: 0.3441
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9117 - loss: 0.3444 - val_accuracy: 0.3402 - val_loss: 2.2801 - learning_rate: 2.5000e-04
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 20.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step
# Time elapsed: 0:49:17.292238
# Total Training Time: 0:49:17
# Val Acc per fold: [32.75, 32.56, 33.32, 35.85, 34.02]

# %% [markdown]
# ## Training on phone gyroscope sensor

# %%
##################################################################
#Hyperparameter
##################################################################
#ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "kicking soccer ball"]
ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "typing", "brushing teeth",
                  "eating soup", "drinking from cup", 
                  "kicking soccer ball", "playing catch tennis ball", "dribbling basket ball", 
                  "writing", "clapping", "folding clothes"]
NUM_EPOCHS = 90
BATCH_SIZE = 256
WINDOW_SIZE=200
STEP_SIZE=100
NUM_SPLITS=5
DATA_DIR="../dataset/raw/phone/gyro"

##################################################################
#Training
##################################################################
train(data_dir=DATA_DIR,
      num_splits=NUM_SPLITS,
      window_size=WINDOW_SIZE,
      step_size=STEP_SIZE,
      activity_names=ACTIVITY_NAMES,
      batch_size=BATCH_SIZE,
      num_epochs=NUM_EPOCHS)
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'K': 8, 'M': 9, 'O': 10, 'P': 11, 'Q': 12, 'R': 13, 'S': 14}
# Number of Categories 15
# loading data 100%|███████████████████████████| [   51/  51, 00:12<00:00 ]
#          id activity_code        timestamp         x         y         z
# 0      1600             A  252207918580802 -0.853210  0.297226  0.890182
# 1      1600             A  252207968934806 -0.875137  0.015472  0.162231
# 2      1600             A  252208019288809 -0.720169  0.388489 -0.284012
# 3      1600             A  252208069642813 -0.571640  1.227402 -0.241669
# 4      1600             A  252208119996817 -0.380493  1.202835 -0.213135
# ...     ...           ...              ...       ...       ...       ...
# 78280  1650             S  357650830694000  0.687096  0.087352  0.167247
# 78281  1650             S  357650870975000  0.417584 -0.095874  0.056459
# 78282  1650             S  357650911282000  0.096939 -0.083091 -0.028762
# 78283  1650             S  357650951562000 -0.242880 -0.164051 -0.102265
# 78284  1650             S  357650992561000 -0.543285 -0.302535 -0.196009
#
# [1819200 rows x 6 columns]
# Model: "GRU_NET"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_18                │ (None, 200, 1024)      │     1,588,224 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 200, 1024)      │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_19                │ (None, 200, 512)       │     1,969,152 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 200, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_20                │ (None, 200, 256)       │       493,056 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 200, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │     6,553,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 15)             │         1,935 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,613,775 (40.49 MB)
#  Trainable params: 10,609,935 (40.47 MB)
#  Non-trainable params: 3,840 (15.00 KB)
# None
# Running fold: 0
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 24s 359ms/step - accuracy: 0.1869 - loss: 2.8450 - val_accuracy: 0.2089 - val_loss: 2.2658 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - accuracy: 0.2672 - loss: 2.1066 - val_accuracy: 0.2980 - val_loss: 2.0454 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.3394 - loss: 1.8816 - val_accuracy: 0.3018 - val_loss: 1.8957 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 360ms/step - accuracy: 0.4010 - loss: 1.6849 - val_accuracy: 0.3408 - val_loss: 1.9230 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.4539 - loss: 1.5443 - val_accuracy: 0.3933 - val_loss: 1.6843 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.5013 - loss: 1.3937 - val_accuracy: 0.4178 - val_loss: 1.6502 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.5504 - loss: 1.2633 - val_accuracy: 0.4412 - val_loss: 1.6031 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.5784 - loss: 1.1651 - val_accuracy: 0.4673 - val_loss: 1.4742 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.6293 - loss: 1.0322 - val_accuracy: 0.4706 - val_loss: 1.4995 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.6583 - loss: 0.9411 - val_accuracy: 0.4918 - val_loss: 1.4451 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6805 - loss: 0.9024 - val_accuracy: 0.5027 - val_loss: 1.4284 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7230 - loss: 0.7899 - val_accuracy: 0.5036 - val_loss: 1.4802 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.7290 - loss: 0.7488 - val_accuracy: 0.5223 - val_loss: 1.3578 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7491 - loss: 0.6930 - val_accuracy: 0.5379 - val_loss: 1.3235 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.7814 - loss: 0.6250 - val_accuracy: 0.5148 - val_loss: 1.4636 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7771 - loss: 0.6291 - val_accuracy: 0.5291 - val_loss: 1.4209 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.8004 - loss: 0.5656 - val_accuracy: 0.5423 - val_loss: 1.3403 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.8248 - loss: 0.5180 - val_accuracy: 0.5374 - val_loss: 1.4756 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8415 - loss: 0.4767
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.8417 - loss: 0.4761 - val_accuracy: 0.5624 - val_loss: 1.3741 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 364ms/step - accuracy: 0.8621 - loss: 0.4020 - val_accuracy: 0.5426 - val_loss: 1.4657 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.8861 - loss: 0.3519 - val_accuracy: 0.5522 - val_loss: 1.4503 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.9119 - loss: 0.2787 - val_accuracy: 0.5676 - val_loss: 1.3973 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9286 - loss: 0.2348 - val_accuracy: 0.5679 - val_loss: 1.4085 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9477 - loss: 0.1834
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.9478 - loss: 0.1831 - val_accuracy: 0.5827 - val_loss: 1.3794 - learning_rate: 5.0000e-04
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step
# Time elapsed: 0:08:21.766978
# Running fold: 1
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 24s 367ms/step - accuracy: 0.1879 - loss: 2.8241 - val_accuracy: 0.2185 - val_loss: 2.2333 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.2759 - loss: 2.1102 - val_accuracy: 0.2889 - val_loss: 1.9502 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 364ms/step - accuracy: 0.3417 - loss: 1.8642 - val_accuracy: 0.3087 - val_loss: 1.8967 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 364ms/step - accuracy: 0.3974 - loss: 1.7090 - val_accuracy: 0.3810 - val_loss: 1.7443 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.4524 - loss: 1.5332 - val_accuracy: 0.4032 - val_loss: 1.6601 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 364ms/step - accuracy: 0.4859 - loss: 1.4400 - val_accuracy: 0.4206 - val_loss: 1.6126 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.5217 - loss: 1.3249 - val_accuracy: 0.4692 - val_loss: 1.5183 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 365ms/step - accuracy: 0.5708 - loss: 1.1894 - val_accuracy: 0.4665 - val_loss: 1.4825 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 364ms/step - accuracy: 0.6039 - loss: 1.0860 - val_accuracy: 0.4769 - val_loss: 1.4883 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.6356 - loss: 1.0009 - val_accuracy: 0.4830 - val_loss: 1.5067 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.6792 - loss: 0.9162 - val_accuracy: 0.5239 - val_loss: 1.4184 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.7038 - loss: 0.8276 - val_accuracy: 0.5181 - val_loss: 1.3963 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.7153 - loss: 0.7866 - val_accuracy: 0.5429 - val_loss: 1.2899 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.7394 - loss: 0.7314 - val_accuracy: 0.5030 - val_loss: 1.4589 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7530 - loss: 0.6944 - val_accuracy: 0.5322 - val_loss: 1.4126 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.7829 - loss: 0.6228 - val_accuracy: 0.5264 - val_loss: 1.4222 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7943 - loss: 0.5904 - val_accuracy: 0.5434 - val_loss: 1.4004 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8175 - loss: 0.5189
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.8177 - loss: 0.5184 - val_accuracy: 0.5495 - val_loss: 1.4325 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 364ms/step - accuracy: 0.8509 - loss: 0.4506 - val_accuracy: 0.5671 - val_loss: 1.3875 - learning_rate: 5.0000e-04
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.8690 - loss: 0.4036 - val_accuracy: 0.5764 - val_loss: 1.3466 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.8947 - loss: 0.3285 - val_accuracy: 0.5756 - val_loss: 1.3615 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9081 - loss: 0.2902 - val_accuracy: 0.5731 - val_loss: 1.3536 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9277 - loss: 0.2432
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.9277 - loss: 0.2430 - val_accuracy: 0.5750 - val_loss: 1.4176 - learning_rate: 5.0000e-04
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step
# Time elapsed: 0:16:24.187739
# Running fold: 2
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 24s 363ms/step - accuracy: 0.1788 - loss: 2.8491 - val_accuracy: 0.2279 - val_loss: 2.2444 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.2789 - loss: 2.1055 - val_accuracy: 0.3073 - val_loss: 1.9585 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.3498 - loss: 1.8635 - val_accuracy: 0.3304 - val_loss: 1.8251 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.4091 - loss: 1.6821 - val_accuracy: 0.3873 - val_loss: 1.7098 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 364ms/step - accuracy: 0.4636 - loss: 1.5168 - val_accuracy: 0.3678 - val_loss: 1.7906 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.4993 - loss: 1.3910 - val_accuracy: 0.4098 - val_loss: 1.6738 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.5380 - loss: 1.2934 - val_accuracy: 0.4667 - val_loss: 1.5125 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.5876 - loss: 1.1429 - val_accuracy: 0.4739 - val_loss: 1.5669 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6104 - loss: 1.0791 - val_accuracy: 0.4860 - val_loss: 1.4598 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6627 - loss: 0.9517 - val_accuracy: 0.5168 - val_loss: 1.3865 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.6947 - loss: 0.8576 - val_accuracy: 0.5280 - val_loss: 1.3654 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7284 - loss: 0.7793 - val_accuracy: 0.5184 - val_loss: 1.4447 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7352 - loss: 0.7557 - val_accuracy: 0.5176 - val_loss: 1.4918 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7365 - loss: 0.7395 - val_accuracy: 0.5349 - val_loss: 1.4504 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7498 - loss: 0.7067 - val_accuracy: 0.4989 - val_loss: 1.5837 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7928 - loss: 0.6034
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.7931 - loss: 0.6027 - val_accuracy: 0.5377 - val_loss: 1.4534 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.8250 - loss: 0.5103 - val_accuracy: 0.5588 - val_loss: 1.4253 - learning_rate: 5.0000e-04
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.8490 - loss: 0.4563 - val_accuracy: 0.5712 - val_loss: 1.2718 - learning_rate: 5.0000e-04
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.8800 - loss: 0.3832 - val_accuracy: 0.5814 - val_loss: 1.3389 - learning_rate: 5.0000e-04
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.8886 - loss: 0.3440 - val_accuracy: 0.5720 - val_loss: 1.3675 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9035 - loss: 0.3043 - val_accuracy: 0.5904 - val_loss: 1.3259 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9188 - loss: 0.2651 - val_accuracy: 0.5833 - val_loss: 1.3783 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9296 - loss: 0.2362
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9297 - loss: 0.2359 - val_accuracy: 0.5745 - val_loss: 1.4455 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9292 - loss: 0.2223 - val_accuracy: 0.5998 - val_loss: 1.3460 - learning_rate: 2.5000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9622 - loss: 0.1511 - val_accuracy: 0.5995 - val_loss: 1.2849 - learning_rate: 2.5000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9687 - loss: 0.1254 - val_accuracy: 0.6023 - val_loss: 1.2792 - learning_rate: 2.5000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9710 - loss: 0.1154 - val_accuracy: 0.6174 - val_loss: 1.2586 - learning_rate: 2.5000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.9753 - loss: 0.1038 - val_accuracy: 0.6072 - val_loss: 1.3151 - learning_rate: 2.5000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9818 - loss: 0.0885 - val_accuracy: 0.6160 - val_loss: 1.2726 - learning_rate: 2.5000e-04
# Epoch 30/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 20s 360ms/step - accuracy: 0.9838 - loss: 0.0785 - val_accuracy: 0.6182 - val_loss: 1.2926 - learning_rate: 2.5000e-04
# Epoch 31/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9861 - loss: 0.0677 - val_accuracy: 0.6193 - val_loss: 1.2735 - learning_rate: 2.5000e-04
# Epoch 32/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9890 - loss: 0.0620
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9890 - loss: 0.0620 - val_accuracy: 0.6204 - val_loss: 1.2605 - learning_rate: 2.5000e-04
# Epoch 33/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9890 - loss: 0.0620 - val_accuracy: 0.6182 - val_loss: 1.2895 - learning_rate: 1.2500e-04
# Epoch 34/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9917 - loss: 0.0513 - val_accuracy: 0.6196 - val_loss: 1.3172 - learning_rate: 1.2500e-04
# Epoch 35/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9932 - loss: 0.0445 - val_accuracy: 0.6190 - val_loss: 1.3191 - learning_rate: 1.2500e-04
# Epoch 36/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9948 - loss: 0.0390 - val_accuracy: 0.6229 - val_loss: 1.3210 - learning_rate: 1.2500e-04
# Epoch 37/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9956 - loss: 0.0371
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9956 - loss: 0.0371 - val_accuracy: 0.6229 - val_loss: 1.3162 - learning_rate: 1.2500e-04
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 27.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step
# Time elapsed: 0:29:12.972840
# Running fold: 3
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 24s 365ms/step - accuracy: 0.1884 - loss: 2.8039 - val_accuracy: 0.2301 - val_loss: 2.1978 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.2746 - loss: 2.1327 - val_accuracy: 0.2719 - val_loss: 2.0350 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.3443 - loss: 1.8935 - val_accuracy: 0.3381 - val_loss: 1.8302 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.3933 - loss: 1.7337 - val_accuracy: 0.3802 - val_loss: 1.7139 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.4517 - loss: 1.5530 - val_accuracy: 0.4120 - val_loss: 1.6542 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.4975 - loss: 1.4072 - val_accuracy: 0.4313 - val_loss: 1.6299 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.5424 - loss: 1.2820 - val_accuracy: 0.4478 - val_loss: 1.5173 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.5737 - loss: 1.1935 - val_accuracy: 0.4830 - val_loss: 1.4434 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6272 - loss: 1.0358 - val_accuracy: 0.4956 - val_loss: 1.3979 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.6399 - loss: 0.9975 - val_accuracy: 0.4937 - val_loss: 1.4523 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.6811 - loss: 0.8913 - val_accuracy: 0.4920 - val_loss: 1.4550 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6903 - loss: 0.8714 - val_accuracy: 0.5173 - val_loss: 1.4234 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7103 - loss: 0.8021 - val_accuracy: 0.5181 - val_loss: 1.3614 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.7222 - loss: 0.7635 - val_accuracy: 0.5291 - val_loss: 1.3962 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.7567 - loss: 0.6914 - val_accuracy: 0.5286 - val_loss: 1.3840 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.7874 - loss: 0.6113 - val_accuracy: 0.4813 - val_loss: 1.7768 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.7818 - loss: 0.6190 - val_accuracy: 0.5388 - val_loss: 1.4472 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8073 - loss: 0.5588
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.8076 - loss: 0.5581 - val_accuracy: 0.5396 - val_loss: 1.4400 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.8222 - loss: 0.5263 - val_accuracy: 0.5687 - val_loss: 1.2791 - learning_rate: 5.0000e-04
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.8656 - loss: 0.3997 - val_accuracy: 0.5836 - val_loss: 1.2436 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.8984 - loss: 0.3150 - val_accuracy: 0.5805 - val_loss: 1.3526 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9191 - loss: 0.2562 - val_accuracy: 0.5957 - val_loss: 1.2876 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9306 - loss: 0.2358 - val_accuracy: 0.5959 - val_loss: 1.2669 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.9472 - loss: 0.1870 - val_accuracy: 0.5990 - val_loss: 1.2954 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9593 - loss: 0.1605
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.9593 - loss: 0.1603 - val_accuracy: 0.5976 - val_loss: 1.3494 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9562 - loss: 0.1515 - val_accuracy: 0.6105 - val_loss: 1.2428 - learning_rate: 2.5000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.9749 - loss: 0.1050 - val_accuracy: 0.6135 - val_loss: 1.2518 - learning_rate: 2.5000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.9802 - loss: 0.0893 - val_accuracy: 0.6124 - val_loss: 1.2587 - learning_rate: 2.5000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9840 - loss: 0.0791 - val_accuracy: 0.6108 - val_loss: 1.2673 - learning_rate: 2.5000e-04
# Epoch 30/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9857 - loss: 0.0685 - val_accuracy: 0.6149 - val_loss: 1.2712 - learning_rate: 2.5000e-04
# Epoch 31/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9893 - loss: 0.0618
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9893 - loss: 0.0617 - val_accuracy: 0.6171 - val_loss: 1.3172 - learning_rate: 2.5000e-04
# Epoch 32/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9910 - loss: 0.0574 - val_accuracy: 0.6215 - val_loss: 1.2972 - learning_rate: 1.2500e-04
# Epoch 33/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9909 - loss: 0.0517 - val_accuracy: 0.6226 - val_loss: 1.2912 - learning_rate: 1.2500e-04
# Epoch 34/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9935 - loss: 0.0449 - val_accuracy: 0.6220 - val_loss: 1.2936 - learning_rate: 1.2500e-04
# Epoch 35/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9933 - loss: 0.0441 - val_accuracy: 0.6234 - val_loss: 1.2921 - learning_rate: 1.2500e-04
# Epoch 36/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9945 - loss: 0.0405
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9944 - loss: 0.0405 - val_accuracy: 0.6220 - val_loss: 1.3140 - learning_rate: 1.2500e-04
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step
# Time elapsed: 0:41:41.934591
# Running fold: 4
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 24s 364ms/step - accuracy: 0.1855 - loss: 2.9267 - val_accuracy: 0.2053 - val_loss: 2.3087 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.2874 - loss: 2.1215 - val_accuracy: 0.2741 - val_loss: 1.9863 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.3545 - loss: 1.8826 - val_accuracy: 0.3370 - val_loss: 1.8273 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.3928 - loss: 1.7263 - val_accuracy: 0.3615 - val_loss: 1.7522 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.4388 - loss: 1.5818 - val_accuracy: 0.4098 - val_loss: 1.7040 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.5012 - loss: 1.4075 - val_accuracy: 0.4478 - val_loss: 1.5459 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.5306 - loss: 1.3046 - val_accuracy: 0.4670 - val_loss: 1.5044 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.5795 - loss: 1.1646 - val_accuracy: 0.4747 - val_loss: 1.5589 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.6191 - loss: 1.0531 - val_accuracy: 0.4997 - val_loss: 1.4896 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.6488 - loss: 0.9793 - val_accuracy: 0.5000 - val_loss: 1.5099 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.6794 - loss: 0.9044 - val_accuracy: 0.5333 - val_loss: 1.3287 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.6972 - loss: 0.8449 - val_accuracy: 0.5247 - val_loss: 1.3254 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.7315 - loss: 0.7631 - val_accuracy: 0.5143 - val_loss: 1.4257 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7478 - loss: 0.7200 - val_accuracy: 0.5327 - val_loss: 1.3783 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7486 - loss: 0.7254 - val_accuracy: 0.5335 - val_loss: 1.4001 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7774 - loss: 0.6262 - val_accuracy: 0.5313 - val_loss: 1.4232 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7963 - loss: 0.5876
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.7964 - loss: 0.5873 - val_accuracy: 0.5377 - val_loss: 1.4711 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.8218 - loss: 0.5218 - val_accuracy: 0.5511 - val_loss: 1.3930 - learning_rate: 5.0000e-04
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.8651 - loss: 0.4042 - val_accuracy: 0.5717 - val_loss: 1.3018 - learning_rate: 5.0000e-04
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.9001 - loss: 0.3203 - val_accuracy: 0.5704 - val_loss: 1.3419 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9208 - loss: 0.2659 - val_accuracy: 0.5877 - val_loss: 1.2674 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9321 - loss: 0.2290 - val_accuracy: 0.5764 - val_loss: 1.3904 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9325 - loss: 0.2245 - val_accuracy: 0.5811 - val_loss: 1.4170 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9429 - loss: 0.1949 - val_accuracy: 0.6025 - val_loss: 1.2325 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9539 - loss: 0.1648 - val_accuracy: 0.5981 - val_loss: 1.2730 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 363ms/step - accuracy: 0.9620 - loss: 0.1409 - val_accuracy: 0.5935 - val_loss: 1.3349 - learning_rate: 5.0000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9707 - loss: 0.1125 - val_accuracy: 0.5998 - val_loss: 1.3553 - learning_rate: 5.0000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9770 - loss: 0.0984 - val_accuracy: 0.5965 - val_loss: 1.3445 - learning_rate: 5.0000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9772 - loss: 0.0925
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9772 - loss: 0.0925 - val_accuracy: 0.5992 - val_loss: 1.3578 - learning_rate: 5.0000e-04
# Epoch 30/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9752 - loss: 0.0965 - val_accuracy: 0.6069 - val_loss: 1.3529 - learning_rate: 2.5000e-04
# Epoch 31/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9836 - loss: 0.0686 - val_accuracy: 0.6091 - val_loss: 1.3296 - learning_rate: 2.5000e-04
# Epoch 32/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9895 - loss: 0.0511 - val_accuracy: 0.6056 - val_loss: 1.3406 - learning_rate: 2.5000e-04
# Epoch 33/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.9937 - loss: 0.0398 - val_accuracy: 0.6072 - val_loss: 1.3400 - learning_rate: 2.5000e-04
# Epoch 34/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9938 - loss: 0.0383
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21s 361ms/step - accuracy: 0.9938 - loss: 0.0383 - val_accuracy: 0.6111 - val_loss: 1.3347 - learning_rate: 2.5000e-04
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step
# Time elapsed: 0:53:29.832726
# Total Training Time: 0:53:29
# Val Acc per fold: [58.27, 57.5, 62.29, 62.2, 61.11]
