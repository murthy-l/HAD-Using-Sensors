# %% [markdown]
# # Detecting Human Activities Through Smartphone Sensor - Training

# %% [markdown]
# ## Imports

# %%
# TF related imports
import tensorflow as tf
from tensorflow.keras.models import Model
import tensorflow.keras.layers as layer
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

#scikit related imports
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# other generic imports
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from mlxtend import plotting
from tqdm import tqdm
from datetime import timedelta
import time
# Out:
# 2024-11-24 08:48:05.483657: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-24 08:48:05.498896: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-24 08:48:05.503510: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-24 08:48:05.514843: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-24 08:48:06.331186: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Global Variables

# %%
# global variables
PBAR_FORMAT='{desc:12} {percentage:3.0f}%|{bar:27}| [ {n:4d}/{total:4d}, {elapsed}<{remaining}{postfix} ]'

ACTIVITY_CODES_MAPPING = {'A': 'walking',
                          'B': 'jogging',
                          'C': 'stairs',
                          'D': 'sitting',
                          'E': 'standing',
                          'F': 'typing',
                          'G': 'brushing teeth',
                          'H': 'eating soup',
                          'I': 'eating chips',
                          'J': 'eating pasta',
                          'K': 'drinking from cup',
                          'L': 'eating sandwich',
                          'M': 'kicking soccer ball',
                          'O': 'playing catch tennis ball',
                          'P': 'dribbling basket ball',
                          'Q': 'writing',
                          'R': 'clapping',
                          'S': 'folding clothes'}
# csv file column names
COL_NAMES =  ['id' , 'activity_code' , 'timestamp', 'x', 'y', 'z']
# training verbose
VERBOSE = 1

NUM_FOLDS = 5

# %% [markdown]
# ## Dataset, Model and Trainer

# %% [markdown]
# ### Helper functions

# %%
def get_activity_code(activity_names):
    cat_len=len(activity_names)
    activity_code={}
    for idx, an in enumerate(activity_names):
        for k in ACTIVITY_CODES_MAPPING.keys() :
            if ACTIVITY_CODES_MAPPING[k]==an:
                key = k
        activity_code[key]=idx

    assert(len(activity_code.keys())== cat_len)

    print(f"{activity_code}")
    print(f"Number of Categories {cat_len}")
    return activity_code, cat_len

def sliding_window(dataset, window_size, step_size):
    x_list, y_list, z_list = [], [], []
    targets_list = []
    for i in range(0, dataset.shape[0] - window_size, step_size):
        x_list.append(dataset["x"].values[i: i + window_size])
        y_list.append(dataset["y"].values[i: i + window_size])
        z_list.append(dataset["z"].values[i: i + window_size])
        targets_list.append(stats.mode(dataset["activity_code"][i: i + window_size])[0])

    targets = np.array(targets_list)
    feature_list = [x_list, y_list, z_list]

    feature_list = [np.array(data_list) for data_list in feature_list]
    dataset = np.stack(feature_list, axis = 2)

    return dataset, targets

# %% [markdown]
# ### Dataset

# %%
def WISDM_Dataset(data_dir, window_size, step_size, activity_code):
    column_names = COL_NAMES
    filelist_train = sorted([txt for txt in os.listdir(data_dir + "/") if txt[-4:] == ".txt"])
    columns = ["x", "y", "z"]

    # Training data
    dataset_train = pd.DataFrame()

    for txt in tqdm(filelist_train, desc="loading data", bar_format=PBAR_FORMAT):
        dataset_tmp = pd.read_csv(data_dir + '/' + txt, header = None, names = column_names, comment = ";")
        for k in activity_code.keys():
            df_tmp = dataset_tmp[dataset_tmp['activity_code']==k][0:2400]
            dataset_train = pd.concat([dataset_train, df_tmp])
    print(dataset_train)

    # normalize the data
    dataset_train["activity_code"] = dataset_train["activity_code"].map(activity_code)
    labels = dataset_train["activity_code"].to_numpy()

    scaler = RobustScaler()
    dataset_train = scaler.fit_transform(dataset_train[["x", "y", "z"]])
    dataset_train = pd.DataFrame(data = dataset_train, columns = ["x", "y", "z"])
    dataset_train["activity_code"] = labels

    # feature engineering
    dataset_train, targets = sliding_window(dataset_train, window_size, step_size)
    return dataset_train, targets

# %% [markdown]
# ### Model

# %%
def gru_net(data, num_classes):
    x_input = layer.Input(shape = (data.shape[-2:]))
    x = layer.Bidirectional(layer.GRU(512, return_sequences = True))(x_input)
    x = layer.BatchNormalization()(x)
    x = layer.Bidirectional(layer.GRU(256, return_sequences = True))(x)
    x = layer.BatchNormalization()(x)
    x = layer.Bidirectional(layer.GRU(128, return_sequences = True))(x)
    x = layer.BatchNormalization()(x)

    x = layer.Flatten()(x)

    x = layer.Dense(128, activation = "relu")(x)
    x = layer.BatchNormalization()(x)
    x = layer.Dropout(0.5)(x)
    x_output = layer.Dense(num_classes, activation = "softmax")(x)

    model = Model(inputs = x_input, outputs = x_output, name = "GRU_NET")

    return model

# %% [markdown]
# ### Plotting function

# %%
def plot_loss_acc(epochs, train_losses, train_acc, test_losses, test_acc, fold):
    fig, ax1 = plt.subplots()
    xaxis = list(range(1, epochs + 1))
    plt_train_loss = ax1.plot(xaxis, train_losses, label = "Training Loss", color="red")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2 = ax1.twinx()
    plt_train_acc = ax2.plot(xaxis, train_acc, label = "Training Accuracy", color="green")
    ax2.set_ylabel("Accuracy in %")
    ax2.set_ylim(0.0, 100.0)

    plt_val_loss = ax1.plot(xaxis, test_losses, label = "Validation Loss", color="firebrick")
    plt_val_acc = ax2.plot(xaxis, test_acc, label = "Validation Accuracy", color="limegreen")

    lines = plt_train_loss + plt_train_acc + plt_val_loss + plt_val_acc
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels)
    fold = " Fold " + str(fold)
    plt.title("Loss and Accuracy" + fold)
    plt.show()

def plot_confusion_matrix(y_pred, y_valid, fold, activity_names):
    conf_matrix = confusion_matrix(y_valid, y_pred)
    plotting.plot_confusion_matrix(conf_mat = conf_matrix,
                                   class_names = activity_names,
                                   show_normed = True,
                                   figsize = (14, 12),
                                   colorbar = True)
    plt.title("Confusion matrix Fold " + str(fold))
    plt.show()

# %% [markdown]
# ### Trainer function

# %%
def train(nn_net, cat_len, batch_size, num_epochs, min_epochs, k_fold, train_ds, target_ds):
    val_acc_last = []

    training_data={}
    start_time = time.time()
    for fold, (train_index, test_index) in enumerate(k_fold.split(train_ds, target_ds)):
        print(f"Running fold: {fold}")
        x_train, x_valid = train_ds[train_index], train_ds[test_index]
        y_train, y_valid = target_ds[train_index], target_ds[test_index]

        # convert to tf dataset
        train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size).with_options(options)
        valid_data = tf.data.Dataset.from_tensor_slices((x_valid, y_valid)).batch(batch_size).with_options(options)

        model = nn_net(train_ds, cat_len)

        model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])

        learning_rate = ReduceLROnPlateau(monitor = "val_loss", factor = 0.75, patience = 3, verbose = VERBOSE)
        early_stopping = EarlyStopping(monitor = "val_accuracy", patience = 9,
                                       start_from_epoch=min_epochs, verbose = VERBOSE, mode = "max")

        # model training
        model_data = model.fit(train_data,
                                validation_data = valid_data,
                                epochs = num_epochs,
                                verbose = VERBOSE,
                                batch_size = BATCH_SIZE,
                                callbacks = [learning_rate, early_stopping])
        val_acc_last.append(np.around(100.0 * model_data.history["val_accuracy"][-1], 2))

        y_pred = np.argmax(model.predict(valid_data, batch_size = BATCH_SIZE), axis = 1)

        training_data[fold] = {'model_data':model_data,
                               'y_pred': y_pred,
                               'y_valid':y_valid}
        print(f'Time elapsed: {timedelta(microseconds=int((time.time()-start_time)*1000000))}')


    print(f'Total Training Time: {timedelta(seconds=int(time.time()-start_time))}')
    print("Val Acc per fold:", val_acc_last)
    return training_data

# %% [markdown]
# ## Training on watch accelerometer

# %% [markdown]
# ### Hyper parameters

# %%
ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "typing", "brushing teeth",
                  "eating soup", "eating chips", "eating pasta", "drinking from cup", "eating sandwich",
                  "kicking soccer ball", "playing catch tennis ball", "dribbling basket ball",
                  "writing", "clapping", "folding clothes"]
NUM_EPOCHS = 90
MIN_EPOCHS = 27
BATCH_SIZE = 256
WINDOW_SIZE=200
STEP_SIZE=100
NN_NET = gru_net
DATA_DIR="../dataset/raw/watch/accel"

# %% [markdown]
# ### Initialize Dataset

# %%
options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.OFF
activity_code, cat_len = get_activity_code(ACTIVITY_NAMES)
# Dataset
train_ds, target_ds = WISDM_Dataset(data_dir = DATA_DIR,
                                      window_size = WINDOW_SIZE,
                                      step_size = STEP_SIZE,
                                      activity_code = activity_code)
k_fold = StratifiedKFold(n_splits = NUM_FOLDS,
                           shuffle = True)
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9, 'K': 10, 'L': 11, 'M': 12, 'O': 13, 'P': 14, 'Q': 15, 'R': 16, 'S': 17}
# Number of Categories 18
# loading data 100%|███████████████████████████| [   51/  51, 00:18<00:00 ]
#          id activity_code         timestamp         x         y         z
# 0      1600             A    90426708196641  7.091625 -0.591667  8.195502
# 1      1600             A    90426757696641  4.972757 -0.158317  6.696732
# 2      1600             A    90426807196641  3.253720 -0.191835  6.107758
# 3      1600             A    90426856696641  2.801216 -0.155922  5.997625
# 4      1600             A    90426906196641  3.770868 -1.051354  7.731027
# ...     ...           ...               ...       ...       ...       ...
# 65386  1650             S  2426124382870752  6.425738 -6.462100  1.874061
# 65387  1650             S  2426124432864802  6.267721 -6.217891  1.682525
# 65388  1650             S  2426124482858852  5.822399 -6.553080  1.079186
# 65389  1650             S  2426124532852902  5.590162 -7.029526  0.504578
# 65390  1650             S  2426124582846952  5.702689 -7.668778  0.317830
#
# [2188800 rows x 6 columns]

# %% [markdown]
# ### Model Summary

# %%
model = NN_NET(train_ds, cat_len)
print(model.summary())
# Out:
# 2024-11-24 08:48:35.540696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6634 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:65:00.0, compute capability: 7.5
# Model: "GRU_NET"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 200, 1024)      │     1,588,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200, 1024)      │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 200, 512)       │     1,969,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 200, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 200, 256)       │       493,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 200, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     6,553,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 18)             │         2,322 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,614,162 (40.49 MB)
#  Trainable params: 10,610,322 (40.48 MB)
#  Non-trainable params: 3,840 (15.00 KB)
# None

# %% [markdown]
# ### Training

# %%
training_data = train(nn_net=NN_NET,
                      cat_len=cat_len,
                      batch_size=BATCH_SIZE,
                      num_epochs=NUM_EPOCHS,
                      min_epochs=MIN_EPOCHS,
                      k_fold=k_fold,
                      train_ds=train_ds,
                      target_ds=target_ds)
# Out:
# Running fold: 0
# Epoch 1/90
# 2024-11-24 08:48:41.363449: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 346ms/step - accuracy: 0.1884 - loss: 3.2074 - val_accuracy: 0.2017 - val_loss: 2.8307 - learning_rate: 0.0010
# Epoch 2/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 344ms/step - accuracy: 0.3113 - loss: 2.3284 - val_accuracy: 0.2092 - val_loss: 2.5612 - learning_rate: 0.0010
# Epoch 3/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 348ms/step - accuracy: 0.4073 - loss: 1.9329 - val_accuracy: 0.2065 - val_loss: 2.7847 - learning_rate: 0.0010
# Epoch 4/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 350ms/step - accuracy: 0.4736 - loss: 1.6882 - val_accuracy: 0.3223 - val_loss: 2.2234 - learning_rate: 0.0010
# Epoch 5/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 351ms/step - accuracy: 0.5465 - loss: 1.4269 - val_accuracy: 0.3883 - val_loss: 1.9885 - learning_rate: 0.0010
# Epoch 6/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 352ms/step - accuracy: 0.5938 - loss: 1.2651 - val_accuracy: 0.5021 - val_loss: 1.5558 - learning_rate: 0.0010
# Epoch 7/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 352ms/step - accuracy: 0.6502 - loss: 1.0967 - val_accuracy: 0.5738 - val_loss: 1.3552 - learning_rate: 0.0010
# Epoch 8/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 352ms/step - accuracy: 0.6993 - loss: 0.9406 - val_accuracy: 0.5818 - val_loss: 1.3682 - learning_rate: 0.0010
# Epoch 9/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 353ms/step - accuracy: 0.7052 - loss: 0.9153 - val_accuracy: 0.6268 - val_loss: 1.2225 - learning_rate: 0.0010
# Epoch 10/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 353ms/step - accuracy: 0.7401 - loss: 0.7987 - val_accuracy: 0.6524 - val_loss: 1.1533 - learning_rate: 0.0010
# Epoch 11/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 353ms/step - accuracy: 0.7646 - loss: 0.7260 - val_accuracy: 0.6683 - val_loss: 1.0931 - learning_rate: 0.0010
# Epoch 12/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 354ms/step - accuracy: 0.8027 - loss: 0.6249 - val_accuracy: 0.6772 - val_loss: 1.1457 - learning_rate: 0.0010
# Epoch 13/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 354ms/step - accuracy: 0.8218 - loss: 0.5610 - val_accuracy: 0.6759 - val_loss: 1.1316 - learning_rate: 0.0010
# Epoch 14/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8361 - loss: 0.5227
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.8360 - loss: 0.5229 - val_accuracy: 0.6772 - val_loss: 1.1325 - learning_rate: 0.0010
# Epoch 15/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 354ms/step - accuracy: 0.8571 - loss: 0.4671 - val_accuracy: 0.6974 - val_loss: 1.1368 - learning_rate: 7.5000e-04
# Epoch 16/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 354ms/step - accuracy: 0.8677 - loss: 0.4262 - val_accuracy: 0.7138 - val_loss: 0.9809 - learning_rate: 7.5000e-04
# Epoch 17/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.8919 - loss: 0.3531 - val_accuracy: 0.7108 - val_loss: 1.0640 - learning_rate: 7.5000e-04
# Epoch 18/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9018 - loss: 0.3196 - val_accuracy: 0.7252 - val_loss: 0.9950 - learning_rate: 7.5000e-04
# Epoch 19/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9126 - loss: 0.2818
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9126 - loss: 0.2817 - val_accuracy: 0.7129 - val_loss: 1.0862 - learning_rate: 7.5000e-04
# Epoch 20/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9285 - loss: 0.2338 - val_accuracy: 0.7225 - val_loss: 1.0337 - learning_rate: 5.6250e-04
# Epoch 21/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9313 - loss: 0.2270 - val_accuracy: 0.7385 - val_loss: 0.9981 - learning_rate: 5.6250e-04
# Epoch 22/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9470 - loss: 0.1870
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9469 - loss: 0.1872 - val_accuracy: 0.7373 - val_loss: 1.0300 - learning_rate: 5.6250e-04
# Epoch 23/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9553 - loss: 0.1593 - val_accuracy: 0.7469 - val_loss: 0.9539 - learning_rate: 4.2187e-04
# Epoch 24/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9648 - loss: 0.1299 - val_accuracy: 0.7570 - val_loss: 0.9547 - learning_rate: 4.2187e-04
# Epoch 25/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9661 - loss: 0.1237 - val_accuracy: 0.7394 - val_loss: 1.0390 - learning_rate: 4.2187e-04
# Epoch 26/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9743 - loss: 0.1070
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9743 - loss: 0.1071 - val_accuracy: 0.7529 - val_loss: 0.9819 - learning_rate: 4.2187e-04
# Epoch 27/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9746 - loss: 0.0936 - val_accuracy: 0.7426 - val_loss: 1.0903 - learning_rate: 3.1641e-04
# Epoch 28/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9785 - loss: 0.0840 - val_accuracy: 0.7602 - val_loss: 0.9846 - learning_rate: 3.1641e-04
# Epoch 29/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9853 - loss: 0.0672
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9852 - loss: 0.0674 - val_accuracy: 0.7558 - val_loss: 1.0446 - learning_rate: 3.1641e-04
# Epoch 30/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9831 - loss: 0.0719 - val_accuracy: 0.7622 - val_loss: 0.9851 - learning_rate: 2.3730e-04
# Epoch 31/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9884 - loss: 0.0524 - val_accuracy: 0.7663 - val_loss: 1.0042 - learning_rate: 2.3730e-04
# Epoch 32/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9913 - loss: 0.0449
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9913 - loss: 0.0450 - val_accuracy: 0.7686 - val_loss: 1.0008 - learning_rate: 2.3730e-04
# Epoch 33/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9907 - loss: 0.0423 - val_accuracy: 0.7668 - val_loss: 1.0299 - learning_rate: 1.7798e-04
# Epoch 34/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9943 - loss: 0.0333 - val_accuracy: 0.7670 - val_loss: 1.0105 - learning_rate: 1.7798e-04
# Epoch 35/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9954 - loss: 0.0304
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9953 - loss: 0.0305 - val_accuracy: 0.7702 - val_loss: 1.0228 - learning_rate: 1.7798e-04
# Epoch 36/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9969 - loss: 0.0259 - val_accuracy: 0.7702 - val_loss: 1.0053 - learning_rate: 1.3348e-04
# Epoch 37/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9964 - loss: 0.0256 - val_accuracy: 0.7727 - val_loss: 1.0186 - learning_rate: 1.3348e-04
# Epoch 38/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9966 - loss: 0.0233
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9966 - loss: 0.0233 - val_accuracy: 0.7718 - val_loss: 1.0100 - learning_rate: 1.3348e-04
# Epoch 39/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9971 - loss: 0.0223 - val_accuracy: 0.7752 - val_loss: 1.0060 - learning_rate: 1.0011e-04
# Epoch 40/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9977 - loss: 0.0191 - val_accuracy: 0.7766 - val_loss: 0.9927 - learning_rate: 1.0011e-04
# Epoch 41/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9985 - loss: 0.0187
# Epoch 41: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9985 - loss: 0.0188 - val_accuracy: 0.7741 - val_loss: 1.0120 - learning_rate: 1.0011e-04
# Epoch 42/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9978 - loss: 0.0176 - val_accuracy: 0.7771 - val_loss: 0.9969 - learning_rate: 7.5085e-05
# Epoch 43/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9985 - loss: 0.0167 - val_accuracy: 0.7720 - val_loss: 1.0170 - learning_rate: 7.5085e-05
# Epoch 44/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9991 - loss: 0.0146
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9991 - loss: 0.0147 - val_accuracy: 0.7782 - val_loss: 1.0114 - learning_rate: 7.5085e-05
# Epoch 45/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9988 - loss: 0.0144 - val_accuracy: 0.7743 - val_loss: 1.0187 - learning_rate: 5.6314e-05
# Epoch 46/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9992 - loss: 0.0133 - val_accuracy: 0.7755 - val_loss: 1.0167 - learning_rate: 5.6314e-05
# Epoch 47/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9992 - loss: 0.0127
# Epoch 47: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9992 - loss: 0.0127 - val_accuracy: 0.7755 - val_loss: 1.0186 - learning_rate: 5.6314e-05
# Epoch 48/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9993 - loss: 0.0120 - val_accuracy: 0.7762 - val_loss: 1.0197 - learning_rate: 4.2235e-05
# Epoch 49/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9993 - loss: 0.0125 - val_accuracy: 0.7750 - val_loss: 1.0232 - learning_rate: 4.2235e-05
# Epoch 50/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9994 - loss: 0.0124
# Epoch 50: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9994 - loss: 0.0124 - val_accuracy: 0.7762 - val_loss: 1.0199 - learning_rate: 4.2235e-05
# Epoch 51/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9998 - loss: 0.0116 - val_accuracy: 0.7752 - val_loss: 1.0193 - learning_rate: 3.1676e-05
# Epoch 52/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9997 - loss: 0.0117 - val_accuracy: 0.7755 - val_loss: 1.0253 - learning_rate: 3.1676e-05
# Epoch 53/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9998 - loss: 0.0113
# Epoch 53: ReduceLROnPlateau reducing learning rate to 2.3757263079460245e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9998 - loss: 0.0114 - val_accuracy: 0.7784 - val_loss: 1.0209 - learning_rate: 3.1676e-05
# Epoch 54/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9999 - loss: 0.0111 - val_accuracy: 0.7762 - val_loss: 1.0233 - learning_rate: 2.3757e-05
# Epoch 55/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9996 - loss: 0.0106 - val_accuracy: 0.7766 - val_loss: 1.0241 - learning_rate: 2.3757e-05
# Epoch 56/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9996 - loss: 0.0109
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.781794799171621e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9996 - loss: 0.0109 - val_accuracy: 0.7771 - val_loss: 1.0265 - learning_rate: 2.3757e-05
# Epoch 57/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9993 - loss: 0.0110 - val_accuracy: 0.7762 - val_loss: 1.0274 - learning_rate: 1.7818e-05
# Epoch 58/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9998 - loss: 0.0103 - val_accuracy: 0.7757 - val_loss: 1.0285 - learning_rate: 1.7818e-05
# Epoch 59/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9997 - loss: 0.0102
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.3363460311666131e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9997 - loss: 0.0102 - val_accuracy: 0.7771 - val_loss: 1.0305 - learning_rate: 1.7818e-05
# Epoch 60/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9996 - loss: 0.0100 - val_accuracy: 0.7782 - val_loss: 1.0302 - learning_rate: 1.3363e-05
# Epoch 61/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9999 - loss: 0.0097 - val_accuracy: 0.7789 - val_loss: 1.0303 - learning_rate: 1.3363e-05
# Epoch 62/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9997 - loss: 0.0103
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.0022595233749598e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9997 - loss: 0.0103 - val_accuracy: 0.7771 - val_loss: 1.0298 - learning_rate: 1.3363e-05
# Epoch 63/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9998 - loss: 0.0098 - val_accuracy: 0.7778 - val_loss: 1.0294 - learning_rate: 1.0023e-05
# Epoch 64/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9998 - loss: 0.0100 - val_accuracy: 0.7764 - val_loss: 1.0293 - learning_rate: 1.0023e-05
# Epoch 65/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9996 - loss: 0.0099
# Epoch 65: ReduceLROnPlateau reducing learning rate to 7.516946425312199e-06.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9996 - loss: 0.0099 - val_accuracy: 0.7773 - val_loss: 1.0289 - learning_rate: 1.0023e-05
# Epoch 66/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9998 - loss: 0.0099 - val_accuracy: 0.7780 - val_loss: 1.0295 - learning_rate: 7.5169e-06
# Epoch 67/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9995 - loss: 0.0097 - val_accuracy: 0.7778 - val_loss: 1.0313 - learning_rate: 7.5169e-06
# Epoch 68/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9997 - loss: 0.0097
# Epoch 68: ReduceLROnPlateau reducing learning rate to 5.637709818984149e-06.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9997 - loss: 0.0097 - val_accuracy: 0.7768 - val_loss: 1.0310 - learning_rate: 7.5169e-06
# Epoch 69/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9999 - loss: 0.0092 - val_accuracy: 0.7780 - val_loss: 1.0306 - learning_rate: 5.6377e-06
# Epoch 70/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9998 - loss: 0.0095 - val_accuracy: 0.7773 - val_loss: 1.0323 - learning_rate: 5.6377e-06
# Epoch 70: early stopping
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step
# Time elapsed: 0:28:43.020418
# Running fold: 1
# Epoch 1/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 28s 358ms/step - accuracy: 0.1830 - loss: 3.3166 - val_accuracy: 0.1855 - val_loss: 2.5663 - learning_rate: 0.0010
# Epoch 2/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.3153 - loss: 2.2801 - val_accuracy: 0.2458 - val_loss: 2.5457 - learning_rate: 0.0010
# Epoch 3/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.3993 - loss: 1.9205 - val_accuracy: 0.2790 - val_loss: 2.4196 - learning_rate: 0.0010
# Epoch 4/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.4924 - loss: 1.6172 - val_accuracy: 0.3544 - val_loss: 2.0983 - learning_rate: 0.0010
# Epoch 5/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.5343 - loss: 1.4385 - val_accuracy: 0.4051 - val_loss: 1.9796 - learning_rate: 0.0010
# Epoch 6/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.5927 - loss: 1.2642 - val_accuracy: 0.5001 - val_loss: 1.6323 - learning_rate: 0.0010
# Epoch 7/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.6370 - loss: 1.1106 - val_accuracy: 0.6059 - val_loss: 1.3125 - learning_rate: 0.0010
# Epoch 8/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.6746 - loss: 0.9858 - val_accuracy: 0.5545 - val_loss: 1.4001 - learning_rate: 0.0010
# Epoch 9/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.7063 - loss: 0.9089 - val_accuracy: 0.5698 - val_loss: 1.3676 - learning_rate: 0.0010
# Epoch 10/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.7373 - loss: 0.8199 - val_accuracy: 0.6143 - val_loss: 1.3026 - learning_rate: 0.0010
# Epoch 11/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.7716 - loss: 0.7185 - val_accuracy: 0.6153 - val_loss: 1.2657 - learning_rate: 0.0010
# Epoch 12/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.7992 - loss: 0.6486 - val_accuracy: 0.6539 - val_loss: 1.1330 - learning_rate: 0.0010
# Epoch 13/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.8117 - loss: 0.5992 - val_accuracy: 0.6408 - val_loss: 1.1675 - learning_rate: 0.0010
# Epoch 14/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.8231 - loss: 0.5560 - val_accuracy: 0.6498 - val_loss: 1.1945 - learning_rate: 0.0010
# Epoch 15/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8408 - loss: 0.5089 - val_accuracy: 0.6735 - val_loss: 1.1065 - learning_rate: 0.0010
# Epoch 16/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.8507 - loss: 0.4710 - val_accuracy: 0.7050 - val_loss: 0.9466 - learning_rate: 0.0010
# Epoch 17/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8617 - loss: 0.4242 - val_accuracy: 0.6749 - val_loss: 1.1399 - learning_rate: 0.0010
# Epoch 18/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8759 - loss: 0.3890 - val_accuracy: 0.7066 - val_loss: 1.0263 - learning_rate: 0.0010
# Epoch 19/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8978 - loss: 0.3230
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8977 - loss: 0.3233 - val_accuracy: 0.7108 - val_loss: 1.0175 - learning_rate: 0.0010
# Epoch 20/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.8952 - loss: 0.3242 - val_accuracy: 0.7224 - val_loss: 0.9766 - learning_rate: 7.5000e-04
# Epoch 21/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9144 - loss: 0.2765 - val_accuracy: 0.7462 - val_loss: 0.9435 - learning_rate: 7.5000e-04
# Epoch 22/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9392 - loss: 0.2057 - val_accuracy: 0.7395 - val_loss: 0.9975 - learning_rate: 7.5000e-04
# Epoch 23/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.9478 - loss: 0.1795 - val_accuracy: 0.7491 - val_loss: 1.0077 - learning_rate: 7.5000e-04
# Epoch 24/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9554 - loss: 0.1570
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9553 - loss: 0.1572 - val_accuracy: 0.7407 - val_loss: 0.9934 - learning_rate: 7.5000e-04
# Epoch 25/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9622 - loss: 0.1326 - val_accuracy: 0.7583 - val_loss: 0.9810 - learning_rate: 5.6250e-04
# Epoch 26/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9686 - loss: 0.1188 - val_accuracy: 0.7466 - val_loss: 0.9689 - learning_rate: 5.6250e-04
# Epoch 27/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9688 - loss: 0.1099
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.9688 - loss: 0.1099 - val_accuracy: 0.7660 - val_loss: 0.9528 - learning_rate: 5.6250e-04
# Epoch 28/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9765 - loss: 0.0863 - val_accuracy: 0.7521 - val_loss: 1.0737 - learning_rate: 4.2187e-04
# Epoch 29/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9809 - loss: 0.0778 - val_accuracy: 0.7560 - val_loss: 0.9805 - learning_rate: 4.2187e-04
# Epoch 30/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9842 - loss: 0.0652
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9842 - loss: 0.0653 - val_accuracy: 0.7555 - val_loss: 0.9986 - learning_rate: 4.2187e-04
# Epoch 31/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9877 - loss: 0.0535 - val_accuracy: 0.7674 - val_loss: 0.9610 - learning_rate: 3.1641e-04
# Epoch 32/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9930 - loss: 0.0391 - val_accuracy: 0.7672 - val_loss: 1.0005 - learning_rate: 3.1641e-04
# Epoch 33/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9934 - loss: 0.0343
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 354ms/step - accuracy: 0.9934 - loss: 0.0343 - val_accuracy: 0.7692 - val_loss: 0.9818 - learning_rate: 3.1641e-04
# Epoch 34/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9952 - loss: 0.0306 - val_accuracy: 0.7651 - val_loss: 1.0882 - learning_rate: 2.3730e-04
# Epoch 35/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9925 - loss: 0.0374 - val_accuracy: 0.7658 - val_loss: 1.0165 - learning_rate: 2.3730e-04
# Epoch 36/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9927 - loss: 0.0355
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.9927 - loss: 0.0356 - val_accuracy: 0.7766 - val_loss: 1.0430 - learning_rate: 2.3730e-04
# Epoch 37/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9960 - loss: 0.0244 - val_accuracy: 0.7779 - val_loss: 0.9862 - learning_rate: 1.7798e-04
# Epoch 38/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9976 - loss: 0.0195 - val_accuracy: 0.7809 - val_loss: 0.9782 - learning_rate: 1.7798e-04
# Epoch 39/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9977 - loss: 0.0172
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9977 - loss: 0.0173 - val_accuracy: 0.7816 - val_loss: 0.9880 - learning_rate: 1.7798e-04
# Epoch 40/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9980 - loss: 0.0166 - val_accuracy: 0.7811 - val_loss: 0.9707 - learning_rate: 1.3348e-04
# Epoch 41/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9982 - loss: 0.0141 - val_accuracy: 0.7809 - val_loss: 0.9789 - learning_rate: 1.3348e-04
# Epoch 42/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9992 - loss: 0.0136
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9992 - loss: 0.0136 - val_accuracy: 0.7852 - val_loss: 0.9873 - learning_rate: 1.3348e-04
# Epoch 43/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.9991 - loss: 0.0118 - val_accuracy: 0.7827 - val_loss: 0.9810 - learning_rate: 1.0011e-04
# Epoch 44/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9992 - loss: 0.0120 - val_accuracy: 0.7827 - val_loss: 0.9909 - learning_rate: 1.0011e-04
# Epoch 45/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9992 - loss: 0.0113
# Epoch 45: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.9992 - loss: 0.0114 - val_accuracy: 0.7827 - val_loss: 0.9831 - learning_rate: 1.0011e-04
# Epoch 46/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9993 - loss: 0.0105 - val_accuracy: 0.7830 - val_loss: 0.9932 - learning_rate: 7.5085e-05
# Epoch 47/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9993 - loss: 0.0101 - val_accuracy: 0.7827 - val_loss: 0.9837 - learning_rate: 7.5085e-05
# Epoch 48/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9996 - loss: 0.0090
# Epoch 48: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9995 - loss: 0.0090 - val_accuracy: 0.7809 - val_loss: 0.9883 - learning_rate: 7.5085e-05
# Epoch 49/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9996 - loss: 0.0094 - val_accuracy: 0.7827 - val_loss: 0.9934 - learning_rate: 5.6314e-05
# Epoch 50/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9995 - loss: 0.0091 - val_accuracy: 0.7859 - val_loss: 0.9881 - learning_rate: 5.6314e-05
# Epoch 51/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9995 - loss: 0.0089
# Epoch 51: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9995 - loss: 0.0090 - val_accuracy: 0.7846 - val_loss: 0.9922 - learning_rate: 5.6314e-05
# Epoch 52/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9991 - loss: 0.0095 - val_accuracy: 0.7850 - val_loss: 0.9874 - learning_rate: 4.2235e-05
# Epoch 53/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9996 - loss: 0.0084 - val_accuracy: 0.7832 - val_loss: 0.9910 - learning_rate: 4.2235e-05
# Epoch 54/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9996 - loss: 0.0087
# Epoch 54: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9996 - loss: 0.0087 - val_accuracy: 0.7843 - val_loss: 0.9917 - learning_rate: 4.2235e-05
# Epoch 55/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9998 - loss: 0.0079 - val_accuracy: 0.7836 - val_loss: 0.9943 - learning_rate: 3.1676e-05
# Epoch 56/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9996 - loss: 0.0081 - val_accuracy: 0.7836 - val_loss: 0.9954 - learning_rate: 3.1676e-05
# Epoch 57/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9997 - loss: 0.0079
# Epoch 57: ReduceLROnPlateau reducing learning rate to 2.3757263079460245e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9997 - loss: 0.0079 - val_accuracy: 0.7841 - val_loss: 1.0014 - learning_rate: 3.1676e-05
# Epoch 58/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9996 - loss: 0.0081 - val_accuracy: 0.7836 - val_loss: 1.0014 - learning_rate: 2.3757e-05
# Epoch 59/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9997 - loss: 0.0074 - val_accuracy: 0.7841 - val_loss: 1.0006 - learning_rate: 2.3757e-05
# Epoch 59: early stopping
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step
# Time elapsed: 0:53:00.469094
# Running fold: 2
# Epoch 1/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 28s 358ms/step - accuracy: 0.1814 - loss: 3.4066 - val_accuracy: 0.1889 - val_loss: 2.7246 - learning_rate: 0.0010
# Epoch 2/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.3336 - loss: 2.2612 - val_accuracy: 0.1581 - val_loss: 2.9517 - learning_rate: 0.0010
# Epoch 3/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.4156 - loss: 1.8998 - val_accuracy: 0.2209 - val_loss: 2.6910 - learning_rate: 0.0010
# Epoch 4/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.4933 - loss: 1.6075 - val_accuracy: 0.2959 - val_loss: 2.3770 - learning_rate: 0.0010
# Epoch 5/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.5476 - loss: 1.3853 - val_accuracy: 0.4277 - val_loss: 1.8891 - learning_rate: 0.0010
# Epoch 6/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.5899 - loss: 1.2578 - val_accuracy: 0.5296 - val_loss: 1.5447 - learning_rate: 0.0010
# Epoch 7/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.6354 - loss: 1.1108 - val_accuracy: 0.5520 - val_loss: 1.4101 - learning_rate: 0.0010
# Epoch 8/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.6847 - loss: 0.9745 - val_accuracy: 0.6198 - val_loss: 1.2215 - learning_rate: 0.0010
# Epoch 9/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.7229 - loss: 0.8562 - val_accuracy: 0.6253 - val_loss: 1.2063 - learning_rate: 0.0010
# Epoch 10/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.7561 - loss: 0.7711 - val_accuracy: 0.6525 - val_loss: 1.1461 - learning_rate: 0.0010
# Epoch 11/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.7733 - loss: 0.7092 - val_accuracy: 0.6751 - val_loss: 1.1016 - learning_rate: 0.0010
# Epoch 12/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8054 - loss: 0.6271 - val_accuracy: 0.6671 - val_loss: 1.1666 - learning_rate: 0.0010
# Epoch 13/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.8199 - loss: 0.5705 - val_accuracy: 0.6767 - val_loss: 1.1985 - learning_rate: 0.0010
# Epoch 14/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8366 - loss: 0.5235 - val_accuracy: 0.6877 - val_loss: 1.0748 - learning_rate: 0.0010
# Epoch 15/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8462 - loss: 0.4964 - val_accuracy: 0.7082 - val_loss: 1.0854 - learning_rate: 0.0010
# Epoch 16/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.8598 - loss: 0.4502 - val_accuracy: 0.7085 - val_loss: 1.0246 - learning_rate: 0.0010
# Epoch 17/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8678 - loss: 0.4172 - val_accuracy: 0.7062 - val_loss: 1.0048 - learning_rate: 0.0010
# Epoch 18/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8743 - loss: 0.3916 - val_accuracy: 0.7112 - val_loss: 1.0361 - learning_rate: 0.0010
# Epoch 19/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.8851 - loss: 0.3497 - val_accuracy: 0.7238 - val_loss: 0.9681 - learning_rate: 0.0010
# Epoch 20/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8996 - loss: 0.3219 - val_accuracy: 0.7153 - val_loss: 1.0889 - learning_rate: 0.0010
# Epoch 21/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9034 - loss: 0.3014 - val_accuracy: 0.7361 - val_loss: 0.9964 - learning_rate: 0.0010
# Epoch 22/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9179 - loss: 0.2586
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9179 - loss: 0.2588 - val_accuracy: 0.7391 - val_loss: 0.9932 - learning_rate: 0.0010
# Epoch 23/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9333 - loss: 0.2270 - val_accuracy: 0.7201 - val_loss: 1.1360 - learning_rate: 7.5000e-04
# Epoch 24/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9279 - loss: 0.2375 - val_accuracy: 0.7512 - val_loss: 0.9423 - learning_rate: 7.5000e-04
# Epoch 25/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9484 - loss: 0.1736 - val_accuracy: 0.7578 - val_loss: 1.0007 - learning_rate: 7.5000e-04
# Epoch 26/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9595 - loss: 0.1405 - val_accuracy: 0.7615 - val_loss: 0.9611 - learning_rate: 7.5000e-04
# Epoch 27/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9685 - loss: 0.1140
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9684 - loss: 0.1142 - val_accuracy: 0.7578 - val_loss: 1.0162 - learning_rate: 7.5000e-04
# Epoch 28/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9701 - loss: 0.1120 - val_accuracy: 0.7613 - val_loss: 0.9452 - learning_rate: 5.6250e-04
# Epoch 29/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9757 - loss: 0.0946 - val_accuracy: 0.7409 - val_loss: 1.0851 - learning_rate: 5.6250e-04
# Epoch 30/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9697 - loss: 0.1140 - val_accuracy: 0.7718 - val_loss: 0.8852 - learning_rate: 5.6250e-04
# Epoch 31/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9816 - loss: 0.0730 - val_accuracy: 0.7633 - val_loss: 0.9315 - learning_rate: 5.6250e-04
# Epoch 32/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9857 - loss: 0.0594 - val_accuracy: 0.7718 - val_loss: 0.9386 - learning_rate: 5.6250e-04
# Epoch 33/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9859 - loss: 0.0574
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9858 - loss: 0.0577 - val_accuracy: 0.7690 - val_loss: 0.9324 - learning_rate: 5.6250e-04
# Epoch 34/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9867 - loss: 0.0531 - val_accuracy: 0.7658 - val_loss: 0.9916 - learning_rate: 4.2187e-04
# Epoch 35/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9863 - loss: 0.0555 - val_accuracy: 0.7606 - val_loss: 0.9853 - learning_rate: 4.2187e-04
# Epoch 36/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9891 - loss: 0.0452
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9890 - loss: 0.0454 - val_accuracy: 0.7674 - val_loss: 1.0351 - learning_rate: 4.2187e-04
# Epoch 37/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9922 - loss: 0.0375 - val_accuracy: 0.7750 - val_loss: 1.0242 - learning_rate: 3.1641e-04
# Epoch 38/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9935 - loss: 0.0287 - val_accuracy: 0.7809 - val_loss: 0.9908 - learning_rate: 3.1641e-04
# Epoch 39/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9957 - loss: 0.0219
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9957 - loss: 0.0220 - val_accuracy: 0.7818 - val_loss: 0.9849 - learning_rate: 3.1641e-04
# Epoch 40/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9963 - loss: 0.0216 - val_accuracy: 0.7857 - val_loss: 0.9640 - learning_rate: 2.3730e-04
# Epoch 41/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9977 - loss: 0.0160 - val_accuracy: 0.7848 - val_loss: 0.9680 - learning_rate: 2.3730e-04
# Epoch 42/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9977 - loss: 0.0155
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9977 - loss: 0.0156 - val_accuracy: 0.7795 - val_loss: 1.0103 - learning_rate: 2.3730e-04
# Epoch 43/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9977 - loss: 0.0139 - val_accuracy: 0.7880 - val_loss: 0.9816 - learning_rate: 1.7798e-04
# Epoch 44/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9989 - loss: 0.0111 - val_accuracy: 0.7868 - val_loss: 0.9782 - learning_rate: 1.7798e-04
# Epoch 45/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9989 - loss: 0.0100
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9989 - loss: 0.0101 - val_accuracy: 0.7884 - val_loss: 0.9701 - learning_rate: 1.7798e-04
# Epoch 46/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9993 - loss: 0.0086 - val_accuracy: 0.7900 - val_loss: 0.9648 - learning_rate: 1.3348e-04
# Epoch 47/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9996 - loss: 0.0087 - val_accuracy: 0.7910 - val_loss: 0.9667 - learning_rate: 1.3348e-04
# Epoch 48/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9996 - loss: 0.0081
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9996 - loss: 0.0082 - val_accuracy: 0.7884 - val_loss: 0.9918 - learning_rate: 1.3348e-04
# Epoch 49/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9993 - loss: 0.0090 - val_accuracy: 0.7907 - val_loss: 0.9702 - learning_rate: 1.0011e-04
# Epoch 50/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9993 - loss: 0.0082 - val_accuracy: 0.7859 - val_loss: 0.9814 - learning_rate: 1.0011e-04
# Epoch 51/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9994 - loss: 0.0074
# Epoch 51: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9994 - loss: 0.0075 - val_accuracy: 0.7912 - val_loss: 0.9639 - learning_rate: 1.0011e-04
# Epoch 52/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9994 - loss: 0.0070 - val_accuracy: 0.7850 - val_loss: 0.9978 - learning_rate: 7.5085e-05
# Epoch 53/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9993 - loss: 0.0086 - val_accuracy: 0.7894 - val_loss: 0.9777 - learning_rate: 7.5085e-05
# Epoch 54/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9996 - loss: 0.0067
# Epoch 54: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9996 - loss: 0.0068 - val_accuracy: 0.7896 - val_loss: 0.9805 - learning_rate: 7.5085e-05
# Epoch 55/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9997 - loss: 0.0064 - val_accuracy: 0.7889 - val_loss: 0.9841 - learning_rate: 5.6314e-05
# Epoch 56/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9997 - loss: 0.0064 - val_accuracy: 0.7891 - val_loss: 0.9815 - learning_rate: 5.6314e-05
# Epoch 57/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9997 - loss: 0.0059
# Epoch 57: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9997 - loss: 0.0060 - val_accuracy: 0.7891 - val_loss: 0.9826 - learning_rate: 5.6314e-05
# Epoch 58/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9998 - loss: 0.0060 - val_accuracy: 0.7887 - val_loss: 0.9842 - learning_rate: 4.2235e-05
# Epoch 59/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9996 - loss: 0.0059 - val_accuracy: 0.7882 - val_loss: 0.9872 - learning_rate: 4.2235e-05
# Epoch 60/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9998 - loss: 0.0053
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9998 - loss: 0.0054 - val_accuracy: 0.7882 - val_loss: 0.9871 - learning_rate: 4.2235e-05
# Epoch 60: early stopping
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step
# Time elapsed: 1:17:41.868973
# Running fold: 3
# Epoch 1/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 28s 356ms/step - accuracy: 0.1864 - loss: 3.3058 - val_accuracy: 0.1937 - val_loss: 2.7817 - learning_rate: 0.0010
# Epoch 2/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 354ms/step - accuracy: 0.3276 - loss: 2.2343 - val_accuracy: 0.1972 - val_loss: 2.7907 - learning_rate: 0.0010
# Epoch 3/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.4177 - loss: 1.8589 - val_accuracy: 0.2632 - val_loss: 2.5429 - learning_rate: 0.0010
# Epoch 4/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.4805 - loss: 1.6159 - val_accuracy: 0.3486 - val_loss: 2.2071 - learning_rate: 0.0010
# Epoch 5/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.5446 - loss: 1.3948 - val_accuracy: 0.4496 - val_loss: 1.8258 - learning_rate: 0.0010
# Epoch 6/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.5944 - loss: 1.2244 - val_accuracy: 0.5204 - val_loss: 1.6153 - learning_rate: 0.0010
# Epoch 7/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.6442 - loss: 1.0996 - val_accuracy: 0.5652 - val_loss: 1.4198 - learning_rate: 0.0010
# Epoch 8/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.6848 - loss: 0.9522 - val_accuracy: 0.6143 - val_loss: 1.2662 - learning_rate: 0.0010
# Epoch 9/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.7171 - loss: 0.8616 - val_accuracy: 0.6363 - val_loss: 1.2147 - learning_rate: 0.0010
# Epoch 10/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.7326 - loss: 0.8219 - val_accuracy: 0.6358 - val_loss: 1.2130 - learning_rate: 0.0010
# Epoch 11/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.7670 - loss: 0.7122 - val_accuracy: 0.6571 - val_loss: 1.2489 - learning_rate: 0.0010
# Epoch 12/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.7870 - loss: 0.6671 - val_accuracy: 0.6276 - val_loss: 1.2954 - learning_rate: 0.0010
# Epoch 13/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8030 - loss: 0.6056
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8030 - loss: 0.6060 - val_accuracy: 0.6530 - val_loss: 1.2477 - learning_rate: 0.0010
# Epoch 14/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.8171 - loss: 0.5452 - val_accuracy: 0.7085 - val_loss: 1.0520 - learning_rate: 7.5000e-04
# Epoch 15/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.8559 - loss: 0.4422 - val_accuracy: 0.7215 - val_loss: 0.9861 - learning_rate: 7.5000e-04
# Epoch 16/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8750 - loss: 0.3936 - val_accuracy: 0.7265 - val_loss: 0.9394 - learning_rate: 7.5000e-04
# Epoch 17/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8915 - loss: 0.3452 - val_accuracy: 0.7347 - val_loss: 0.9699 - learning_rate: 7.5000e-04
# Epoch 18/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8974 - loss: 0.3292 - val_accuracy: 0.7121 - val_loss: 0.9649 - learning_rate: 7.5000e-04
# Epoch 19/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9064 - loss: 0.2938
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9064 - loss: 0.2940 - val_accuracy: 0.7094 - val_loss: 1.0797 - learning_rate: 7.5000e-04
# Epoch 20/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9127 - loss: 0.2801 - val_accuracy: 0.7265 - val_loss: 1.0009 - learning_rate: 5.6250e-04
# Epoch 21/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9286 - loss: 0.2395 - val_accuracy: 0.7311 - val_loss: 1.0201 - learning_rate: 5.6250e-04
# Epoch 22/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9361 - loss: 0.2059
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9360 - loss: 0.2062 - val_accuracy: 0.7377 - val_loss: 0.9776 - learning_rate: 5.6250e-04
# Epoch 23/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9407 - loss: 0.1933 - val_accuracy: 0.7585 - val_loss: 0.9234 - learning_rate: 4.2187e-04
# Epoch 24/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9562 - loss: 0.1521 - val_accuracy: 0.7494 - val_loss: 0.9762 - learning_rate: 4.2187e-04
# Epoch 25/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9639 - loss: 0.1325 - val_accuracy: 0.7478 - val_loss: 0.9777 - learning_rate: 4.2187e-04
# Epoch 26/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9656 - loss: 0.1162
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9656 - loss: 0.1163 - val_accuracy: 0.7594 - val_loss: 0.9731 - learning_rate: 4.2187e-04
# Epoch 27/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9714 - loss: 0.1038 - val_accuracy: 0.7560 - val_loss: 1.0219 - learning_rate: 3.1641e-04
# Epoch 28/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9775 - loss: 0.0875 - val_accuracy: 0.7599 - val_loss: 1.0169 - learning_rate: 3.1641e-04
# Epoch 29/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9787 - loss: 0.0805
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9786 - loss: 0.0806 - val_accuracy: 0.7667 - val_loss: 0.9837 - learning_rate: 3.1641e-04
# Epoch 30/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9836 - loss: 0.0672 - val_accuracy: 0.7546 - val_loss: 0.9994 - learning_rate: 2.3730e-04
# Epoch 31/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9878 - loss: 0.0579 - val_accuracy: 0.7706 - val_loss: 0.9461 - learning_rate: 2.3730e-04
# Epoch 32/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9884 - loss: 0.0537
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9883 - loss: 0.0537 - val_accuracy: 0.7718 - val_loss: 0.9732 - learning_rate: 2.3730e-04
# Epoch 33/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9907 - loss: 0.0460 - val_accuracy: 0.7635 - val_loss: 1.0151 - learning_rate: 1.7798e-04
# Epoch 34/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9931 - loss: 0.0394 - val_accuracy: 0.7688 - val_loss: 0.9865 - learning_rate: 1.7798e-04
# Epoch 35/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9931 - loss: 0.0374
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9931 - loss: 0.0375 - val_accuracy: 0.7647 - val_loss: 1.0222 - learning_rate: 1.7798e-04
# Epoch 36/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9941 - loss: 0.0352 - val_accuracy: 0.7772 - val_loss: 0.9703 - learning_rate: 1.3348e-04
# Epoch 37/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9940 - loss: 0.0312 - val_accuracy: 0.7697 - val_loss: 0.9731 - learning_rate: 1.3348e-04
# Epoch 38/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9962 - loss: 0.0271
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9962 - loss: 0.0271 - val_accuracy: 0.7807 - val_loss: 0.9610 - learning_rate: 1.3348e-04
# Epoch 39/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9974 - loss: 0.0238 - val_accuracy: 0.7809 - val_loss: 0.9543 - learning_rate: 1.0011e-04
# Epoch 40/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9968 - loss: 0.0228 - val_accuracy: 0.7852 - val_loss: 0.9474 - learning_rate: 1.0011e-04
# Epoch 41/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9975 - loss: 0.0219
# Epoch 41: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9975 - loss: 0.0220 - val_accuracy: 0.7852 - val_loss: 0.9403 - learning_rate: 1.0011e-04
# Epoch 42/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9985 - loss: 0.0192 - val_accuracy: 0.7862 - val_loss: 0.9472 - learning_rate: 7.5085e-05
# Epoch 43/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9983 - loss: 0.0180 - val_accuracy: 0.7848 - val_loss: 0.9435 - learning_rate: 7.5085e-05
# Epoch 44/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9990 - loss: 0.0167
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9990 - loss: 0.0168 - val_accuracy: 0.7864 - val_loss: 0.9624 - learning_rate: 7.5085e-05
# Epoch 45/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.9986 - loss: 0.0163 - val_accuracy: 0.7830 - val_loss: 0.9668 - learning_rate: 5.6314e-05
# Epoch 46/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9993 - loss: 0.0155 - val_accuracy: 0.7846 - val_loss: 0.9684 - learning_rate: 5.6314e-05
# Epoch 47/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9990 - loss: 0.0147
# Epoch 47: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9990 - loss: 0.0147 - val_accuracy: 0.7827 - val_loss: 0.9693 - learning_rate: 5.6314e-05
# Epoch 48/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.9991 - loss: 0.0148 - val_accuracy: 0.7855 - val_loss: 0.9624 - learning_rate: 4.2235e-05
# Epoch 49/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9992 - loss: 0.0146 - val_accuracy: 0.7855 - val_loss: 0.9719 - learning_rate: 4.2235e-05
# Epoch 50/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9990 - loss: 0.0142
# Epoch 50: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9990 - loss: 0.0142 - val_accuracy: 0.7850 - val_loss: 0.9712 - learning_rate: 4.2235e-05
# Epoch 51/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9995 - loss: 0.0133 - val_accuracy: 0.7846 - val_loss: 0.9760 - learning_rate: 3.1676e-05
# Epoch 52/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.9995 - loss: 0.0123 - val_accuracy: 0.7855 - val_loss: 0.9746 - learning_rate: 3.1676e-05
# Epoch 53/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9993 - loss: 0.0130
# Epoch 53: ReduceLROnPlateau reducing learning rate to 2.3757263079460245e-05.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 365ms/step - accuracy: 0.9993 - loss: 0.0131 - val_accuracy: 0.7855 - val_loss: 0.9836 - learning_rate: 3.1676e-05
# Epoch 53: early stopping
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step
# Time elapsed: 1:39:29.599845
# Running fold: 4
# Epoch 1/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 28s 359ms/step - accuracy: 0.1842 - loss: 3.2550 - val_accuracy: 0.2221 - val_loss: 2.5241 - learning_rate: 0.0010
# Epoch 2/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.3210 - loss: 2.2658 - val_accuracy: 0.1997 - val_loss: 2.6645 - learning_rate: 0.0010
# Epoch 3/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.4025 - loss: 1.9049 - val_accuracy: 0.2509 - val_loss: 2.6513 - learning_rate: 0.0010
# Epoch 4/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.4705 - loss: 1.6351 - val_accuracy: 0.2842 - val_loss: 2.3675 - learning_rate: 0.0010
# Epoch 5/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.5207 - loss: 1.4667 - val_accuracy: 0.4469 - val_loss: 1.7757 - learning_rate: 0.0010
# Epoch 6/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.5910 - loss: 1.2615 - val_accuracy: 0.5307 - val_loss: 1.4879 - learning_rate: 0.0010
# Epoch 7/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.6338 - loss: 1.0970 - val_accuracy: 0.5846 - val_loss: 1.3124 - learning_rate: 0.0010
# Epoch 8/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.6834 - loss: 0.9768 - val_accuracy: 0.6075 - val_loss: 1.2380 - learning_rate: 0.0010
# Epoch 9/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.7176 - loss: 0.8752 - val_accuracy: 0.6084 - val_loss: 1.2591 - learning_rate: 0.0010
# Epoch 10/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.7226 - loss: 0.8448 - val_accuracy: 0.6345 - val_loss: 1.1897 - learning_rate: 0.0010
# Epoch 11/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.7504 - loss: 0.7614 - val_accuracy: 0.6516 - val_loss: 1.1333 - learning_rate: 0.0010
# Epoch 12/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.7907 - loss: 0.6669 - val_accuracy: 0.6534 - val_loss: 1.1245 - learning_rate: 0.0010
# Epoch 13/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.8039 - loss: 0.6119 - val_accuracy: 0.6626 - val_loss: 1.1533 - learning_rate: 0.0010
# Epoch 14/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.8045 - loss: 0.6136 - val_accuracy: 0.6877 - val_loss: 1.0773 - learning_rate: 0.0010
# Epoch 15/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 359ms/step - accuracy: 0.8270 - loss: 0.5333 - val_accuracy: 0.6792 - val_loss: 1.1047 - learning_rate: 0.0010
# Epoch 16/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.8395 - loss: 0.4973 - val_accuracy: 0.6929 - val_loss: 1.0354 - learning_rate: 0.0010
# Epoch 17/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 360ms/step - accuracy: 0.8597 - loss: 0.4375 - val_accuracy: 0.7215 - val_loss: 0.9610 - learning_rate: 0.0010
# Epoch 18/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.8757 - loss: 0.3924 - val_accuracy: 0.6950 - val_loss: 1.0450 - learning_rate: 0.0010
# Epoch 19/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.8790 - loss: 0.3825 - val_accuracy: 0.7208 - val_loss: 0.9695 - learning_rate: 0.0010
# Epoch 20/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8951 - loss: 0.3363
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.8950 - loss: 0.3366 - val_accuracy: 0.6849 - val_loss: 1.1613 - learning_rate: 0.0010
# Epoch 21/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 359ms/step - accuracy: 0.8987 - loss: 0.3163 - val_accuracy: 0.7366 - val_loss: 0.9720 - learning_rate: 7.5000e-04
# Epoch 22/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 359ms/step - accuracy: 0.9160 - loss: 0.2669 - val_accuracy: 0.7363 - val_loss: 1.0320 - learning_rate: 7.5000e-04
# Epoch 23/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.9334 - loss: 0.2215 - val_accuracy: 0.7544 - val_loss: 0.9035 - learning_rate: 7.5000e-04
# Epoch 24/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.9520 - loss: 0.1683 - val_accuracy: 0.7400 - val_loss: 1.0019 - learning_rate: 7.5000e-04
# Epoch 25/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 360ms/step - accuracy: 0.9488 - loss: 0.1760 - val_accuracy: 0.7439 - val_loss: 0.9857 - learning_rate: 7.5000e-04
# Epoch 26/90
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9580 - loss: 0.1462

# %% [markdown]
# ### Plot loss and accuracy

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    plot_loss_acc(len(model_data.history["loss"]), model_data.history["loss"],
                              [acc * 100.0 for acc in model_data.history["accuracy"]],
                              model_data.history["val_loss"],
                              [acc * 100.0 for acc in model_data.history["val_accuracy"]], str(k))

# %% [markdown]
# ### Plot Confusion matrix

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    plot_confusion_matrix(y_pred, y_valid, k, ACTIVITY_NAMES)

# %% [markdown]
# ### Accuracy Per Fold

# %%
print("Validation Accuracy fold wise")
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    val_acc = np.around(100.0 * model_data.history["val_accuracy"][-1], 2)
    print(f"fold {k}: {val_acc}")

# %% [markdown]
# ### Classification metric

# %%
for k in training_data.keys():
    # F1 score
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    print(f"Classification report for fold {k}")
    print(classification_report(y_true=y_valid,
                                y_pred=y_pred))

# %% [markdown]
# ## Training on watch gyroscope sensor

# %% [markdown]
# ### Hyper parameters

# %%
ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "typing", "brushing teeth",
                  "eating soup", "eating chips", "eating pasta", "drinking from cup", "eating sandwich",
                  "kicking soccer ball", "playing catch tennis ball", "dribbling basket ball",
                  "writing", "clapping", "folding clothes"]
NUM_EPOCHS = 90
MIN_EPOCHS = 27
BATCH_SIZE = 256
WINDOW_SIZE=200
STEP_SIZE=100
NN_NET = gru_net
DATA_DIR="../dataset/raw/watch/gyro"

# %% [markdown]
# ### Initialize Dataset

# %%
options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.OFF
activity_code, cat_len = get_activity_code(ACTIVITY_NAMES)
# Dataset
train_ds, target_ds = WISDM_Dataset(data_dir = DATA_DIR,
                                      window_size = WINDOW_SIZE,
                                      step_size = STEP_SIZE,
                                      activity_code = activity_code)
k_fold = StratifiedKFold(n_splits = NUM_FOLDS,
                           shuffle = True)

# %% [markdown]
# ### Model Summary

# %%
model = NN_NET(train_ds, cat_len)
print(model.summary())

# %% [markdown]
# ### Training

# %%
training_data = train(nn_net=NN_NET,
                      cat_len=cat_len,
                      batch_size=BATCH_SIZE,
                      num_epochs=NUM_EPOCHS,
                      min_epochs=MIN_EPOCHS,
                      k_fold=k_fold,
                      train_ds=train_ds,
                      target_ds=target_ds)

# %% [markdown]
# ### Plot loss and accuracy

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    plot_loss_acc(len(model_data.history["loss"]), model_data.history["loss"],
                              [acc * 100.0 for acc in model_data.history["accuracy"]],
                              model_data.history["val_loss"],
                              [acc * 100.0 for acc in model_data.history["val_accuracy"]], str(k))

# %% [markdown]
# ### Plot Confusion matrix

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    plot_confusion_matrix(y_pred, y_valid, k, ACTIVITY_NAMES)

# %% [markdown]
# ### Accuracy Per Fold

# %%
print("Validation Accuracy fold wise")
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    val_acc = np.around(100.0 * model_data.history["val_accuracy"][-1], 2)
    print(f"fold {k}: {val_acc}")

# %% [markdown]
# ### Classification metric

# %%
for k in training_data.keys():
    # F1 score
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    print(f"Classification report for fold {k}")
    print(classification_report(y_true=y_valid,
                                y_pred=y_pred))
