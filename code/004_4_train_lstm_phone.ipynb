# %% [markdown]
# # Detecting Human Activities Through Smartphone Sensor - Training

# %% [markdown]
# ## Imports

# %%
# TF related imports
import tensorflow as tf
from tensorflow.keras.models import Model
import tensorflow.keras.layers as layer
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

#scikit related imports
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# other generic imports
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from mlxtend import plotting
from tqdm import tqdm
from datetime import timedelta
import time
# Out:
# 2024-11-20 14:37:42.000001: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-20 14:37:42.014668: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-20 14:37:42.019132: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-20 14:37:42.030590: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-20 14:37:42.821111: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Global Variables

# %%
# global variables
PBAR_FORMAT='{desc:12} {percentage:3.0f}%|{bar:27}| [ {n:4d}/{total:4d}, {elapsed}<{remaining}{postfix} ]'

ACTIVITY_CODES_MAPPING = {'A': 'walking',
                          'B': 'jogging',
                          'C': 'stairs',
                          'D': 'sitting',
                          'E': 'standing',
                          'F': 'typing',
                          'G': 'brushing teeth',
                          'H': 'eating soup',
                          'I': 'eating chips',
                          'J': 'eating pasta',
                          'K': 'drinking from cup',
                          'L': 'eating sandwich',
                          'M': 'kicking soccer ball',
                          'O': 'playing catch tennis ball',
                          'P': 'dribbling basket ball',
                          'Q': 'writing',
                          'R': 'clapping',
                          'S': 'folding clothes'}
# csv file column names
COL_NAMES =  ['id' , 'activity_code' , 'timestamp', 'x', 'y', 'z']
# training verbose
VERBOSE = 1
# rnadom state for split
RANDOM_STATE=12345

# %% [markdown]
# ## Dataset, Model and Trainer

# %% [markdown]
# ### Helper functions

# %%
def get_activity_code(activity_names):
    cat_len=len(activity_names)
    activity_code={}
    for idx, an in enumerate(activity_names):
        for k in ACTIVITY_CODES_MAPPING.keys() :
            if ACTIVITY_CODES_MAPPING[k]==an:
                key = k
        activity_code[key]=idx
    
    assert(len(activity_code.keys())== cat_len)
    
    print(f"{activity_code}")
    print(f"Number of Categories {cat_len}")
    return activity_code, cat_len

def sliding_window(dataset, window_size, step_size):  
    x_list, y_list, z_list = [], [], []
    targets_list = []
    for i in range(0, dataset.shape[0] - window_size, step_size):
        x_list.append(dataset["x"].values[i: i + window_size])
        y_list.append(dataset["y"].values[i: i + window_size])
        z_list.append(dataset["z"].values[i: i + window_size])
        targets_list.append(stats.mode(dataset["activity_code"][i: i + window_size])[0])

    feature_list = [x_list, y_list, z_list]

    feature_list = [np.array(data_list) for data_list in feature_list]
    dataset = np.stack(feature_list, axis = 2)

    return dataset, targets_list

# %% [markdown]
# ### Dataset

# %%
def WISDM_Dataset(dir, window_size, step_size, activity_code):
    window_size = window_size
    step_size = step_size
    path = dir
    column_names = COL_NAMES
    activity_dic = activity_code
    filelist_train = sorted([txt for txt in os.listdir(path + "/") if txt[-4:] == ".txt"])
    columns = ["x", "y", "z"]
        
    # Training data
    dataset_train = pd.DataFrame()

    for txt in tqdm(filelist_train, desc="loading data", bar_format=PBAR_FORMAT):
        dataset_tmp = pd.read_csv(path + '/' + txt, header = None, names = column_names, comment = ";")
        for k in activity_dic.keys():
            df_tmp = dataset_tmp[dataset_tmp['activity_code']==k][0:2400]
            dataset_train = pd.concat([dataset_train, df_tmp])
    print(dataset_train)

    # normalize the data
    dataset_train["activity_code"] = dataset_train["activity_code"].map(activity_dic)
    labels = dataset_train["activity_code"].to_numpy()

    scaler = RobustScaler()
    dataset_train = scaler.fit_transform(dataset_train[["x", "y", "z"]])
    dataset_train = pd.DataFrame(data = dataset_train, columns = ["x", "y", "z"])
    dataset_train["activity_code"] = labels
    
    # feature engineering
    dataset_train, targets_list = sliding_window(dataset_train, window_size, step_size)
    targets = np.array(targets_list)
    return dataset_train, targets

# %% [markdown]
# ### Model

# %%
def lstm_net(data, num_classes):
    x_input = layer.Input(shape = (data.shape[-2:]))

    x = layer.Bidirectional(layer.LSTM(256, return_sequences = True))(x_input)
    x = layer.BatchNormalization()(x)
    x = layer.Bidirectional(layer.LSTM(128, return_sequences = True))(x)
    x = layer.BatchNormalization()(x)

    x = layer.Flatten()(x)

    x = layer.Dense(128, activation = "relu")(x)
    x = layer.BatchNormalization()(x)
    x = layer.Dropout(0.5)(x)
    x_output = layer.Dense(num_classes, activation = "softmax")(x)

    model = Model(inputs = x_input, outputs = x_output, name = "LSTM_NET")

    return model

# %% [markdown]
# ### Plotting function

# %%
def plot_loss_acc(epochs, train_losses, train_acc, test_losses, test_acc, fold):
    fig, ax1 = plt.subplots()
    xaxis = list(range(1, epochs + 1))
    plt_train_loss = ax1.plot(xaxis, train_losses, label = "Training Loss", color="red")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2 = ax1.twinx()
    plt_train_acc = ax2.plot(xaxis, train_acc, label = "Training Accuracy", color="green")
    ax2.set_ylabel("Accuracy in %")
    ax2.set_ylim(0.0, 100.0)

    plt_val_loss = ax1.plot(xaxis, test_losses, label = "Validation Loss", color="firebrick")
    plt_val_acc = ax2.plot(xaxis, test_acc, label = "Validation Accuracy", color="limegreen")

    lines = plt_train_loss + plt_train_acc + plt_val_loss + plt_val_acc
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels)
    fold = " Fold " + str(fold) 
    plt.title("Loss and Accuracy" + fold)
    plt.show()

def plot_confusion_matrix(y_pred, y_valid, fold):
    conf_matrix = confusion_matrix(y_valid, y_pred)
    plotting.plot_confusion_matrix(conf_mat = conf_matrix,
                                   class_names = ACTIVITY_NAMES,
                                   show_normed = True,
                                   figsize = (10, 7),
                                   colorbar = True)
    plt.title("Confusion matrix Fold " + str(fold))
    plt.show()

# %% [markdown]
# ### Trainer function

# %%
def train(nn_net, cat_len, batch_size, num_epochs, k_fold, train_ds, target_ds):
    val_acc_last = []
    
    training_data={}
    start_time = time.time()
    for fold, (train_index, test_index) in enumerate(k_fold.split(train_ds, target_ds)):
        print(f"Running fold: {fold}")
        x_train, x_valid = train_ds[train_index], train_ds[test_index]
        y_train, y_valid = target_ds[train_index], target_ds[test_index]
        
        # convert to tf dataset
        train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(batch_size).with_options(options)
        valid_data = tf.data.Dataset.from_tensor_slices((x_valid, y_valid)).batch(batch_size).with_options(options)
        
        model = nn_net(train_ds, cat_len)
        
        model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
        
        learning_rate = ReduceLROnPlateau(monitor = "val_loss", factor = 0.5, patience = 5, verbose = VERBOSE)
        early_stopping = EarlyStopping(monitor = "val_loss", patience = 10, verbose = VERBOSE, mode = "min", 
                                       restore_best_weights = True)
        
        # model training
        model_data = model.fit(train_data, 
                                validation_data = valid_data, 
                                epochs = num_epochs,
                                verbose = VERBOSE,
                                batch_size = BATCH_SIZE, 
                                callbacks = [learning_rate, early_stopping])        
        val_acc_last.append(np.around(100.0 * model_data.history["val_accuracy"][-1], 2))

        y_pred = np.argmax(model.predict(valid_data, batch_size = BATCH_SIZE), axis = 1)

        training_data[fold] = {'model_data':model_data,
                               'y_pred': y_pred, 
                               'y_valid':y_valid}
        print(f'Time elapsed: {timedelta(microseconds=int((time.time()-start_time)*1000000))}')
    
    print(f'Total Training Time: {timedelta(seconds=int(time.time()-start_time))}')
    print("Val Acc per fold:", val_acc_last)
    return training_data

# %% [markdown]
# ## Training on phone accelerometer

# %% [markdown]
# ### Hyper parameters

# %%
#ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "kicking soccer ball"]
ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "typing", "brushing teeth",
                  "eating soup", "drinking from cup", 
                  "kicking soccer ball", "playing catch tennis ball", "dribbling basket ball", 
                  "writing", "clapping", "folding clothes"]
NUM_EPOCHS = 90
BATCH_SIZE = 256
WINDOW_SIZE=200
STEP_SIZE=100
NUM_SPLITS=5
NN_NET = lstm_net
DATA_DIR="../dataset/raw/phone/accel"

# %% [markdown]
# ### Initialize Dataset

# %%
options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.OFF
activity_code, cat_len = get_activity_code(ACTIVITY_NAMES)
# Dataset
train_ds, target_ds = WISDM_Dataset(dir = DATA_DIR,
                              window_size = WINDOW_SIZE,
                              step_size = STEP_SIZE,
                              activity_code = activity_code)
k_fold = KFold(n_splits = NUM_SPLITS,
           shuffle = True,
           random_state = RANDOM_STATE)
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'K': 8, 'M': 9, 'O': 10, 'P': 11, 'Q': 12, 'R': 13, 'S': 14}
# Number of Categories 15
# loading data 100%|███████████████████████████| [   51/  51, 00:15<00:00 ]
#           id activity_code        timestamp         x          y         z
# 0       1600             A  252207666810782 -0.364761   8.793503  1.055084
# 1       1600             A  252207717164786 -0.879730   9.768784  1.016998
# 2       1600             A  252207767518790  2.001495  11.109070  2.619156
# 3       1600             A  252207817872794  0.450623  12.651642  0.184555
# 4       1600             A  252207868226798 -2.164352  13.928436 -4.422485
# ...      ...           ...              ...       ...        ...       ...
# 154242  1650             S  357602446012000 -8.763377  -3.745811 -2.277664
# 154243  1650             S  357602466108000 -8.895103  -3.717071 -2.919529
# 154244  1650             S  357602486288000 -8.631651  -3.836822 -3.475173
# 154245  1650             S  357602506384000 -8.270002  -4.102669 -2.859653
# 154246  1650             S  357602526598000 -8.183782  -4.315825 -1.733994
#
# [1821600 rows x 6 columns]

# %% [markdown]
# ### Model Summary

# %%
model = NN_NET(train_ds, cat_len)
print(model.summary())
# Out:
# 2024-11-20 14:38:07.965765: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6634 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:65:00.0, compute capability: 7.5
# Model: "LSTM_NET"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 200, 512)       │       532,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 200, 256)       │       656,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 200, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     6,553,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 15)             │         1,935 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,748,111 (29.56 MB)
#  Trainable params: 7,746,319 (29.55 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# None

# %% [markdown]
# ### Training

# %%
training_data = train(nn_net=NN_NET,
                      cat_len=cat_len,
                      batch_size=BATCH_SIZE,
                      num_epochs=NUM_EPOCHS,
                      k_fold=k_fold,
                      train_ds=train_ds,
                      target_ds=target_ds)
# Out:
# Running fold: 0
# Epoch 1/90
# 2024-11-20 14:38:12.644085: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 12s 134ms/step - accuracy: 0.1066 - loss: 3.8504 - val_accuracy: 0.0920 - val_loss: 2.6128 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0.1035 - loss: 3.1900 - val_accuracy: 0.1054 - val_loss: 2.6561 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - accuracy: 0
- learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2038 - loss: 2.3254 - val_accuracy: 0.2020 - val_loss: 2.1839 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2471 - loss: 2.1545 - val_accuracy: 0.2306 - val_loss: 2.1414 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2528 - loss: 2.1143 - val_accuracy: 0.1696 - val_loss: 2.2065 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2075 - loss: 2.1999 - val_accuracy: 0.1987 - val_loss: 2.1556 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2501 - loss: 2.0348 - val_accuracy: 0.2366 - val_loss: 2.0493 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2700 - loss: 1.9680 - val_accuracy: 0.2418 - val_loss: 2.0462 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3097 - loss: 1.8759 - val_accuracy: 0.2767 - val_loss: 2.0168 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3220 - loss: 1.8287 - val_accuracy: 0.2814 - val_loss: 1.9901 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.3587 - loss: 1.7407 - val_accuracy: 0.2632 - val_loss: 2.0284 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3812 - loss: 1.6848 - val_accuracy: 0.2825 - val_loss: 1.9654 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3944 - loss: 1.6208 - val_accuracy: 0.2921 - val_loss: 1.9006 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4086 - loss: 1.5879 - val_accuracy: 0.3220 - val_loss: 1.8801 - learning_rate: 0.0010
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4400 - loss: 1.5042 - val_accuracy: 0.2945 - val_loss: 2.0203 - learning_rate: 0.0010
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4408 - loss: 1.5243 - val_accuracy: 0.2720 - val_loss: 2.1039 - learning_rate: 0.0010
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4382 - loss: 1.5029 - val_accuracy: 0.2438 - val_loss: 2.0486 - learning_rate: 0.0010
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4047 - loss: 1.6001 - val_accuracy: 0.2470 - val_loss: 2.2731 - learning_rate: 0.0010
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3946 - loss: 1.6808
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3947 - loss: 1.6805 - val_accuracy: 0.2899 - val_loss: 2.0382 - learning_rate: 0.0010
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.4546 - loss: 1.4759 - val_accuracy: 0.3149 - val_loss: 1.8427 - learning_rate: 5.0000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5281 - loss: 1.2972 - val_accuracy: 0.3354 - val_loss: 1.8447 - learning_rate: 5.0000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5289 - loss: 1.3081 - val_accuracy: 0.3253 - val_loss: 1.8876 - learning_rate: 5.0000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5252 - loss: 1.3187 - val_accuracy: 0.3242 - val_loss: 1.8540 - learning_rate: 5.0000e-04
# Epoch 30/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5720 - loss: 1.1891 - val_accuracy: 0.3302 - val_loss: 1.8569 - learning_rate: 5.0000e-04
# Epoch 31/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6189 - loss: 1.1016 - val_accuracy: 0.3525 - val_loss: 1.8393 - learning_rate: 5.0000e-04
# Epoch 32/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6575 - loss: 1.0109 - val_accuracy: 0.3478 - val_loss: 1.8464 - learning_rate: 5.0000e-04
# Epoch 33/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.6747 - loss: 0.9433 - val_accuracy: 0.3472 - val_loss: 1.9003 - learning_rate: 5.0000e-04
# Epoch 34/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7086 - loss: 0.8831 - val_accuracy: 0.3431 - val_loss: 1.8945 - learning_rate: 5.0000e-04
# Epoch 35/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7318 - loss: 0.8251 - val_accuracy: 0.3610 - val_loss: 1.9199 - learning_rate: 5.0000e-04
# Epoch 36/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7395 - loss: 0.8038
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7392 - loss: 0.8044 - val_accuracy: 0.3341 - val_loss: 1.9368 - learning_rate: 5.0000e-04
# Epoch 37/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7295 - loss: 0.8086 - val_accuracy: 0.3396 - val_loss: 2.0271 - learning_rate: 2.5000e-04
# Epoch 38/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8017 - loss: 0.6514 - val_accuracy: 0.3379 - val_loss: 2.0526 - learning_rate: 2.5000e-04
# Epoch 39/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8150 - loss: 0.6088 - val_accuracy: 0.3297 - val_loss: 2.0605 - learning_rate: 2.5000e-04
# Epoch 40/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.
# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    plot_loss_acc(len(model_data.history["loss"]), model_data.history["loss"], 
                              [acc * 100.0 for acc in model_data.history["accuracy"]], 
                              model_data.history["val_loss"], 
                              [acc * 100.0 for acc in model_data.history["val_accuracy"]], str(k))

# %% [markdown]
# ### Plot Confusion matrix

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    plot_confusion_matrix(y_pred, y_valid, k)

# %% [markdown]
# ### Accuracy Per Fold

# %%
print("Validation Accuracy fold wise")
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    val_acc = np.around(100.0 * model_data.history["val_accuracy"][-1], 2)
    print(f"fold {k}: {val_acc}")
# Out:
# Validation Accuracy fold wise
# fold 0: 26.6
# fold 1: 33.63
# fold 2: 31.62
# fold 3: 28.55
# fold 4: 30.83

# %% [markdown]
# ### Classification metric

# %%
for k in training_data.keys():
    # F1 score
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    print(f"Classification report for fold {k}")
    print(classification_report(y_true=y_valid,
                                y_pred=y_pred))
# Out:
# Classification report for fold 0
#               precision    recall  f1-score   support
#
#            0       0.54      0.45      0.49       244
#            1       0.61      0.96      0.75       227
#            2       0.40      0.31      0.35       229
#            3       0.17      0.24      0.20       280
#            4       0.24      0.39      0.30       238
#            5       0.18      0.19      0.18       242
#            6       0.07      0.05      0.06       221
#            7       0.08      0.07      0.07       235
#            8       0.23      0.01      0.02       275
#            9       0.44      0.33      0.38       256
#           10       0.26      0.18      0.22       226
#           11       0.25      0.44      0.32       226
#           12       0.13      0.08      0.10       244
#           13       0.17      0.24      0.20       253
#           14       0.29      0.27      0.28       247
#
#     accuracy                           0.28      3643
#    macro avg       0.27      0.28      0.26      3643
# weighted avg       0.27      0.28      0.26      3643
#
# Classification report for fold 1
#               precision    recall  f1-score   support
#
#            0       0.49      0.73      0.58       246
#            1       0.86      0.88      0.87       217
#            2       0.49      0.49      0.49       245
#            3       0.15      0.15      0.15       229
#            4       0.39      0.61      0.47       246
#            5       0.14      0.09      0.11       246
#            6       0.19      0.21      0.20       243
#            7       0.17      0.02      0.04       263
#            8       0.15      0.14      0.15       223
#            9       0.49      0.37      0.42       229
#           10       0.31      0.30      0.30       226
#           11       0.45      0.36      0.40       240
#           12       0.23      0.19      0.21       248
#           13       0.25      0.38      0.30       280
#           14       0.35      0.40      0.38       262
#
#     accuracy                           0.35      3643
#    macro avg       0.34      0.36      0.34      3643
# weighted avg       0.34      0.35      0.33      3643
#
# Classification report for fold 2
#               precision    recall  f1-score   support
#
#            0       0.49      0.64      0.56       261
#            1       0.81      0.87      0.84       226
#            2       0.52      0.29      0.37       261
#            3       0.15      0.20      0.17       236
#            4       0.31      0.46      0.37       248
#            5       0.16      0.18      0.16       222
#            6       0.19      0.25      0.22       243
#            7       0.07      0.08      0.07       233
#            8       0.23      0.08      0.12       259
#            9       0.41      0.44      0.42       243
#           10       0.27      0.20      0.23       262
#           11       0.27      0.29      0.28       246
#           12       0.24      0.16      0.19       253
#           13       0.14      0.20      0.16       224
#           14       0.13      0.05      0.08       226
#
#     accuracy                           0.29      3643
#    macro avg       0.29      0.29      0.28      3643
# weighted avg       0.29      0.29      0.28      3643
#
# Classification report for fold 3
#               precision    recall  f1-score   support
#
#            0       0.43      0.46      0.44       265
#            1       0.61      0.77      0.68       267
#            2       0.34      0.23      0.28       214
#            3       0.17      0.32      0.23       251
#            4       0.37      0.58      0.45       246
#            5       0.10      0.10      0.10       232
#            6       0.14      0.09      0.11       256
#            7       0.21      0.06      0.10       253
#            8       0.16      0.10      0.13       211
#            9       0.31      0.42      0.35       242
#           10       0.33      0.20      0.25       259
#           11       0.41      0.24      0.30       263
#           12       0.15      0.26      0.19       239
#           13       0.11      0.06      0.08       230
#           14       0.22      0.23      0.22       215
#
#     accuracy                           0.28      3643
#    macro avg       0.27      0.28      0.26      3643
# weighted avg       0.28      0.28      0.27      3643
#
# Classification report for fold 4
#               precision    recall  f1-score   support
#
#            0       0.36      0.70      0.48       258
#            1       0.89      0.57      0.70       239
#            2       0.30      0.33      0.31       251
#            3       0.18      0.09      0.12       228
#            4       0.31      0.59      0.40       246
#            5       0.07      0.04      0.05       234
#            6       0.19      0.22      0.21       261
#            7       0.15      0.03      0.04       240
#            8       0.18      0.20      0.19       256
#            9       0.35      0.34      0.34       254
#           10       0.20      0.14      0.16       227
#           11       0.35      0.16      0.22       249
#           12       0.16      0.39      0.23       240
#           13       0.14      0.05      0.07       237
#           14       0.25      0.23      0.24       222
#
#     accuracy                           0.28      3642
#    macro avg       0.27      0.27      0.25      3642
# weighted avg       0.27      0.28      0.25      3642

# %% [markdown]
# ## Training on phone gyroscope sensor

# %% [markdown]
# ### Hyper parameters

# %%
#ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "kicking soccer ball"]
ACTIVITY_NAMES = ["walking", "jogging", "stairs", "sitting", "standing", "typing", "brushing teeth",
                  "eating soup", "drinking from cup", 
                  "kicking soccer ball", "playing catch tennis ball", "dribbling basket ball", 
                  "writing", "clapping", "folding clothes"]
NUM_EPOCHS = 90
BATCH_SIZE = 256
WINDOW_SIZE=200
STEP_SIZE=100
NUM_SPLITS=5
NN_NET = lstm_net
DATA_DIR="../dataset/raw/phone/gyro"

# %% [markdown]
# ### Initialize Dataset

# %%
options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.OFF
activity_code, cat_len = get_activity_code(ACTIVITY_NAMES)
# Dataset
train_ds, target_ds = WISDM_Dataset(dir = DATA_DIR,
                              window_size = WINDOW_SIZE,
                              step_size = STEP_SIZE,
                              activity_code = activity_code)
k_fold = KFold(n_splits = NUM_SPLITS,
           shuffle = True,
           random_state = RANDOM_STATE)
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'K': 8, 'M': 9, 'O': 10, 'P': 11, 'Q': 12, 'R': 13, 'S': 14}
# Number of Categories 15
# loading data 100%|███████████████████████████| [   51/  51, 00:13<00:00 ]
#          id activity_code        timestamp         x         y         z
# 0      1600             A  252207918580802 -0.853210  0.297226  0.890182
# 1      1600             A  252207968934806 -0.875137  0.015472  0.162231
# 2      1600             A  252208019288809 -0.720169  0.388489 -0.284012
# 3      1600             A  252208069642813 -0.571640  1.227402 -0.241669
# 4      1600             A  252208119996817 -0.380493  1.202835 -0.213135
# ...     ...           ...              ...       ...       ...       ...
# 78280  1650             S  357650830694000  0.687096  0.087352  0.167247
# 78281  1650             S  357650870975000  0.417584 -0.095874  0.056459
# 78282  1650             S  357650911282000  0.096939 -0.083091 -0.028762
# 78283  1650             S  357650951562000 -0.242880 -0.164051 -0.102265
# 78284  1650             S  357650992561000 -0.543285 -0.302535 -0.196009
#
# [1819200 rows x 6 columns]

# %% [markdown]
# ### Model Summary

# %%
model = NN_NET(train_ds, cat_len)
print(model.summary())
# Out:
# Model: "LSTM_NET"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_12                │ (None, 200, 512)       │       532,480 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 200, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_13                │ (None, 200, 256)       │       656,384 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 200, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 51200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 128)            │     6,553,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 15)             │         1,935 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,748,111 (29.56 MB)
#  Trainable params: 7,746,319 (29.55 MB)
#  Non-trainable params: 1,792 (7.00 KB)
# None

# %% [markdown]
# ### Training

# %%
training_data = train(nn_net=NN_NET,
                      cat_len=cat_len,
                      batch_size=BATCH_SIZE,
                      num_epochs=NUM_EPOCHS,
                      k_fold=k_fold,
                      train_ds=train_ds,
                      target_ds=target_ds)
# Out:
# Running fold: 0
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.1976 - loss: 2.8944 - val_accuracy: 0.2801 - val_loss: 2.1120 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.3044 - loss: 2.0444 - val_accuracy: 0.3161 - val_loss: 1.9819 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.3718 - loss: 1.8149 - val_accuracy: 0.3345 - val_loss: 1.8124 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.3989 - loss: 1.6848 - val_accuracy: 0.3626 - val_loss: 1.7390 - learning_rate: 0.0010
# Epoch 5/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.4705 - loss: 1.5019 - val_accuracy: 0.4118 - val_loss: 1.6589 - learning_rate: 0.0010
# Epoch 6/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5047 - loss: 1.3815 - val_accuracy: 0.4104 - val_loss: 1.6438 - learning_rate: 0.0010
# Epoch 7/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5250 - loss: 1.2911 - val_accuracy: 0.4340 - val_loss: 1.5998 - learning_rate: 0.0010
# Epoch 8/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.5611 - loss: 1.2143 - val_accuracy: 0.4434 - val_loss: 1.5711 - learning_rate: 0.0010
# Epoch 9/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.5883 - loss: 1.1290 - val_accuracy: 0.4577 - val_loss: 1.5657 - learning_rate: 0.0010
# Epoch 10/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6237 - loss: 1.0450 - val_accuracy: 0.4527 - val_loss: 1.5951 - learning_rate: 0.0010
# Epoch 11/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6414 - loss: 0.9936 - val_accuracy: 0.4456 - val_loss: 1.6872 - learning_rate: 0.0010
# Epoch 12/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6688 - loss: 0.9276 - val_accuracy: 0.4722 - val_loss: 1.6065 - learning_rate: 0.0010
# Epoch 13/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.6944 - loss: 0.8612 - val_accuracy: 0.4794 - val_loss: 1.6156 - learning_rate: 0.0010
# Epoch 14/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7188 - loss: 0.8062
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.7192 - loss: 0.8051 - val_accuracy: 0.4736 - val_loss: 1.6171 - learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7430 - loss: 0.7350 - val_accuracy: 0.5080 - val_loss: 1.4534 - learning_rate: 5.0000e-04
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7782 - loss: 0.6448 - val_accuracy: 0.5110 - val_loss: 1.4028 - learning_rate: 5.0000e-04
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8096 - loss: 0.5534 - val_accuracy: 0.5159 - val_loss: 1.4534 - learning_rate: 5.0000e-04
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8316 - loss: 0.4893 - val_accuracy: 0.5209 - val_loss: 1.4570 - learning_rate: 5.0000e-04
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8497 - loss: 0.4512 - val_accuracy: 0.5146 - val_loss: 1.5413 - learning_rate: 5.0000e-04
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8453 - loss: 0.4486 - val_accuracy: 0.5311 - val_loss: 1.5270 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8587 - loss: 0.4170
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8590 - loss: 0.4164 - val_accuracy: 0.5184 - val_loss: 1.4957 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8715 - loss: 0.3777 - val_accuracy: 0.5327 - val_loss: 1.4545 - learning_rate: 2.5000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.8927 - loss: 0.3287 - val_accuracy: 0.5360 - val_loss: 1.4573 - learning_rate: 2.5000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9102 - loss: 0.2799 - val_accuracy: 0.5379 - val_loss: 1.4560 - learning_rate: 2.5000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9211 - loss: 0.2510 - val_accuracy: 0.5352 - val_loss: 1.4839 - learning_rate: 2.5000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9254 - loss: 0.2386
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9255 - loss: 0.2383 - val_accuracy: 0.5352 - val_loss: 1.5703 - learning_rate: 2.5000e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# Time elapsed: 0:03:20.257650
# Running fold: 1
# Epoch 1/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.2090 - loss: 2.7918 - val_accuracy: 0.2416 - val_loss: 2.2229 - learning_rate: 0.0010
# Epoch 2/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.2949 - loss: 2.0320 - val_accuracy: 0.2543 - val_loss: 2.1165 - learning_rate: 0.0010
# Epoch 3/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.3710 - loss: 1.7790 - val_accuracy: 0.3029 - val_loss: 1.9444 - learning_rate: 0.0010
# Epoch 4/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.
- learning_rate: 0.0010
# Epoch 15/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7381 - loss: 0.7405 - val_accuracy: 0.4986 - val_loss: 1.4526 - learning_rate: 0.0010
# Epoch 16/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7586 - loss: 0.6890 - val_accuracy: 0.5102 - val_loss: 1.4324 - learning_rate: 0.0010
# Epoch 17/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.7747 - loss: 0.6476 - val_accuracy: 0.5008 - val_loss: 1.5489 - learning_rate: 0.0010
# Epoch 18/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7946 - loss: 0.5809 - val_accuracy: 0.5173 - val_loss: 1.6162 - learning_rate: 0.0010
# Epoch 19/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7780 - loss: 0.6403
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.7783 - loss: 0.6394 - val_accuracy: 0.5206 - val_loss: 1.4532 - learning_rate: 0.0010
# Epoch 20/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8101 - loss: 0.5333 - val_accuracy: 0.5330 - val_loss: 1.4963 - learning_rate: 5.0000e-04
# Epoch 21/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8467 - loss: 0.4484 - val_accuracy: 0.5349 - val_loss: 1.3981 - learning_rate: 5.0000e-04
# Epoch 22/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.8732 - loss: 0.3656 - val_accuracy: 0.5525 - val_loss: 1.3965 - learning_rate: 5.0000e-04
# Epoch 23/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.8983 - loss: 0.3088 - val_accuracy: 0.5476 - val_loss: 1.4182 - learning_rate: 5.0000e-04
# Epoch 24/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9068 - loss: 0.2859 - val_accuracy: 0.5544 - val_loss: 1.4324 - learning_rate: 5.0000e-04
# Epoch 25/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9069 - loss: 0.2829 - val_accuracy: 0.5481 - val_loss: 1.5412 - learning_rate: 5.0000e-04
# Epoch 26/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9109 - loss: 0.2808 - val_accuracy: 0.5467 - val_loss: 1.5832 - learning_rate: 5.0000e-04
# Epoch 27/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9191 - loss: 0.2494
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9192 - loss: 0.2490 - val_accuracy: 0.5588 - val_loss: 1.4501 - learning_rate: 5.0000e-04
# Epoch 28/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9363 - loss: 0.2063 - val_accuracy: 0.5610 - val_loss: 1.4549 - learning_rate: 2.5000e-04
# Epoch 29/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9533 - loss: 0.1624 - val_accuracy: 0.5585 - val_loss: 1.4839 - learning_rate: 2.5000e-04
# Epoch 30/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9625 - loss: 0.1434 - val_accuracy: 0.5638 - val_loss: 1.5157 - learning_rate: 2.5000e-04
# Epoch 31/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9649 - loss: 0.1273 - val_accuracy: 0.5649 - val_loss: 1.5153 - learning_rate: 2.5000e-04
# Epoch 32/90
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9658 - loss: 0.1229
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9658 - loss: 0.1227 - val_accuracy: 0.5613 - val_loss: 1.5519 - learning_rate: 2.5000e-04
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# Time elapsed: 0:19:33.426809
# Total Training Time: 0:19:33
# Val Acc per fold: [53.52, 55.88, 56.95, 55.85, 56.13]

# %% [markdown]
# ### Plot loss and accuracy

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    plot_loss_acc(len(model_data.history["loss"]), model_data.history["loss"], 
                              [acc * 100.0 for acc in model_data.history["accuracy"]], 
                              model_data.history["val_loss"], 
                              [acc * 100.0 for acc in model_data.history["val_accuracy"]], str(k))

# %% [markdown]
# ### Plot Confusion matrix

# %%
for k in training_data.keys():
    # Plot loss and accuracy curves
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    plot_confusion_matrix(y_pred, y_valid, k)

# %% [markdown]
# ### Accuracy Per Fold

# %%
print("Validation Accuracy fold wise")
for k in training_data.keys():
    # Plot loss and accuracy curves
    model_data = training_data[k]['model_data']
    val_acc = np.around(100.0 * model_data.history["val_accuracy"][-1], 2)
    print(f"fold {k}: {val_acc}")
# Out:
# Validation Accuracy fold wise
# fold 0: 53.52
# fold 1: 55.88
# fold 2: 56.95
# fold 3: 55.85
# fold 4: 56.13

# %% [markdown]
# ### Classification metric

# %%
for k in training_data.keys():
    # F1 score
    y_pred = training_data[k]['y_pred']
    y_valid = training_data[k]['y_valid']
    print(f"Classification report for fold {k}")
    print(classification_report(y_true=y_valid,
                                y_pred=y_pred))
# Out:
# Classification report for fold 0
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92       244
#            1       0.93      0.92      0.92       228
#            2       0.86      0.85      0.85       236
#            3       0.25      0.21      0.23       284
#            4       0.38      0.47      0.42       240
#            5       0.16      0.57      0.25       233
#            6       0.51      0.42      0.46       229
#            7       0.45      0.17      0.25       252
#            8       0.31      0.14      0.19       254
#            9       0.68      0.79      0.73       217
#           10       0.70      0.72      0.71       247
#           11       0.71      0.67      0.69       236
#           12       0.52      0.11      0.18       253
#           13       0.59      0.28      0.38       244
#           14       0.50      0.60      0.54       241
#
#     accuracy                           0.51      3638
#    macro avg       0.56      0.52      0.51      3638
# weighted avg       0.56      0.51      0.51      3638
#
# Classification report for fold 1
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92       256
#            1       0.92      0.95      0.94       215
#            2       0.89      0.87      0.88       247
#            3       0.27      0.09      0.13       224
#            4       0.39      0.54      0.45       242
#            5       0.32      0.14      0.19       251
#            6       0.50      0.51      0.51       230
#            7       0.34      0.28      0.31       242
#            8       0.29      0.20      0.24       226
#            9       0.69      0.78      0.73       251
#           10       0.67      0.69      0.68       232
#           11       0.69      0.67      0.68       242
#           12       0.23      0.57      0.32       248
#           13       0.70      0.36      0.48       274
#           14       0.55      0.61      0.58       258
#
#     accuracy                           0.55      3638
#    macro avg       0.56      0.55      0.54      3638
# weighted avg       0.56      0.55      0.54      3638
#
# Classification report for fold 2
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95       269
#            1       0.92      0.93      0.93       222
#            2       0.86      0.85      0.86       261
#            3       0.23      0.55      0.33       225
#            4       0.45      0.54      0.49       241
#            5       0.26      0.23      0.25       235
#            6       0.48      0.46      0.47       247
#            7       0.31      0.33      0.32       242
#            8       0.34      0.17      0.23       259
#            9       0.66      0.76      0.71       235
#           10       0.71      0.63      0.67       250
#           11       0.70      0.75      0.72       258
#           12       0.35      0.15      0.21       236
#           13       0.53      0.32      0.40       237
#           14       0.61      0.61      0.61       221
#
#     accuracy                           0.55      3638
#    macro avg       0.56      0.55      0.54      3638
# weighted avg       0.56      0.55      0.55      3638
#
# Classification report for fold 3
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93       254
#            1       0.93      0.96      0.95       273
#            2       0.86      0.89      0.87       211
#            3       0.27      0.34      0.30       264
#            4       0.45      0.50      0.47       238
#            5       0.30      0.17      0.22       231
#            6       0.53      0.34      0.42       254
#            7       0.31      0.31      0.31       252
#            8       0.32      0.17      0.22       213
#            9       0.70      0.81      0.75       262
#           10       0.74      0.72      0.73       254
#           11       0.71      0.65      0.68       234
#           12       0.21      0.46      0.29       237
#           13       0.58      0.35      0.44       229
#           14       0.61      0.57      0.59       232
#
#     accuracy                           0.55      3638
#    macro avg       0.56      0.54      0.54      3638
# weighted avg       0.57      0.55      0.55      3638
#
# Classification report for fold 4
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93       251
#            1       0.93      0.93      0.93       238
#            2       0.80      0.94      0.87       245
#            3       0.31      0.18      0.22       227
#            4       0.49      0.48      0.48       263
#            5       0.22      0.17      0.19       226
#            6       0.46      0.47      0.46       264
#            7       0.42      0.30      0.35       236
#            8       0.43      0.16      0.23       272
#            9       0.73      0.78      0.76       259
#           10       0.70      0.69      0.70       217
#           11       0.71      0.69      0.70       254
#           12       0.22      0.64      0.33       226
#           13       0.59      0.29      0.39       240
#           14       0.54      0.69      0.60       220
#
#     accuracy                           0.55      3638
#    macro avg       0.57      0.55      0.54      3638
# weighted avg       0.57      0.55      0.54      3638
